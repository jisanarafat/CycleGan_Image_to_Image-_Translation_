# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import matplotlib.pyplot as plt
import warnings
import os

# %%
import torch
from torch.utils.data import DataLoader
import torchvision
import torchvision.datasets as datasets
import torchvision.transforms as transforms
import torch.nn.functional as F
from torch import nn, optim

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = "retina"

# %% [markdown]
# ### Loading Data

# %%
from PIL import Image

def get_data_loader(image_type, image_dir='/content/drive/MyDrive/ColabNotebooks/DataSet/horse2zebra', image_size=128, batch_size=16, num_workers=0):
    """returns: training and test data loaders for a given image type, either summer or winter"""

    # Resize and normalize the images
    transform = transforms.Compose([
        transforms.Resize((image_size, image_size), interpolation=Image.BICUBIC),  # Resize images to have dimensions (image_size, image_size)
        transforms.ToTensor()  # Convert images to PyTorch tensors
    ])

    # Get training and test directories
    train_path = os.path.join(image_dir, image_type)
    test_path = os.path.join(image_dir, 'test_{}'.format(image_type))

    # Define datasets using ImageFolder
    train_dataset = datasets.ImageFolder(train_path, transform)
    test_dataset = datasets.ImageFolder(test_path, transform)

    # Create and return DataLoaders
    train_loader = DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True, num_workers=num_workers)
    test_loader = DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=False, num_workers=num_workers)

    # Retrieve a sample image from the training dataset for visualization
    sample_image, _ = train_dataset[2]


    # Visualize the sample image

    # Display the raw image and transformed image side by side
    plt.figure(figsize=(12, 8))

    plt.subplot(1, 5, 2)
    plt.imshow(sample_image.permute(1, 2, 0))
    plt.title('Original Image')
    plt.axis('off')

    # Display the transformed image
    plt.subplot(1, 5, 4)
    np_image = sample_image.numpy().transpose((1, 2, 0))
    plt.imshow(np_image)
    plt.title('Transformed Image')
    plt.axis('off')

    plt.show()

    return train_loader, test_loader

# %% [markdown]
# ####Resize and Normalize Output Check

# %%
dataloader_X, test_dataloader_X = get_data_loader(image_type='hourse')
dataloader_Y, test_dataloader_Y = get_data_loader(image_type='zebra')

# %%
# display sample images
def imshow(img):
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))

# %%
import torch
import torchvision
import matplotlib.pyplot as plt

# Assuming dataloader_X is your DataLoader
dataiter = iter(dataloader_X)
images, _ = next(dataiter)  # Use next() directly to get the next batch

# Visualize the batch of images
fig = plt.figure(figsize=(12, 8))
imshow(torchvision.utils.make_grid(images))
plt.show()

# %%
import torch
import torchvision
import matplotlib.pyplot as plt

# Assuming dataloader_Y is your DataLoader
dataiter = iter(dataloader_Y)

# Get the first batch from the dataloader
for images, _ in dataiter:
    break

# Visualize the batch of images
fig = plt.figure(figsize=(12, 8))
imshow(torchvision.utils.make_grid(images))
plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# ### Building the Model

# %%
img = images[3]
print('min: ', img.min())
print('max: ', img.max())
# Out:
# min:  tensor(0.)
# max:  tensor(1.)

# %%
# Define a helper function for creating convolutional layers
def conv(in_channels, out_channels, kernel_size=4, stride=2, padding=1, batch_norm=True):
    layers = []
    conv_layer = nn.Conv2d(in_channels, out_channels, kernel_size, stride, padding, bias=False)
    layers.append(conv_layer)
    if batch_norm:
        layers.append(nn.BatchNorm2d(out_channels))
    return nn.Sequential(*layers)

# %% [markdown]
# #### Discriminator

# %%
# Discriminator Class
class Discriminator(nn.Module):
    def __init__(self, conv_dim=64):
        super(Discriminator, self).__init__()
        # Define all convolutional layers
        self.conv1 = conv(3, conv_dim, 4, stride=2, padding=1, batch_norm=False)  # 64x64x64
        self.conv2 = conv(conv_dim, conv_dim * 2, 4, stride=2, padding=1)  # 32x32x128
        self.conv3 = conv(conv_dim * 2, conv_dim * 4, 4, stride=2, padding=1)  # 16x16x256
        self.conv4 = conv(conv_dim * 4, conv_dim * 8, 4, stride=2, padding=1)  # 8x8x512
        # Final layer
        self.conv5 = nn.Conv2d(conv_dim * 8, 1, 4, stride=1, padding=0, bias=False)  # 1x1x1

    def forward(self, x):
        out = nn.ReLU()(self.conv1(x))
        out = nn.ReLU()(self.conv2(out))
        out = nn.ReLU()(self.conv3(out))
        out = nn.ReLU()(self.conv4(out))
        out = self.conv5(out)
        out = torch.sigmoid(out)  # Add sigmoid for output
        return out.view(-1)  # Flatten to 1D for output

# %%
# Residual block definition
class ResidualBlock(nn.Module):
    def __init__(self, dim):
        super(ResidualBlock, self).__init__()
        self.conv1 = conv(dim, dim, kernel_size=3, stride=1, padding=1)
        self.conv2 = conv(dim, dim, kernel_size=3, stride=1, padding=1, batch_norm=False)

    def forward(self, x):
        residual = x
        x = nn.ReLU()(self.conv1(x))
        x = self.conv2(x)
        return x + residual  # Adding residual for skip connection

# %%
def deconv(in_channels, out_channels, kernel_size=4, stride=2, padding=1, batch_norm=True):
    layers = []
    deconv_layer = nn.ConvTranspose2d(in_channels, out_channels, kernel_size, stride, padding, bias=False)
    layers.append(deconv_layer)
    if batch_norm:
        layers.append(nn.BatchNorm2d(out_channels))
    return nn.Sequential(*layers)

# %% [markdown]
# #### CycleGenerator

# %%
# CycleGenerator Class
class CycleGenerator(nn.Module):
    def __init__(self, conv_dim=64, n_res_blocks=6):
        super(CycleGenerator, self).__init__()
        # 1. Encoder
        self.conv1 = conv(3, conv_dim, 4, stride=2, padding=1)  # 128x128 -> 64x64
        self.conv2 = conv(conv_dim, conv_dim * 2, 4, stride=2, padding=1)  # 64x64 -> 32x32
        self.conv3 = conv(conv_dim * 2, conv_dim * 4, 4, stride=2, padding=1)  # 32x32 -> 16x16

        # 2. Residual blocks
        res_layers = []
        for _ in range(n_res_blocks):
            res_layers.append(ResidualBlock(conv_dim * 4))
        self.res_blocks = nn.Sequential(*res_layers)

        # 3. Decoder
        self.deconv1 = deconv(conv_dim * 4, conv_dim * 2, 4, stride=2, padding=1)  # 16x16 -> 32x32
        self.deconv2 = deconv(conv_dim * 2, conv_dim, 4, stride=2, padding=1)  # 32x32 -> 64x64
        self.deconv3 = deconv(conv_dim, 3, 4, stride=2, padding=1, batch_norm=False)  # 64x64 -> 128x128

    def forward(self, x):
        """Transforms an image and returns it."""
        out = nn.ReLU()(self.conv1(x))
        out = nn.ReLU()(self.conv2(out))
        out = nn.ReLU()(self.conv3(out))
        out = self.res_blocks(out)
        out = nn.ReLU()(self.deconv1(out))
        out = nn.ReLU()(self.deconv2(out))
        # Apply tanh activation to the final output
        out = nn.Tanh()(self.deconv3(out))
        return out

# %% [markdown]
# ### Complete Network

# %%
# Assuming CycleGenerator and Discriminator are defined elsewhere

def create_model(
    g_conv_dim=64,
    d_conv_dim=64,
    n_res_blocks=6,
    device=None
):
    """Builds and initializes generators and discriminators for CycleGAN."""
    # Assign the device if not provided
    if device is None:
        device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

    # Instantiate generators
    G_XtoY = CycleGenerator(conv_dim=g_conv_dim, n_res_blocks=n_res_blocks).to(device)
    G_YtoX = CycleGenerator(conv_dim=g_conv_dim, n_res_blocks=n_res_blocks).to(device)

    # Instantiate discriminators
    D_X = Discriminator(conv_dim=d_conv_dim).to(device)
    D_Y = Discriminator(conv_dim=d_conv_dim).to(device)

    # Log the device information
    if device.type == "cuda":
        print(f"Models moved to GPU: {torch.cuda.get_device_name(device)}.")
    else:
        print("Models using CPU.")

    # Return the initialized models
    return G_XtoY, G_YtoX, D_X, D_Y

# %%
G_XtoY, G_YtoX, D_X, D_Y = create_model()
# Out:
# Models moved to GPU: Tesla T4.

# %%
def print_models(G_XtoY, G_YtoX, D_X, D_Y):
    """Prints model information for the generators and discriminators.
    """
    print("                     G_XtoY                    ")
    print("-----------------------------------------------")
    print(G_XtoY)
    print()

    print("                     G_YtoX                    ")
    print("-----------------------------------------------")
    print(G_YtoX)
    print()

    print("                      D_X                      ")
    print("-----------------------------------------------")
    print(D_X)
    print()

    print("                      D_Y                      ")
    print("-----------------------------------------------")
    print(D_Y)
    print()


# print all of the models
print_models(G_XtoY, G_YtoX, D_X, D_Y)
# Out:
#                      G_XtoY
# -----------------------------------------------
# CycleGenerator(
#   (conv1): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv3): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (res_blocks): Sequential(
#     (0): ResidualBlock(
#       (conv1): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (1): ResidualBlock(
#       (conv1): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (2): ResidualBlock(
#       (conv1): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (3): ResidualBlock(
#       (conv1): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (4): ResidualBlock(
#       (conv1): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (5): ResidualBlock(
#       (conv1): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#   )
#   (deconv1): Sequential(
#     (0): ConvTranspose2d(256, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (deconv2): Sequential(
#     (0): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (deconv3): Sequential(
#     (0): ConvTranspose2d(64, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   )
# )
#
#                      G_YtoX
# -----------------------------------------------
# CycleGenerator(
#   (conv1): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv3): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (res_blocks): Sequential(
#     (0): ResidualBlock(
#       (conv1): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (1): ResidualBlock(
#       (conv1): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (2): ResidualBlock(
#       (conv1): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (3): ResidualBlock(
#       (conv1): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (4): ResidualBlock(
#       (conv1): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (5): ResidualBlock(
#       (conv1): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#   )
#   (deconv1): Sequential(
#     (0): ConvTranspose2d(256, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (deconv2): Sequential(
#     (0): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (deconv3): Sequential(
#     (0): ConvTranspose2d(64, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   )
# )
#
#                       D_X
# -----------------------------------------------
# Discriminator(
#   (conv1): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv3): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv4): Sequential(
#     (0): Conv2d(256, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv5): Conv2d(512, 1, kernel_size=(4, 4), stride=(1, 1), bias=False)
# )
#
#                       D_Y
# -----------------------------------------------
# Discriminator(
#   (conv1): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv3): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv4): Sequential(
#     (0): Conv2d(256, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv5): Conv2d(512, 1, kernel_size=(4, 4), stride=(1, 1), bias=False)
# )

# %% [markdown]
# #### GANs loss

# %%
def real_mse_loss(D_out):
    # how close is the produced output from being "real"?
    return torch.mean((D_out-1)**2)

# %%
def fake_mse_loss(D_out):
    # how close is the produced output from being "fake"?
    return torch.mean(D_out**2)

# %%
def cycle_consistency_loss(real_im, reconstructed_im, lambda_weight):
    # calculate reconstruction loss
    # as absolute value difference between the real and reconstructed images
    reconstr_loss = torch.mean(torch.abs(real_im - reconstructed_im))
    # return weighted loss
    return lambda_weight*reconstr_loss

# %% [markdown]
# ### Optimizers

# %%
# hyperparams for Adam optimizer
lr=0.0002
beta1=0.5
beta2=0.999 # default value

# %%
# Get generator parameters
g_params = list(G_XtoY.parameters()) + list(G_YtoX.parameters())

# %%
# Create optimizers for the generators and discriminators
g_optimizer = optim.Adam(g_params, lr, [beta1, beta2])
d_x_optimizer = optim.Adam(D_X.parameters(), lr, [beta1, beta2])
d_y_optimizer = optim.Adam(D_Y.parameters(), lr, [beta1, beta2])

# %% [markdown]
# ### Helper functions

# %%
import pdb
import pickle
import argparse
import scipy
import scipy.misc

# %%
warnings.filterwarnings("ignore")

# %%
def checkpoint(iteration, G_XtoY, G_YtoX, D_X, D_Y, checkpoint_dir='/content/drive/MyDrive/ColabNotebooks/model_checkpoints'):
    """saves the parameters of both generators G_YtoX, G_XtoY and discriminators D_X, D_Y"""
    G_XtoY_path = os.path.join(checkpoint_dir, 'G_XtoY.pkl')
    G_YtoX_path = os.path.join(checkpoint_dir, 'G_YtoX.pkl')
    D_X_path = os.path.join(checkpoint_dir, 'D_X.pkl')
    D_Y_path = os.path.join(checkpoint_dir, 'D_Y.pkl')
    torch.save(G_XtoY.state_dict(), G_XtoY_path)
    torch.save(G_YtoX.state_dict(), G_YtoX_path)
    torch.save(D_X.state_dict(), D_X_path)
    torch.save(D_Y.state_dict(), D_Y_path)

# %%
import numpy as np

def merge_images(sources, targets, batch_size=16):
    """
    Merges source and target image batches into a single image for visualization.

    Args:
    - sources (numpy array): Source images of shape (B, C, H, W).
    - targets (numpy array): Target images of shape (B, C, H, W).
    - batch_size (int): Number of images in each batch.

    Returns:
    - merged (numpy array): Merged image with source and target pairs side-by-side.
    """
    # Check if batch_size matches the number of images
    if len(sources) != batch_size or len(targets) != batch_size:
        raise ValueError("Batch size does not match the number of images in sources or targets.")

    # Get height and width from source images
    _, channels, height, width = sources.shape

    # Calculate number of rows for the merged image (square layout)
    row = int(np.sqrt(batch_size))

    # Initialize an empty array for the merged image
    # This will contain source and target pairs side-by-side
    merged = np.zeros((channels, row * height, row * width * 2))

    # Loop through the batches to fill the merged array
    for idx, (source, target) in enumerate(zip(sources, targets)):
        # Determine row and column index for placement
        row_idx = idx // row
        col_idx = idx % row

        # Place the source and target images into the merged array
        merged[:, row_idx * height:(row_idx + 1) * height, (col_idx * 2) * width:(col_idx * 2 + 1) * width] = source
        merged[:, row_idx * height:(row_idx + 1) * height, (col_idx * 2 + 1) * width:(col_idx * 2 + 2) * width] = target

    # Transpose the merged array for the correct (H, W, C) format
    merged = merged.transpose(1, 2, 0)

    return merged

# %%
def to_data(x):
    """converts variable to numpy."""
    if torch.cuda.is_available():
        x = x.cpu()
    x = x.data.numpy()
    x = ((x +1)*255 / (2)).astype(np.uint8) # rescale to 0-255
    return x

# %%
import os
import imageio
def save_samples(iteration, fixed_Y, fixed_X, G_YtoX, G_XtoY, batch_size=16, sample_dir='image_samples'):
    """saves samples from both generators X->Y and Y->X."""
    # move input data to correct device
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

    fake_X = G_YtoX(fixed_Y.to(device))
    fake_Y = G_XtoY(fixed_X.to(device))

    X, fake_X = to_data(fixed_X), to_data(fake_X)
    Y, fake_Y = to_data(fixed_Y), to_data(fake_Y)

    # Create directory if it doesn't exist
    os.makedirs(sample_dir, exist_ok=True)


    merged = merge_images(X, fake_Y, batch_size)
    merged = merged.astype(np.uint8)
    path = os.path.join(sample_dir, 'sample-{:06d}-X-Y.png'.format(iteration))
    imageio.imwrite(path, merged)
    print('Saved {}'.format(path))

    merged = merge_images(Y, fake_X, batch_size)
    merged = merged.astype(np.uint8)
    path = os.path.join(sample_dir, 'sample-{:06d}-Y-X.png'.format(iteration))
    imageio.imwrite(path, merged)
    print('Saved {}'.format(path))

# %%
def imshow(img):
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()

# %% [markdown]
# ### Training the Model

# %%
# helper scale function
def scale(x, feature_range=(-1, 1)):
    ''' Scale takes in an image x and returns that image, scaled
       with a feature_range of pixel values from -1 to 1.
       This function assumes that the input x is already scaled from 0-1.'''

    # scale from 0-1 to feature_range
    min, max = feature_range
    x = x * (max - min) + min
    return x

# %%
def unnormalize_images(images):
    """ Return tensor of images to [0:255] space from [-1:1] for plotting. """
    unnormalized = torch.zeros_like(images)
    t = transforms.Normalize(
        mean=[-0.5 / 0.5, -0.5 / 0.5, -0.5 / 0.5],
        std=[1 / 0.5, 1 / 0.5, 1 / 0.5])
    for i, image in enumerate(images):
        unnormalized[i] = t(image)*255
    return unnormalized

# %%
def training_loop(dataloader_X, dataloader_Y, test_dataloader_X, test_dataloader_Y, n_epochs=100):
    print_every=10


    # Create optimizers for the generators and discriminators
    g_optimizer = optim.Adam(g_params, lr, [beta1, beta2])
    d_x_optimizer = optim.Adam(D_X.parameters(), lr, [beta1, beta2])
    d_y_optimizer = optim.Adam(D_Y.parameters(), lr, [beta1, beta2])

    # keep track of losses over time
    losses = []

    test_iter_X = iter(test_dataloader_X)
    test_iter_Y = iter(test_dataloader_Y)

    # Get some fixed data from domains X and Y for sampling. These are images that are held
    # constant throughout training, that allow us to inspect the model's performance.
    fixed_X = next(test_iter_X)[0]
    fixed_Y = next(test_iter_Y)[0]
    fixed_X = scale(fixed_X) # make sure to scale to a range -1 to 1
    fixed_Y = scale(fixed_Y)

    # batches per epoch
    iter_X = iter(dataloader_X)
    iter_Y = iter(dataloader_Y)
    batches_per_epoch = min(len(iter_X), len(iter_Y))

    for epoch in range(1, n_epochs+1):
        # Reset iterators for each epoch
        if epoch % batches_per_epoch == 0:
            iter_X = iter(dataloader_X)
            iter_Y = iter(dataloader_Y)

        images_X, _ = next(iter_X)
        real_images = images_X
        images_X = scale(images_X) # make sure to scale to a range -1 to 1

        images_Y, _ = next(iter_Y)
        real_images = images_Y
        images_Y = scale(images_Y)

        # move images to GPU if available (otherwise stay on CPU)
        device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
        images_X = images_X.to(device)
        images_Y = images_Y.to(device)


        # ============================================
        #            TRAIN THE DISCRIMINATORS
        # ============================================

        ##   First: D_X, real and fake loss components   ##

        # Train with real images
        d_x_optimizer.zero_grad()

        # 1. Compute the discriminator losses on real images
        out_x = D_X(images_X)
        D_X_real_loss = real_mse_loss(out_x)

        # Train with fake images

        # 2. Generate fake images that look like domain X based on real images in domain Y
        fake_X = G_YtoX(images_Y)

        # 3. Compute the fake loss for D_X
        out_x = D_X(fake_X)
        D_X_fake_loss = fake_mse_loss(out_x)


        # 4. Compute the total loss and perform backprop
        d_x_loss = D_X_real_loss + D_X_fake_loss
        d_x_loss.backward()
        d_x_optimizer.step()


        ##   Second: D_Y, real and fake loss components   ##

        # Train with real images
        d_y_optimizer.zero_grad()

        # 1. Compute the discriminator losses on real images
        out_y = D_Y(images_Y)
        D_Y_real_loss = real_mse_loss(out_y)

        # Train with fake images

        # 2. Generate fake images that look like domain Y based on real images in domain X
        fake_Y = G_XtoY(images_X)

        # 3. Compute the fake loss for D_Y
        out_y = D_Y(fake_Y)
        D_Y_fake_loss = fake_mse_loss(out_y)

        # 4. Compute the total loss and perform backprop
        d_y_loss = D_Y_real_loss + D_Y_fake_loss
        d_y_loss.backward()
        d_y_optimizer.step()


        # =========================================
        #            TRAIN THE GENERATORS
        # =========================================

        ##    First: generate fake X images and reconstructed Y images    ##
        g_optimizer.zero_grad()

        # 1. Generate fake images that look like domain X based on real images in domain Y
        fake_X = G_YtoX(images_Y)

        # 2. Compute the generator loss based on domain X
        out_x = D_X(fake_X)
        g_YtoX_loss = real_mse_loss(out_x)

        # 3. Create a reconstructed y
        # 4. Compute the cycle consistency loss (the reconstruction loss)
        reconstructed_Y = G_XtoY(fake_X)

        reconstructed_y_loss = cycle_consistency_loss(images_Y, reconstructed_Y, lambda_weight=10)


        ##    Second: generate fake Y images and reconstructed X images    ##

        # 1. Generate fake images that look like domain Y based on real images in domain X
        fake_Y = G_XtoY(images_X)

        # 2. Compute the generator loss based on domain Y
        out_y = D_Y(fake_Y)
        g_XtoY_loss = real_mse_loss(out_y)

        # 3. Create a reconstructed x
        # 4. Compute the cycle consistency loss (the reconstruction loss)
        reconstructed_X = G_YtoX(fake_Y)
        reconstructed_x_loss = cycle_consistency_loss(images_X, reconstructed_X, lambda_weight=10)

        # 5. Add up all generator and reconstructed losses and perform backprop
        g_total_loss = g_YtoX_loss + g_XtoY_loss + reconstructed_y_loss + reconstructed_x_loss
        g_total_loss.backward()
        g_optimizer.step()


        # Print the log info
        if epoch % print_every == 0:

            # append real and fake discriminator losses and the generator loss
            losses.append((d_x_loss.item(), d_y_loss.item(), g_total_loss.item()))
            print('Epoch [{:5d}/{:5d}] | d_X_loss: {:6.4f} | d_Y_loss: {:6.4f} | g_total_loss: {:6.4f}'.format(
                    epoch, n_epochs, d_x_loss.item(), d_y_loss.item(), g_total_loss.item()))

             # generate image
            X_fake = G_XtoY(images_X)
            X_fake = unnormalize_images(X_fake)
            images_X = unnormalize_images(images_X)
            grid_image_real = torchvision.utils.make_grid(images_X.cpu())
            grid_image_fake = torchvision.utils.make_grid(X_fake.cpu())
            grid_image = torch.cat((grid_image_real, grid_image_fake), 1)
            saveim = np.transpose(grid_image.data.numpy().astype(np.uint8), (1, 2, 0))
            # plt.figure(figsize=(20, 10))
            # plt.imshow(saveim)
            # plt.savefig(filename + '_' + 'XtoY.jpg')

            Y_fake = G_YtoX(images_Y)
            Y_fake = unnormalize_images(Y_fake)
            images_Y = unnormalize_images(images_Y)
            grid_image_real = torchvision.utils.make_grid(images_Y.cpu())
            grid_image_fake = torchvision.utils.make_grid(Y_fake.cpu())
            grid_image = torch.cat((grid_image_real, grid_image_fake), 1)
            saveim = np.transpose(grid_image.data.numpy().astype(np.uint8), (1, 2, 0))



        sample_every=100
        # Save the generated samples
        if epoch % sample_every == 0:
            G_YtoX.eval() # set generators to eval mode for sample generation
            G_XtoY.eval()
            save_samples(epoch, fixed_Y, fixed_X, G_YtoX, G_XtoY, batch_size=16)
            G_YtoX.train()
            G_XtoY.train()

        # uncomment these lines, if you want to save your model
        checkpoint_every=1000
        # Save the model parameters
        if epoch % checkpoint_every == 0:
            checkpoint(epoch, G_XtoY, G_YtoX, D_X, D_Y)

    return losses

# %%
n_epochs = 5000
losses = training_loop(dataloader_X, dataloader_Y, test_dataloader_X, test_dataloader_Y, n_epochs=n_epochs)
# Out:
# Epoch [   10/ 5000] | d_X_loss: 0.1748 | d_Y_loss: 0.1951 | g_total_loss: 8.7113
# Epoch [   20/ 5000] | d_X_loss: 0.0663 | d_Y_loss: 0.0676 | g_total_loss: 7.4177
# Epoch [   30/ 5000] | d_X_loss: 0.0585 | d_Y_loss: 0.0484 | g_total_loss: 7.3786
# Epoch [   40/ 5000] | d_X_loss: 0.0529 | d_Y_loss: 0.0258 | g_total_loss: 7.1246
# Epoch [   50/ 5000] | d_X_loss: 0.0394 | d_Y_loss: 0.1954 | g_total_loss: 7.3854
# Epoch [   60/ 5000] | d_X_loss: 0.1362 | d_Y_loss: 0.0403 | g_total_loss: 6.6065
# Epoch [   70/ 5000] | d_X_loss: 0.1338 | d_Y_loss: 0.0070 | g_total_loss: 6.6879
# Epoch [   80/ 5000] | d_X_loss: 0.0794 | d_Y_loss: 0.0146 | g_total_loss: 6.3256
# Epoch [   90/ 5000] | d_X_loss: 0.2455 | d_Y_loss: 0.1333 | g_total_loss: 6.4718
# Epoch [  100/ 5000] | d_X_loss: 0.0596 | d_Y_loss: 0.0395 | g_total_loss: 6.0649
# Saved image_samples/sample-000100-X-Y.png
# Saved image_samples/sample-000100-Y-X.png
# Epoch [  110/ 5000] | d_X_loss: 0.0483 | d_Y_loss: 0.0444 | g_total_loss: 6.0457
# Epoch [  120/ 5000] | d_X_loss: 0.1934 | d_Y_loss: 0.0690 | g_total_loss: 5.7926
# Epoch [  130/ 5000] | d_X_loss: 0.0771 | d_Y_loss: 0.0114 | g_total_loss: 5.8410
# Epoch [  140/ 5000] | d_X_loss: 0.3782 | d_Y_loss: 0.1544 | g_total_loss: 6.5494
# Epoch [  150/ 5000] | d_X_loss: 0.0983 | d_Y_loss: 0.0100 | g_total_loss: 5.8987
# Epoch [  160/ 5000] | d_X_loss: 0.0767 | d_Y_loss: 0.0022 | g_total_loss: 6.0612
# Epoch [  170/ 5000] | d_X_loss: 0.0364 | d_Y_loss: 0.0017 | g_total_loss: 6.0832
# Epoch [  180/ 5000] | d_X_loss: 0.1388 | d_Y_loss: 0.0474 | g_total_loss: 5.4110
# Epoch [  190/ 5000] | d_X_loss: 0.0406 | d_Y_loss: 0.0064 | g_total_loss: 5.9755
# Epoch [  200/ 5000] | d_X_loss: 0.0603 | d_Y_loss: 0.0038 | g_total_loss: 5.7898
# Saved image_samples/sample-000200-X-Y.png
# Saved image_samples/sample-000200-Y-X.png
# Epoch [  210/ 5000] | d_X_loss: 0.0366 | d_Y_loss: 0.0084 | g_total_loss: 5.3822
# Epoch [  220/ 5000] | d_X_loss: 0.0091 | d_Y_loss: 0.0030 | g_total_loss: 5.5434
# Epoch [  230/ 5000] | d_X_loss: 0.0243 | d_Y_loss: 0.0004 | g_total_loss: 5.6253
# Epoch [  240/ 5000] | d_X_loss: 0.0323 | d_Y_loss: 0.0014 | g_total_loss: 5.4117
# Epoch [  250/ 5000] | d_X_loss: 0.0899 | d_Y_loss: 0.0051 | g_total_loss: 5.4037
# Epoch [  260/ 5000] | d_X_loss: 0.1052 | d_Y_loss: 0.0775 | g_total_loss: 5.3668
# Epoch [  270/ 5000] | d_X_loss: 0.0099 | d_Y_loss: 0.0022 | g_total_loss: 5.4821
# Epoch [  280/ 5000] | d_X_loss: 0.0129 | d_Y_loss: 0.0013 | g_total_loss: 5.4742
# Epoch [  290/ 5000] | d_X_loss: 0.0558 | d_Y_loss: 0.0031 | g_total_loss: 5.1987
# Epoch [  300/ 5000] | d_X_loss: 0.0013 | d_Y_loss: 0.0003 | g_total_loss: 7.2395
# Saved image_samples/sample-000300-X-Y.png
# Saved image_samples/sample-000300-Y-X.png
# Epoch [  310/ 5000] | d_X_loss: 0.0021 | d_Y_loss: 0.0001 | g_total_loss: 5.7159
# Epoch [  320/ 5000] | d_X_loss: 0.0027 | d_Y_loss: 0.0001 | g_total_loss: 5.5404
# Epoch [  330/ 5000] | d_X_loss: 0.0031 | d_Y_loss: 0.0001 | g_total_loss: 5.1923
# Epoch [  340/ 5000] | d_X_loss: 0.0051 | d_Y_loss: 0.0002 | g_total_loss: 5.0741
# Epoch [  350/ 5000] | d_X_loss: 0.0046 | d_Y_loss: 0.0003 | g_total_loss: 5.8245
# Epoch [  360/ 5000] | d_X_loss: 0.0047 | d_Y_loss: 0.0001 | g_total_loss: 4.9623
# Epoch [  370/ 5000] | d_X_loss: 0.0039 | d_Y_loss: 0.0001 | g_total_loss: 5.2301
# Epoch [  380/ 5000] | d_X_loss: 0.0098 | d_Y_loss: 0.0001 | g_total_loss: 5.2102
# Epoch [  390/ 5000] | d_X_loss: 0.0096 | d_Y_loss: 0.0001 | g_total_loss: 5.1379
# Epoch [  400/ 5000] | d_X_loss: 0.0243 | d_Y_loss: 0.0001 | g_total_loss: 5.2138
# Saved image_samples/sample-000400-X-Y.png
# Saved image_samples/sample-000400-Y-X.png
# Epoch [  410/ 5000] | d_X_loss: 0.0011 | d_Y_loss: 0.0001 | g_total_loss: 6.8276
# Epoch [  420/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 0.0001 | g_total_loss: 6.4559
# Epoch [  430/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 0.0001 | g_total_loss: 5.3828
# Epoch [  440/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 0.0005 | g_total_loss: 5.5750
# Epoch [  450/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 0.0007 | g_total_loss: 5.4973
# Epoch [  460/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 0.0026 | g_total_loss: 5.1744
# Epoch [  470/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 0.0038 | g_total_loss: 5.2541
# Epoch [  480/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 0.0010 | g_total_loss: 5.2759
# Epoch [  490/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 0.2214 | g_total_loss: 5.0321
# Epoch [  500/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 0.0121 | g_total_loss: 4.8354
# Saved image_samples/sample-000500-X-Y.png
# Saved image_samples/sample-000500-Y-X.png
# Epoch [  510/ 5000] | d_X_loss: 0.0004 | d_Y_loss: 0.0061 | g_total_loss: 5.0939
# Epoch [  520/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.2348 | g_total_loss: 5.5650
# Epoch [  530/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 0.0332 | g_total_loss: 5.3007
# Epoch [  540/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0015 | g_total_loss: 5.4486
# Epoch [  550/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0584 | g_total_loss: 5.2334
# Epoch [  560/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 0.0074 | g_total_loss: 5.1874
# Epoch [  570/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 0.0108 | g_total_loss: 4.7275
# Epoch [  580/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 0.0011 | g_total_loss: 4.8866
# Epoch [  590/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0039 | g_total_loss: 5.4944
# Epoch [  600/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 0.2552 | g_total_loss: 5.4914
# Saved image_samples/sample-000600-X-Y.png
# Saved image_samples/sample-000600-Y-X.png
# Epoch [  610/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0015 | g_total_loss: 5.0761
# Epoch [  620/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0070 | g_total_loss: 4.8371
# Epoch [  630/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 0.0258 | g_total_loss: 5.2578
# Epoch [  640/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0047 | g_total_loss: 5.0621
# Epoch [  650/ 5000] | d_X_loss: 0.0003 | d_Y_loss: 0.0079 | g_total_loss: 5.1233
# Epoch [  660/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 0.0045 | g_total_loss: 4.7689
# Epoch [  670/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0066 | g_total_loss: 5.0734
# Epoch [  680/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0020 | g_total_loss: 5.3512
# Epoch [  690/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0014 | g_total_loss: 5.2480
# Epoch [  700/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0018 | g_total_loss: 4.9211
# Saved image_samples/sample-000700-X-Y.png
# Saved image_samples/sample-000700-Y-X.png
# Epoch [  710/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0062 | g_total_loss: 5.3678
# Epoch [  720/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0055 | g_total_loss: 4.7622
# Epoch [  730/ 5000] | d_X_loss: 0.0003 | d_Y_loss: 0.0052 | g_total_loss: 4.4601
# Epoch [  740/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 0.0050 | g_total_loss: 5.4999
# Epoch [  750/ 5000] | d_X_loss: 0.0003 | d_Y_loss: 0.0024 | g_total_loss: 4.7061
# Epoch [  760/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0038 | g_total_loss: 4.6668
# Epoch [  770/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 0.0044 | g_total_loss: 4.7521
# Epoch [  780/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 0.0087 | g_total_loss: 4.5886
# Epoch [  790/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 0.0001 | g_total_loss: 4.7885
# Epoch [  800/ 5000] | d_X_loss: 0.0005 | d_Y_loss: 0.0000 | g_total_loss: 4.6560
# Saved image_samples/sample-000800-X-Y.png
# Saved image_samples/sample-000800-Y-X.png
# Epoch [  810/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 0.0000 | g_total_loss: 4.6442
# Epoch [  820/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 0.0000 | g_total_loss: 4.7007
# Epoch [  830/ 5000] | d_X_loss: 0.0004 | d_Y_loss: 0.0001 | g_total_loss: 5.0169
# Epoch [  840/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 0.0001 | g_total_loss: 4.6338
# Epoch [  850/ 5000] | d_X_loss: 0.0003 | d_Y_loss: 0.0003 | g_total_loss: 4.6470
# Epoch [  860/ 5000] | d_X_loss: 0.0005 | d_Y_loss: 0.0003 | g_total_loss: 4.6990
# Epoch [  870/ 5000] | d_X_loss: 0.0003 | d_Y_loss: 0.0001 | g_total_loss: 4.4331
# Epoch [  880/ 5000] | d_X_loss: 0.0003 | d_Y_loss: 0.0000 | g_total_loss: 4.8960
# Epoch [  890/ 5000] | d_X_loss: 0.0005 | d_Y_loss: 0.0009 | g_total_loss: 4.7682
# Epoch [  900/ 5000] | d_X_loss: 0.0004 | d_Y_loss: 0.0008 | g_total_loss: 4.3279
# Saved image_samples/sample-000900-X-Y.png
# Saved image_samples/sample-000900-Y-X.png
# Epoch [  910/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 0.0011 | g_total_loss: 4.4062
# Epoch [  920/ 5000] | d_X_loss: 0.0003 | d_Y_loss: 0.0021 | g_total_loss: 5.1926
# Epoch [  930/ 5000] | d_X_loss: 0.0004 | d_Y_loss: 0.0024 | g_total_loss: 4.5521
# Epoch [  940/ 5000] | d_X_loss: 0.0003 | d_Y_loss: 0.0069 | g_total_loss: 4.4521
# Epoch [  950/ 5000] | d_X_loss: 0.0012 | d_Y_loss: 0.0008 | g_total_loss: 4.4468
# Epoch [  960/ 5000] | d_X_loss: 0.0003 | d_Y_loss: 0.0186 | g_total_loss: 4.4585
# Epoch [  970/ 5000] | d_X_loss: 0.0005 | d_Y_loss: 0.1188 | g_total_loss: 4.4409
# Epoch [  980/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0014 | g_total_loss: 4.7530
# Epoch [  990/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 0.0039 | g_total_loss: 4.5556
# Epoch [ 1000/ 5000] | d_X_loss: 0.0003 | d_Y_loss: 0.0078 | g_total_loss: 4.7819
# Saved image_samples/sample-001000-X-Y.png
# Saved image_samples/sample-001000-Y-X.png
# Epoch [ 1010/ 5000] | d_X_loss: 0.0003 | d_Y_loss: 0.0040 | g_total_loss: 4.5856
# Epoch [ 1020/ 5000] | d_X_loss: 0.0004 | d_Y_loss: 0.0075 | g_total_loss: 4.3824
# Epoch [ 1030/ 5000] | d_X_loss: 0.0004 | d_Y_loss: 0.0086 | g_total_loss: 4.3782
# Epoch [ 1040/ 5000] | d_X_loss: 0.0010 | d_Y_loss: 0.0043 | g_total_loss: 5.0677
# Epoch [ 1050/ 5000] | d_X_loss: 0.0003 | d_Y_loss: 0.0052 | g_total_loss: 4.3961
# Epoch [ 1060/ 5000] | d_X_loss: 0.0004 | d_Y_loss: 0.0031 | g_total_loss: 4.3398
# Epoch [ 1070/ 5000] | d_X_loss: 0.0004 | d_Y_loss: 0.0027 | g_total_loss: 4.2714
# Epoch [ 1080/ 5000] | d_X_loss: 0.0009 | d_Y_loss: 0.0053 | g_total_loss: 4.3999
# Epoch [ 1090/ 5000] | d_X_loss: 0.0003 | d_Y_loss: 0.0029 | g_total_loss: 4.4830
# Epoch [ 1100/ 5000] | d_X_loss: 0.0003 | d_Y_loss: 0.0029 | g_total_loss: 4.4382
# Saved image_samples/sample-001100-X-Y.png
# Saved image_samples/sample-001100-Y-X.png
# Epoch [ 1110/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0002 | g_total_loss: 4.6008
# Epoch [ 1120/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0001 | g_total_loss: 4.5317
# Epoch [ 1130/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0001 | g_total_loss: 4.4822
# Epoch [ 1140/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0003 | g_total_loss: 4.1600
# Epoch [ 1150/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0021 | g_total_loss: 4.3972
# Epoch [ 1160/ 5000] | d_X_loss: 0.0003 | d_Y_loss: 0.0008 | g_total_loss: 4.6884
# Epoch [ 1170/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 0.0014 | g_total_loss: 4.1741
# Epoch [ 1180/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 0.0003 | g_total_loss: 4.4951
# Epoch [ 1190/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 0.0010 | g_total_loss: 4.2872
# Epoch [ 1200/ 5000] | d_X_loss: 0.0005 | d_Y_loss: 0.0067 | g_total_loss: 4.1723
# Saved image_samples/sample-001200-X-Y.png
# Saved image_samples/sample-001200-Y-X.png
# Epoch [ 1210/ 5000] | d_X_loss: 0.0004 | d_Y_loss: 0.0040 | g_total_loss: 4.1842
# Epoch [ 1220/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 0.0006 | g_total_loss: 4.4186
# Epoch [ 1230/ 5000] | d_X_loss: 0.0005 | d_Y_loss: 0.0042 | g_total_loss: 4.2863
# Epoch [ 1240/ 5000] | d_X_loss: 0.0003 | d_Y_loss: 0.0053 | g_total_loss: 4.2919
# Epoch [ 1250/ 5000] | d_X_loss: 0.0003 | d_Y_loss: 0.0017 | g_total_loss: 4.3833
# Epoch [ 1260/ 5000] | d_X_loss: 0.0007 | d_Y_loss: 0.0034 | g_total_loss: 4.2644
# Epoch [ 1270/ 5000] | d_X_loss: 0.0005 | d_Y_loss: 0.0018 | g_total_loss: 4.2302
# Epoch [ 1280/ 5000] | d_X_loss: 0.0009 | d_Y_loss: 0.0039 | g_total_loss: 4.2686
# Epoch [ 1290/ 5000] | d_X_loss: 0.0008 | d_Y_loss: 0.0054 | g_total_loss: 4.1956
# Epoch [ 1300/ 5000] | d_X_loss: 0.0008 | d_Y_loss: 0.0029 | g_total_loss: 4.2379
# Saved image_samples/sample-001300-X-Y.png
# Saved image_samples/sample-001300-Y-X.png
# Epoch [ 1310/ 5000] | d_X_loss: 0.0003 | d_Y_loss: 0.0001 | g_total_loss: 4.6910
# Epoch [ 1320/ 5000] | d_X_loss: 0.0005 | d_Y_loss: 0.0001 | g_total_loss: 4.1365
# Epoch [ 1330/ 5000] | d_X_loss: 0.0007 | d_Y_loss: 0.0000 | g_total_loss: 4.4212
# Epoch [ 1340/ 5000] | d_X_loss: 0.0019 | d_Y_loss: 0.0000 | g_total_loss: 4.2061
# Epoch [ 1350/ 5000] | d_X_loss: 0.0004 | d_Y_loss: 0.0002 | g_total_loss: 4.4183
# Epoch [ 1360/ 5000] | d_X_loss: 0.0009 | d_Y_loss: 0.0001 | g_total_loss: 4.2424
# Epoch [ 1370/ 5000] | d_X_loss: 0.0011 | d_Y_loss: 0.0000 | g_total_loss: 4.5261
# Epoch [ 1380/ 5000] | d_X_loss: 0.0033 | d_Y_loss: 0.0005 | g_total_loss: 4.0640
# Epoch [ 1390/ 5000] | d_X_loss: 0.0027 | d_Y_loss: 0.0003 | g_total_loss: 4.0816
# Epoch [ 1400/ 5000] | d_X_loss: 0.0007 | d_Y_loss: 0.0006 | g_total_loss: 4.4002
# Saved image_samples/sample-001400-X-Y.png
# Saved image_samples/sample-001400-Y-X.png
# Epoch [ 1410/ 5000] | d_X_loss: 0.0008 | d_Y_loss: 0.0007 | g_total_loss: 4.0860
# Epoch [ 1420/ 5000] | d_X_loss: 0.0004 | d_Y_loss: 0.0002 | g_total_loss: 4.0909
# Epoch [ 1430/ 5000] | d_X_loss: 0.0008 | d_Y_loss: 0.0013 | g_total_loss: 4.4679
# Epoch [ 1440/ 5000] | d_X_loss: 0.0005 | d_Y_loss: 0.0028 | g_total_loss: 4.0068
# Epoch [ 1450/ 5000] | d_X_loss: 0.0005 | d_Y_loss: 0.0001 | g_total_loss: 4.1604
# Epoch [ 1460/ 5000] | d_X_loss: 0.0006 | d_Y_loss: 0.0001 | g_total_loss: 4.0836
# Epoch [ 1470/ 5000] | d_X_loss: 0.0006 | d_Y_loss: 0.0019 | g_total_loss: 4.2328
# Epoch [ 1480/ 5000] | d_X_loss: 0.0010 | d_Y_loss: 0.0007 | g_total_loss: 3.9816
# Epoch [ 1490/ 5000] | d_X_loss: 0.0008 | d_Y_loss: 0.0012 | g_total_loss: 4.1341
# Epoch [ 1500/ 5000] | d_X_loss: 0.0008 | d_Y_loss: 0.0006 | g_total_loss: 4.0126
# Saved image_samples/sample-001500-X-Y.png
# Saved image_samples/sample-001500-Y-X.png
# Epoch [ 1510/ 5000] | d_X_loss: 0.0021 | d_Y_loss: 0.0010 | g_total_loss: 4.1130
# Epoch [ 1520/ 5000] | d_X_loss: 0.0012 | d_Y_loss: 0.0040 | g_total_loss: 4.5428
# Epoch [ 1530/ 5000] | d_X_loss: 0.0011 | d_Y_loss: 0.0008 | g_total_loss: 4.1549
# Epoch [ 1540/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0002 | g_total_loss: 4.1058
# Epoch [ 1550/ 5000] | d_X_loss: 0.0004 | d_Y_loss: 0.0005 | g_total_loss: 3.9557
# Epoch [ 1560/ 5000] | d_X_loss: 0.0003 | d_Y_loss: 0.0030 | g_total_loss: 3.8685
# Epoch [ 1570/ 5000] | d_X_loss: 0.0003 | d_Y_loss: 0.0010 | g_total_loss: 3.8583
# Epoch [ 1580/ 5000] | d_X_loss: 0.0005 | d_Y_loss: 0.0003 | g_total_loss: 3.8301
# Epoch [ 1590/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 0.0124 | g_total_loss: 4.0922
# Epoch [ 1600/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0595 | g_total_loss: 4.3949
# Saved image_samples/sample-001600-X-Y.png
# Saved image_samples/sample-001600-Y-X.png
# Epoch [ 1610/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0007 | g_total_loss: 4.4798
# Epoch [ 1620/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.6360 | g_total_loss: 4.1389
# Epoch [ 1630/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 0.0271 | g_total_loss: 4.0276
# Epoch [ 1640/ 5000] | d_X_loss: 0.0009 | d_Y_loss: 0.0014 | g_total_loss: 4.1850
# Epoch [ 1650/ 5000] | d_X_loss: 0.0012 | d_Y_loss: 0.0035 | g_total_loss: 3.8347
# Epoch [ 1660/ 5000] | d_X_loss: 0.0005 | d_Y_loss: 0.0095 | g_total_loss: 4.0223
# Epoch [ 1670/ 5000] | d_X_loss: 0.0010 | d_Y_loss: 0.0004 | g_total_loss: 4.2472
# Epoch [ 1680/ 5000] | d_X_loss: 0.0005 | d_Y_loss: 0.0016 | g_total_loss: 4.1852
# Epoch [ 1690/ 5000] | d_X_loss: 0.0007 | d_Y_loss: 0.0038 | g_total_loss: 3.8837
# Epoch [ 1700/ 5000] | d_X_loss: 0.0009 | d_Y_loss: 0.0006 | g_total_loss: 4.5990
# Saved image_samples/sample-001700-X-Y.png
# Saved image_samples/sample-001700-Y-X.png
# Epoch [ 1710/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0014 | g_total_loss: 3.8879
# Epoch [ 1720/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0010 | g_total_loss: 3.9584
# Epoch [ 1730/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0007 | g_total_loss: 4.4208
# Epoch [ 1740/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0032 | g_total_loss: 3.9335
# Epoch [ 1750/ 5000] | d_X_loss: 0.0003 | d_Y_loss: 0.0010 | g_total_loss: 4.1673
# Epoch [ 1760/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0007 | g_total_loss: 4.8332
# Epoch [ 1770/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 4.0202
# Epoch [ 1780/ 5000] | d_X_loss: 0.0003 | d_Y_loss: 0.0000 | g_total_loss: 3.8808
# Epoch [ 1790/ 5000] | d_X_loss: 0.0006 | d_Y_loss: 0.0000 | g_total_loss: 3.8851
# Epoch [ 1800/ 5000] | d_X_loss: 0.0006 | d_Y_loss: 0.0000 | g_total_loss: 3.7128
# Saved image_samples/sample-001800-X-Y.png
# Saved image_samples/sample-001800-Y-X.png
# Epoch [ 1810/ 5000] | d_X_loss: 0.0004 | d_Y_loss: 0.0000 | g_total_loss: 4.3434
# Epoch [ 1820/ 5000] | d_X_loss: 0.0003 | d_Y_loss: 0.0001 | g_total_loss: 3.9417
# Epoch [ 1830/ 5000] | d_X_loss: 0.0007 | d_Y_loss: 0.0000 | g_total_loss: 3.7810
# Epoch [ 1840/ 5000] | d_X_loss: 0.0041 | d_Y_loss: 0.0000 | g_total_loss: 3.9695
# Epoch [ 1850/ 5000] | d_X_loss: 0.0051 | d_Y_loss: 0.0000 | g_total_loss: 3.9304
# Epoch [ 1860/ 5000] | d_X_loss: 0.9297 | d_Y_loss: 0.0000 | g_total_loss: 3.3360
# Epoch [ 1870/ 5000] | d_X_loss: 0.8232 | d_Y_loss: 0.0001 | g_total_loss: 3.2303
# Epoch [ 1880/ 5000] | d_X_loss: 0.7907 | d_Y_loss: 0.0001 | g_total_loss: 3.7603
# Epoch [ 1890/ 5000] | d_X_loss: 0.4659 | d_Y_loss: 0.0000 | g_total_loss: 3.0545
# Epoch [ 1900/ 5000] | d_X_loss: 0.4705 | d_Y_loss: 0.0000 | g_total_loss: 3.5253
# Saved image_samples/sample-001900-X-Y.png
# Saved image_samples/sample-001900-Y-X.png
# Epoch [ 1910/ 5000] | d_X_loss: 0.3494 | d_Y_loss: 0.0000 | g_total_loss: 3.8716
# Epoch [ 1920/ 5000] | d_X_loss: 0.4186 | d_Y_loss: 0.0001 | g_total_loss: 3.5315
# Epoch [ 1930/ 5000] | d_X_loss: 0.2396 | d_Y_loss: 0.0003 | g_total_loss: 3.5449
# Epoch [ 1940/ 5000] | d_X_loss: 0.1391 | d_Y_loss: 0.0001 | g_total_loss: 4.5279
# Epoch [ 1950/ 5000] | d_X_loss: 0.0981 | d_Y_loss: 0.0003 | g_total_loss: 3.6323
# Epoch [ 1960/ 5000] | d_X_loss: 0.0567 | d_Y_loss: 0.0001 | g_total_loss: 3.9284
# Epoch [ 1970/ 5000] | d_X_loss: 0.1408 | d_Y_loss: 0.0001 | g_total_loss: 4.0906
# Epoch [ 1980/ 5000] | d_X_loss: 0.0278 | d_Y_loss: 0.0000 | g_total_loss: 3.9032
# Epoch [ 1990/ 5000] | d_X_loss: 0.0086 | d_Y_loss: 0.0000 | g_total_loss: 4.8421
# Epoch [ 2000/ 5000] | d_X_loss: 0.0026 | d_Y_loss: 0.0001 | g_total_loss: 5.0984
# Saved image_samples/sample-002000-X-Y.png
# Saved image_samples/sample-002000-Y-X.png
# Epoch [ 2010/ 5000] | d_X_loss: 0.0072 | d_Y_loss: 0.0000 | g_total_loss: 4.0205
# Epoch [ 2020/ 5000] | d_X_loss: 0.0006 | d_Y_loss: 0.0000 | g_total_loss: 4.1618
# Epoch [ 2030/ 5000] | d_X_loss: 0.0019 | d_Y_loss: 0.0001 | g_total_loss: 4.8048
# Epoch [ 2040/ 5000] | d_X_loss: 0.0008 | d_Y_loss: 0.0000 | g_total_loss: 3.7133
# Epoch [ 2050/ 5000] | d_X_loss: 0.0013 | d_Y_loss: 0.0000 | g_total_loss: 3.7538
# Epoch [ 2060/ 5000] | d_X_loss: 0.0017 | d_Y_loss: 0.0000 | g_total_loss: 4.2144
# Epoch [ 2070/ 5000] | d_X_loss: 0.0027 | d_Y_loss: 0.0000 | g_total_loss: 3.8251
# Epoch [ 2080/ 5000] | d_X_loss: 0.0004 | d_Y_loss: 0.0000 | g_total_loss: 4.0818
# Epoch [ 2090/ 5000] | d_X_loss: 0.0005 | d_Y_loss: 0.0000 | g_total_loss: 3.9722
# Epoch [ 2100/ 5000] | d_X_loss: 0.0003 | d_Y_loss: 0.0000 | g_total_loss: 3.7340
# Saved image_samples/sample-002100-X-Y.png
# Saved image_samples/sample-002100-Y-X.png
# Epoch [ 2110/ 5000] | d_X_loss: 0.0004 | d_Y_loss: 0.0000 | g_total_loss: 4.1640
# Epoch [ 2120/ 5000] | d_X_loss: 0.0004 | d_Y_loss: 0.0000 | g_total_loss: 3.9211
# Epoch [ 2130/ 5000] | d_X_loss: 0.0006 | d_Y_loss: 0.0000 | g_total_loss: 3.7840
# Epoch [ 2140/ 5000] | d_X_loss: 0.0005 | d_Y_loss: 0.0000 | g_total_loss: 3.6826
# Epoch [ 2150/ 5000] | d_X_loss: 0.0022 | d_Y_loss: 0.0000 | g_total_loss: 3.8075
# Epoch [ 2160/ 5000] | d_X_loss: 0.0018 | d_Y_loss: 0.0000 | g_total_loss: 3.6711
# Epoch [ 2170/ 5000] | d_X_loss: 0.0053 | d_Y_loss: 0.0000 | g_total_loss: 3.8155
# Epoch [ 2180/ 5000] | d_X_loss: 0.0021 | d_Y_loss: 0.0000 | g_total_loss: 4.0331
# Epoch [ 2190/ 5000] | d_X_loss: 0.0059 | d_Y_loss: 0.0000 | g_total_loss: 3.9638
# Epoch [ 2200/ 5000] | d_X_loss: 0.0083 | d_Y_loss: 0.0000 | g_total_loss: 3.6441
# Saved image_samples/sample-002200-X-Y.png
# Saved image_samples/sample-002200-Y-X.png
# Epoch [ 2210/ 5000] | d_X_loss: 0.0061 | d_Y_loss: 0.0000 | g_total_loss: 4.2753
# Epoch [ 2220/ 5000] | d_X_loss: 0.0039 | d_Y_loss: 0.0000 | g_total_loss: 3.6488
# Epoch [ 2230/ 5000] | d_X_loss: 0.0063 | d_Y_loss: 0.0000 | g_total_loss: 3.6250
# Epoch [ 2240/ 5000] | d_X_loss: 0.0075 | d_Y_loss: 0.0000 | g_total_loss: 3.7935
# Epoch [ 2250/ 5000] | d_X_loss: 0.0082 | d_Y_loss: 0.0000 | g_total_loss: 3.6082
# Epoch [ 2260/ 5000] | d_X_loss: 0.0042 | d_Y_loss: 0.0000 | g_total_loss: 3.6127
# Epoch [ 2270/ 5000] | d_X_loss: 0.0521 | d_Y_loss: 0.0000 | g_total_loss: 3.7804
# Epoch [ 2280/ 5000] | d_X_loss: 0.0835 | d_Y_loss: 0.0000 | g_total_loss: 3.5625
# Epoch [ 2290/ 5000] | d_X_loss: 0.1009 | d_Y_loss: 0.0000 | g_total_loss: 3.6024
# Epoch [ 2300/ 5000] | d_X_loss: 0.0313 | d_Y_loss: 0.0001 | g_total_loss: 4.0622
# Saved image_samples/sample-002300-X-Y.png
# Saved image_samples/sample-002300-Y-X.png
# Epoch [ 2310/ 5000] | d_X_loss: 0.0052 | d_Y_loss: 0.0000 | g_total_loss: 3.8560
# Epoch [ 2320/ 5000] | d_X_loss: 0.0029 | d_Y_loss: 0.0000 | g_total_loss: 3.8048
# Epoch [ 2330/ 5000] | d_X_loss: 0.0104 | d_Y_loss: 0.0000 | g_total_loss: 4.2926
# Epoch [ 2340/ 5000] | d_X_loss: 0.0041 | d_Y_loss: 0.0000 | g_total_loss: 3.8072
# Epoch [ 2350/ 5000] | d_X_loss: 0.0054 | d_Y_loss: 0.0000 | g_total_loss: 3.5943
# Epoch [ 2360/ 5000] | d_X_loss: 0.0078 | d_Y_loss: 0.0000 | g_total_loss: 3.4407
# Epoch [ 2370/ 5000] | d_X_loss: 0.0036 | d_Y_loss: 0.0001 | g_total_loss: 3.7982
# Epoch [ 2380/ 5000] | d_X_loss: 0.0069 | d_Y_loss: 0.0000 | g_total_loss: 3.5606
# Epoch [ 2390/ 5000] | d_X_loss: 0.0014 | d_Y_loss: 0.0000 | g_total_loss: 3.7194
# Epoch [ 2400/ 5000] | d_X_loss: 0.0028 | d_Y_loss: 0.0000 | g_total_loss: 3.5243
# Saved image_samples/sample-002400-X-Y.png
# Saved image_samples/sample-002400-Y-X.png
# Epoch [ 2410/ 5000] | d_X_loss: 0.0050 | d_Y_loss: 0.0000 | g_total_loss: 3.5428
# Epoch [ 2420/ 5000] | d_X_loss: 0.0030 | d_Y_loss: 0.0000 | g_total_loss: 3.8989
# Epoch [ 2430/ 5000] | d_X_loss: 0.0027 | d_Y_loss: 0.0000 | g_total_loss: 3.6222
# Epoch [ 2440/ 5000] | d_X_loss: 0.0018 | d_Y_loss: 0.0000 | g_total_loss: 3.5455
# Epoch [ 2450/ 5000] | d_X_loss: 0.0036 | d_Y_loss: 0.0000 | g_total_loss: 3.7177
# Epoch [ 2460/ 5000] | d_X_loss: 0.0075 | d_Y_loss: 0.0000 | g_total_loss: 3.5602
# Epoch [ 2470/ 5000] | d_X_loss: 0.0009 | d_Y_loss: 0.0000 | g_total_loss: 3.5837
# Epoch [ 2480/ 5000] | d_X_loss: 0.0008 | d_Y_loss: 0.0000 | g_total_loss: 3.5913
# Epoch [ 2490/ 5000] | d_X_loss: 0.0031 | d_Y_loss: 0.0000 | g_total_loss: 3.5227
# Epoch [ 2500/ 5000] | d_X_loss: 0.0011 | d_Y_loss: 0.0000 | g_total_loss: 3.8980
# Saved image_samples/sample-002500-X-Y.png
# Saved image_samples/sample-002500-Y-X.png
# Epoch [ 2510/ 5000] | d_X_loss: 0.0008 | d_Y_loss: 0.0001 | g_total_loss: 5.3948
# Epoch [ 2520/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 4.5735
# Epoch [ 2530/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.9732
# Epoch [ 2540/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 4.4147
# Epoch [ 2550/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.9477
# Epoch [ 2560/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.7655
# Epoch [ 2570/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 4.0690
# Epoch [ 2580/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.7506
# Epoch [ 2590/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.4860
# Epoch [ 2600/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.6285
# Saved image_samples/sample-002600-X-Y.png
# Saved image_samples/sample-002600-Y-X.png
# Epoch [ 2610/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.7350
# Epoch [ 2620/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.5132
# Epoch [ 2630/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.6413
# Epoch [ 2640/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.4565
# Epoch [ 2650/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.5544
# Epoch [ 2660/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.6256
# Epoch [ 2670/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.5476
# Epoch [ 2680/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.8486
# Epoch [ 2690/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.7609
# Epoch [ 2700/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.4793
# Saved image_samples/sample-002700-X-Y.png
# Saved image_samples/sample-002700-Y-X.png
# Epoch [ 2710/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.6574
# Epoch [ 2720/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.8139
# Epoch [ 2730/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.4219
# Epoch [ 2740/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.5190
# Epoch [ 2750/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.7740
# Epoch [ 2760/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.4603
# Epoch [ 2770/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.4914
# Epoch [ 2780/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 4.0522
# Epoch [ 2790/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.4618
# Epoch [ 2800/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.4095
# Saved image_samples/sample-002800-X-Y.png
# Saved image_samples/sample-002800-Y-X.png
# Epoch [ 2810/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.6871
# Epoch [ 2820/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.4733
# Epoch [ 2830/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.4259
# Epoch [ 2840/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.5885
# Epoch [ 2850/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.4481
# Epoch [ 2860/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.4802
# Epoch [ 2870/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.4786
# Epoch [ 2880/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.5674
# Epoch [ 2890/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.3658
# Epoch [ 2900/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.8538
# Saved image_samples/sample-002900-X-Y.png
# Saved image_samples/sample-002900-Y-X.png
# Epoch [ 2910/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.4678
# Epoch [ 2920/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.3831
# Epoch [ 2930/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.2809
# Epoch [ 2940/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.3086
# Epoch [ 2950/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.5272
# Epoch [ 2960/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.5279
# Epoch [ 2970/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.4077
# Epoch [ 2980/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.4229
# Epoch [ 2990/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.9779
# Epoch [ 3000/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.4335
# Saved image_samples/sample-003000-X-Y.png
# Saved image_samples/sample-003000-Y-X.png
# Epoch [ 3010/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.3988
# Epoch [ 3020/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.4447
# Epoch [ 3030/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.3033
# Epoch [ 3040/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.3359
# Epoch [ 3050/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.3371
# Epoch [ 3060/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.2609
# Epoch [ 3070/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.3351
# Epoch [ 3080/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.2524
# Epoch [ 3090/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.3884
# Epoch [ 3100/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.3886
# Saved image_samples/sample-003100-X-Y.png
# Saved image_samples/sample-003100-Y-X.png
# Epoch [ 3110/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.4268
# Epoch [ 3120/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.3868
# Epoch [ 3130/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.3383
# Epoch [ 3140/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.3977
# Epoch [ 3150/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.4020
# Epoch [ 3160/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 0.0000 | g_total_loss: 3.3081
# Epoch [ 3170/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.7407
# Epoch [ 3180/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.2821
# Epoch [ 3190/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.4355
# Epoch [ 3200/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.4540
# Saved image_samples/sample-003200-X-Y.png
# Saved image_samples/sample-003200-Y-X.png
# Epoch [ 3210/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.1965
# Epoch [ 3220/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.4303
# Epoch [ 3230/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.6006
# Epoch [ 3240/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.3458
# Epoch [ 3250/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.3798
# Epoch [ 3260/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 0.0000 | g_total_loss: 3.3299
# Epoch [ 3270/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.2731
# Epoch [ 3280/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.3630
# Epoch [ 3290/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.4344
# Epoch [ 3300/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.2393
# Saved image_samples/sample-003300-X-Y.png
# Saved image_samples/sample-003300-Y-X.png
# Epoch [ 3310/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.3087
# Epoch [ 3320/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.5606
# Epoch [ 3330/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.2045
# Epoch [ 3340/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.3140
# Epoch [ 3350/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 0.0000 | g_total_loss: 3.3617
# Epoch [ 3360/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.3776
# Epoch [ 3370/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.2374
# Epoch [ 3380/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.4749
# Epoch [ 3390/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.1682
# Epoch [ 3400/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.2086
# Saved image_samples/sample-003400-X-Y.png
# Saved image_samples/sample-003400-Y-X.png
# Epoch [ 3410/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.4354
# Epoch [ 3420/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.3591
# Epoch [ 3430/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.1778
# Epoch [ 3440/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.5267
# Epoch [ 3450/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.2489
# Epoch [ 3460/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.3668
# Epoch [ 3470/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.3026
# Epoch [ 3480/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.3156
# Epoch [ 3490/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.4280
# Epoch [ 3500/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.6243
# Saved image_samples/sample-003500-X-Y.png
# Saved image_samples/sample-003500-Y-X.png
# Epoch [ 3510/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.3648
# Epoch [ 3520/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.3467
# Epoch [ 3530/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.4101
# Epoch [ 3540/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.2415
# Epoch [ 3550/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.3620
# Epoch [ 3560/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.3619
# Epoch [ 3570/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.3867
# Epoch [ 3580/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.2129
# Epoch [ 3590/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.3634
# Epoch [ 3600/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.2027
# Saved image_samples/sample-003600-X-Y.png
# Saved image_samples/sample-003600-Y-X.png
# Epoch [ 3610/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.3485
# Epoch [ 3620/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.3829
# Epoch [ 3630/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.2081
# Epoch [ 3640/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.2153
# Epoch [ 3650/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 0.0000 | g_total_loss: 3.4190
# Epoch [ 3660/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.4039
# Epoch [ 3670/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.2892
# Epoch [ 3680/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 5.2411
# Epoch [ 3690/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 4.7564
# Epoch [ 3700/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 4.1060
# Saved image_samples/sample-003700-X-Y.png
# Saved image_samples/sample-003700-Y-X.png
# Epoch [ 3710/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.8757
# Epoch [ 3720/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.8082
# Epoch [ 3730/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.6287
# Epoch [ 3740/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.7070
# Epoch [ 3750/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.5442
# Epoch [ 3760/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.4926
# Epoch [ 3770/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.6101
# Epoch [ 3780/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.5313
# Epoch [ 3790/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.1527
# Epoch [ 3800/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.5354
# Saved image_samples/sample-003800-X-Y.png
# Saved image_samples/sample-003800-Y-X.png
# Epoch [ 3810/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.2594
# Epoch [ 3820/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.3171
# Epoch [ 3830/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.2635
# Epoch [ 3840/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 4.2178
# Epoch [ 3850/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.6453
# Epoch [ 3860/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.5812
# Epoch [ 3870/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.3071
# Epoch [ 3880/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.3816
# Epoch [ 3890/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.6548
# Epoch [ 3900/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.1582
# Saved image_samples/sample-003900-X-Y.png
# Saved image_samples/sample-003900-Y-X.png
# Epoch [ 3910/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.3744
# Epoch [ 3920/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.3569
# Epoch [ 3930/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.2806
# Epoch [ 3940/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.4063
# Epoch [ 3950/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.1897
# Epoch [ 3960/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.2395
# Epoch [ 3970/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.3553
# Epoch [ 3980/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.3790
# Epoch [ 3990/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.2053
# Epoch [ 4000/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.1725
# Saved image_samples/sample-004000-X-Y.png
# Saved image_samples/sample-004000-Y-X.png
# Epoch [ 4010/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.2437
# Epoch [ 4020/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.1327
# Epoch [ 4030/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.2177
# Epoch [ 4040/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.3493
# Epoch [ 4050/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.2265
# Epoch [ 4060/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.2185
# Epoch [ 4070/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.5587
# Epoch [ 4080/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.1628
# Epoch [ 4090/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.1263
# Epoch [ 4100/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.3994
# Saved image_samples/sample-004100-X-Y.png
# Saved image_samples/sample-004100-Y-X.png
# Epoch [ 4110/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.2607
# Epoch [ 4120/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.0916
# Epoch [ 4130/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.3960
# Epoch [ 4140/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.1251
# Epoch [ 4150/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.1817
# Epoch [ 4160/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.2905
# Epoch [ 4170/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.2103
# Epoch [ 4180/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.1519
# Epoch [ 4190/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.1335
# Epoch [ 4200/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.1040
# Saved image_samples/sample-004200-X-Y.png
# Saved image_samples/sample-004200-Y-X.png
# Epoch [ 4210/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.0815
# Epoch [ 4220/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.3479
# Epoch [ 4230/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.2103
# Epoch [ 4240/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.2079
# Epoch [ 4250/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.5259
# Epoch [ 4260/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.0934
# Epoch [ 4270/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.0861
# Epoch [ 4280/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.2766
# Epoch [ 4290/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.1380
# Epoch [ 4300/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.1269
# Saved image_samples/sample-004300-X-Y.png
# Saved image_samples/sample-004300-Y-X.png
# Epoch [ 4310/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.2694
# Epoch [ 4320/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.0205
# Epoch [ 4330/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.1022
# Epoch [ 4340/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.3439
# Epoch [ 4350/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.1541
# Epoch [ 4360/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.0651
# Epoch [ 4370/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.0682
# Epoch [ 4380/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.0934
# Epoch [ 4390/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.2287
# Epoch [ 4400/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.1203
# Saved image_samples/sample-004400-X-Y.png
# Saved image_samples/sample-004400-Y-X.png
# Epoch [ 4410/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.1474
# Epoch [ 4420/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.1024
# Epoch [ 4430/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.1941
# Epoch [ 4440/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.0585
# Epoch [ 4450/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.0635
# Epoch [ 4460/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.1353
# Epoch [ 4470/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 2.9896
# Epoch [ 4480/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.0907
# Epoch [ 4490/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.2965
# Epoch [ 4500/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 2.9979
# Saved image_samples/sample-004500-X-Y.png
# Saved image_samples/sample-004500-Y-X.png
# Epoch [ 4510/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.0480
# Epoch [ 4520/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.3564
# Epoch [ 4530/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.1022
# Epoch [ 4540/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.1062
# Epoch [ 4550/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.3290
# Epoch [ 4560/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.0559
# Epoch [ 4570/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 2.9911
# Epoch [ 4580/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.2645
# Epoch [ 4590/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.0876
# Epoch [ 4600/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 2.9704
# Saved image_samples/sample-004600-X-Y.png
# Saved image_samples/sample-004600-Y-X.png
# Epoch [ 4610/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.1485
# Epoch [ 4620/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.0170
# Epoch [ 4630/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.0478
# Epoch [ 4640/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.1294
# Epoch [ 4650/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.1357
# Epoch [ 4660/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 2.9758
# Epoch [ 4670/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.0492
# Epoch [ 4680/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.0394
# Epoch [ 4690/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.0241
# Epoch [ 4700/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 2.9792
# Saved image_samples/sample-004700-X-Y.png
# Saved image_samples/sample-004700-Y-X.png
# Epoch [ 4710/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.0222
# Epoch [ 4720/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.0175
# Epoch [ 4730/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.0703
# Epoch [ 4740/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 2.9634
# Epoch [ 4750/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.0153
# Epoch [ 4760/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.2301
# Epoch [ 4770/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.0169
# Epoch [ 4780/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 2.9311
# Epoch [ 4790/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.0644
# Epoch [ 4800/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.0036
# Saved image_samples/sample-004800-X-Y.png
# Saved image_samples/sample-004800-Y-X.png
# Epoch [ 4810/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.0200
# Epoch [ 4820/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.1975
# Epoch [ 4830/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.0567
# Epoch [ 4840/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.2080
# Epoch [ 4850/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.3577
# Epoch [ 4860/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.0376
# Epoch [ 4870/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.0713
# Epoch [ 4880/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.0846
# Epoch [ 4890/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.1236
# Epoch [ 4900/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 2.9608
# Saved image_samples/sample-004900-X-Y.png
# Saved image_samples/sample-004900-Y-X.png
# Epoch [ 4910/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.1168
# Epoch [ 4920/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.1618
# Epoch [ 4930/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 2.9575
# Epoch [ 4940/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.1549
# Epoch [ 4950/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.0135
# Epoch [ 4960/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.0483
# Epoch [ 4970/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.1957
# Epoch [ 4980/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.0247
# Epoch [ 4990/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 2.9611
# Epoch [ 5000/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 2.9283
# Saved image_samples/sample-005000-X-Y.png
# Saved image_samples/sample-005000-Y-X.png

# %% [markdown]
# #### Training and Loss Patterns

# %%
fig, ax = plt.subplots(figsize=(12,8))
losses = np.array(losses)
plt.plot(losses.T[0], label='Discriminator, X', alpha=0.5)
plt.plot(losses.T[1], label='Discriminator, Y', alpha=0.5)
plt.plot(losses.T[2], label='Generators', alpha=0.5)
plt.title("Training Losses")
plt.legend()

# %% [markdown]
# ### Results

# %%
import matplotlib.image as mpimg

# %%
def view_samples(iteration, sample_dir='/content/image_samples'):
    # samples are named by iteration
    path_XtoY = os.path.join(sample_dir, 'sample-{:06d}-X-Y.png'.format(iteration))
    path_YtoX = os.path.join(sample_dir, 'sample-{:06d}-Y-X.png'.format(iteration))

    # read in those samples
    x2y, y2x = None, None
    try:
        x2y = mpimg.imread(path_XtoY)
        y2x = mpimg.imread(path_YtoX)
    except:
        print('Invalid number of iterations.')

    fig, (ax1, ax2) = plt.subplots(figsize=(18,20), nrows=2, ncols=1, sharey=True, sharex=True)
    ax1.imshow(x2y)
    ax1.set_title('X to Y')
    ax2.imshow(y2x)
    ax2.set_title('Y to X')

# %%
# view samples at iteration 100
view_samples(100)

# %%
# view samples at iteration 5000
view_samples(5000)
