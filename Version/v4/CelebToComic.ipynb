# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import matplotlib.pyplot as plt
import warnings
import os

# %%
import torch
from torch.utils.data import DataLoader
import torchvision
import torchvision.datasets as datasets
import torchvision.transforms as transforms
import torch.nn.functional as F
from torch import nn, optim

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = "retina"

# %% [markdown]
# ### Loading Data

# %%
from PIL import Image

def get_data_loader(image_type, image_dir='/content/drive/MyDrive/ColabNotebooks/DataSet/celeb2comic', image_size=128, batch_size=16, num_workers=0):
    """returns: training and test data loaders for a given image type, either summer or winter"""

    # Resize and normalize the images
    transform = transforms.Compose([
        transforms.Resize((image_size, image_size), interpolation=Image.BICUBIC),  # Resize images to have dimensions (image_size, image_size)
        transforms.ToTensor()  # Convert images to PyTorch tensors
    ])

    # Get training and test directories
    train_path = os.path.join(image_dir, image_type)
    test_path = os.path.join(image_dir, 'test_{}'.format(image_type))

    # Define datasets using ImageFolder
    train_dataset = datasets.ImageFolder(train_path, transform)
    test_dataset = datasets.ImageFolder(test_path, transform)

    # Create and return DataLoaders
    train_loader = DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True, num_workers=num_workers)
    test_loader = DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=False, num_workers=num_workers)

    # Retrieve a sample image from the training dataset for visualization
    sample_image, _ = train_dataset[2]


    # Visualize the sample image

    # Display the raw image and transformed image side by side
    plt.figure(figsize=(12, 8))

    plt.subplot(1, 5, 2)
    plt.imshow(sample_image.permute(1, 2, 0))
    plt.title('Original Image')
    plt.axis('off')

    # Display the transformed image
    plt.subplot(1, 5, 4)
    np_image = sample_image.numpy().transpose((1, 2, 0))
    plt.imshow(np_image)
    plt.title('Transformed Image')
    plt.axis('off')

    plt.show()

    return train_loader, test_loader

# %% [markdown]
# ####Resize and Normalize Output Check

# %%
dataloader_X, test_dataloader_X = get_data_loader(image_type='celeb')
dataloader_Y, test_dataloader_Y = get_data_loader(image_type='comic')

# %%
# display sample images
def imshow(img):
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))

# %%
import torch
import torchvision
import matplotlib.pyplot as plt

# Assuming dataloader_X is your DataLoader
dataiter = iter(dataloader_X)
images, _ = next(dataiter)  # Use next() directly to get the next batch

# Visualize the batch of images
fig = plt.figure(figsize=(12, 8))
imshow(torchvision.utils.make_grid(images))
plt.show()

# %%
import torch
import torchvision
import matplotlib.pyplot as plt

# Assuming dataloader_Y is your DataLoader
dataiter = iter(dataloader_Y)

# Get the first batch from the dataloader
for images, _ in dataiter:
    break

# Visualize the batch of images
fig = plt.figure(figsize=(12, 8))
imshow(torchvision.utils.make_grid(images))
plt.show()

# %% [markdown]
# ### Building the Model

# %%
img = images[4]
print('min: ', img.min())
print('max: ', img.max())
# Out:
# min:  tensor(0.)
# max:  tensor(0.9686)

# %% [markdown]
# #### Discriminator

# %%
# Define a helper function for creating convolutional layers
def conv(in_channels, out_channels, kernel_size=4, stride=2, padding=1, batch_norm=True):
    layers = []
    conv_layer = nn.Conv2d(in_channels, out_channels, kernel_size, stride, padding, bias=False)
    layers.append(conv_layer)
    if batch_norm:
        layers.append(nn.BatchNorm2d(out_channels))
    return nn.Sequential(*layers)

# %%
# Discriminator Class
class Discriminator(nn.Module):
    def __init__(self, conv_dim=64):
        super(Discriminator, self).__init__()
        # Define all convolutional layers
        self.conv1 = conv(3, conv_dim, 4, stride=2, padding=1, batch_norm=False)  # 64x64x64
        self.conv2 = conv(conv_dim, conv_dim * 2, 4, stride=2, padding=1)  # 32x32x128
        self.conv3 = conv(conv_dim * 2, conv_dim * 4, 4, stride=2, padding=1)  # 16x16x256
        self.conv4 = conv(conv_dim * 4, conv_dim * 8, 4, stride=2, padding=1)  # 8x8x512
        # Final layer
        self.conv5 = nn.Conv2d(conv_dim * 8, 1, 4, stride=1, padding=0, bias=False)  # 1x1x1

    def forward(self, x):
        out = nn.ReLU()(self.conv1(x))
        out = nn.ReLU()(self.conv2(out))
        out = nn.ReLU()(self.conv3(out))
        out = nn.ReLU()(self.conv4(out))
        out = self.conv5(out)
        out = torch.sigmoid(out)  # Add sigmoid for output
        return out.view(-1)  # Flatten to 1D for output

# %%
# Residual block definition
class ResidualBlock(nn.Module):
    def __init__(self, dim):
        super(ResidualBlock, self).__init__()
        self.conv1 = conv(dim, dim, kernel_size=3, stride=1, padding=1)
        self.conv2 = conv(dim, dim, kernel_size=3, stride=1, padding=1, batch_norm=False)

    def forward(self, x):
        residual = x
        x = nn.ReLU()(self.conv1(x))
        x = self.conv2(x)
        return x + residual  # Adding residual for skip connection

# %%
def deconv(in_channels, out_channels, kernel_size=4, stride=2, padding=1, batch_norm=True):
    layers = []
    deconv_layer = nn.ConvTranspose2d(in_channels, out_channels, kernel_size, stride, padding, bias=False)
    layers.append(deconv_layer)
    if batch_norm:
        layers.append(nn.BatchNorm2d(out_channels))
    return nn.Sequential(*layers)

# %% [markdown]
# #### CycleGenerator

# %%
# CycleGenerator Class
class CycleGenerator(nn.Module):
    def __init__(self, conv_dim=64, n_res_blocks=6):
        super(CycleGenerator, self).__init__()
        # 1. Encoder
        self.conv1 = conv(3, conv_dim, 4, stride=2, padding=1)  # 128x128 -> 64x64
        self.conv2 = conv(conv_dim, conv_dim * 2, 4, stride=2, padding=1)  # 64x64 -> 32x32
        self.conv3 = conv(conv_dim * 2, conv_dim * 4, 4, stride=2, padding=1)  # 32x32 -> 16x16

        # 2. Residual blocks
        res_layers = []
        for _ in range(n_res_blocks):
            res_layers.append(ResidualBlock(conv_dim * 4))
        self.res_blocks = nn.Sequential(*res_layers)

        # 3. Decoder
        self.deconv1 = deconv(conv_dim * 4, conv_dim * 2, 4, stride=2, padding=1)  # 16x16 -> 32x32
        self.deconv2 = deconv(conv_dim * 2, conv_dim, 4, stride=2, padding=1)  # 32x32 -> 64x64
        self.deconv3 = deconv(conv_dim, 3, 4, stride=2, padding=1, batch_norm=False)  # 64x64 -> 128x128

    def forward(self, x):
        """Transforms an image and returns it."""
        out = nn.ReLU()(self.conv1(x))
        out = nn.ReLU()(self.conv2(out))
        out = nn.ReLU()(self.conv3(out))
        out = self.res_blocks(out)
        out = nn.ReLU()(self.deconv1(out))
        out = nn.ReLU()(self.deconv2(out))
        # Apply tanh activation to the final output
        out = nn.Tanh()(self.deconv3(out))
        return out

# %% [markdown]
# ### Complete Network

# %%
# Assuming CycleGenerator and Discriminator are defined elsewhere

def create_model(
    g_conv_dim=64,
    d_conv_dim=64,
    n_res_blocks=6,
    device=None
):
    """Builds and initializes generators and discriminators for CycleGAN."""
    # Assign the device if not provided
    if device is None:
        device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

    # Instantiate generators
    G_XtoY = CycleGenerator(conv_dim=g_conv_dim, n_res_blocks=n_res_blocks).to(device)
    G_YtoX = CycleGenerator(conv_dim=g_conv_dim, n_res_blocks=n_res_blocks).to(device)

    # Instantiate discriminators
    D_X = Discriminator(conv_dim=d_conv_dim).to(device)
    D_Y = Discriminator(conv_dim=d_conv_dim).to(device)

    # Log the device information
    if device.type == "cuda":
        print(f"Models moved to GPU: {torch.cuda.get_device_name(device)}.")
    else:
        print("Models using CPU.")

    # Return the initialized models
    return G_XtoY, G_YtoX, D_X, D_Y

# %%
G_XtoY, G_YtoX, D_X, D_Y = create_model()
# Out:
# Models moved to GPU: Tesla T4.

# %%
def print_models(G_XtoY, G_YtoX, D_X, D_Y):
    """Prints model information for the generators and discriminators.
    """
    print("                     G_XtoY                    ")
    print("-----------------------------------------------")
    print(G_XtoY)
    print()

    print("                     G_YtoX                    ")
    print("-----------------------------------------------")
    print(G_YtoX)
    print()

    print("                      D_X                      ")
    print("-----------------------------------------------")
    print(D_X)
    print()

    print("                      D_Y                      ")
    print("-----------------------------------------------")
    print(D_Y)
    print()


# print all of the models
print_models(G_XtoY, G_YtoX, D_X, D_Y)
# Out:
#                      G_XtoY
# -----------------------------------------------
# CycleGenerator(
#   (conv1): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv3): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (res_blocks): Sequential(
#     (0): ResidualBlock(
#       (conv1): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (1): ResidualBlock(
#       (conv1): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (2): ResidualBlock(
#       (conv1): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (3): ResidualBlock(
#       (conv1): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (4): ResidualBlock(
#       (conv1): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (5): ResidualBlock(
#       (conv1): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#   )
#   (deconv1): Sequential(
#     (0): ConvTranspose2d(256, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (deconv2): Sequential(
#     (0): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (deconv3): Sequential(
#     (0): ConvTranspose2d(64, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   )
# )
#
#                      G_YtoX
# -----------------------------------------------
# CycleGenerator(
#   (conv1): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv3): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (res_blocks): Sequential(
#     (0): ResidualBlock(
#       (conv1): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (1): ResidualBlock(
#       (conv1): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (2): ResidualBlock(
#       (conv1): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (3): ResidualBlock(
#       (conv1): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (4): ResidualBlock(
#       (conv1): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (5): ResidualBlock(
#       (conv1): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#   )
#   (deconv1): Sequential(
#     (0): ConvTranspose2d(256, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (deconv2): Sequential(
#     (0): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (deconv3): Sequential(
#     (0): ConvTranspose2d(64, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   )
# )
#
#                       D_X
# -----------------------------------------------
# Discriminator(
#   (conv1): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv3): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv4): Sequential(
#     (0): Conv2d(256, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv5): Conv2d(512, 1, kernel_size=(4, 4), stride=(1, 1), bias=False)
# )
#
#                       D_Y
# -----------------------------------------------
# Discriminator(
#   (conv1): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv3): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv4): Sequential(
#     (0): Conv2d(256, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv5): Conv2d(512, 1, kernel_size=(4, 4), stride=(1, 1), bias=False)
# )

# %% [markdown]
# #### GANs loss

# %%
def real_mse_loss(D_out):
    # how close is the produced output from being "real"?
    return torch.mean((D_out-1)**2)

# %%
def fake_mse_loss(D_out):
    # how close is the produced output from being "fake"?
    return torch.mean(D_out**2)

# %%
def cycle_consistency_loss(real_im, reconstructed_im, lambda_weight):
    # calculate reconstruction loss
    # as absolute value difference between the real and reconstructed images
    reconstr_loss = torch.mean(torch.abs(real_im - reconstructed_im))
    # return weighted loss
    return lambda_weight*reconstr_loss

# %% [markdown]
# ### Optimizers

# %%
# hyperparams for Adam optimizer
lr=0.0002
beta1=0.5
beta2=0.999 # default value

# %%
# Get generator parameters
g_params = list(G_XtoY.parameters()) + list(G_YtoX.parameters())

# %%
# Create optimizers for the generators and discriminators
g_optimizer = optim.Adam(g_params, lr, [beta1, beta2])
d_x_optimizer = optim.Adam(D_X.parameters(), lr, [beta1, beta2])
d_y_optimizer = optim.Adam(D_Y.parameters(), lr, [beta1, beta2])

# %% [markdown]
# ### Helper functions

# %%
import pdb
import pickle
import argparse
import scipy
import scipy.misc

# %%
warnings.filterwarnings("ignore")

# %%
def checkpoint(iteration, G_XtoY, G_YtoX, D_X, D_Y, checkpoint_dir='/content/drive/MyDrive/ColabNotebooks/model_checkpoints'):
    """saves the parameters of both generators G_YtoX, G_XtoY and discriminators D_X, D_Y"""
    G_XtoY_path = os.path.join(checkpoint_dir, 'G_XtoY.pkl')
    G_YtoX_path = os.path.join(checkpoint_dir, 'G_YtoX.pkl')
    D_X_path = os.path.join(checkpoint_dir, 'D_X.pkl')
    D_Y_path = os.path.join(checkpoint_dir, 'D_Y.pkl')
    torch.save(G_XtoY.state_dict(), G_XtoY_path)
    torch.save(G_YtoX.state_dict(), G_YtoX_path)
    torch.save(D_X.state_dict(), D_X_path)
    torch.save(D_Y.state_dict(), D_Y_path)

# %%
import numpy as np

def merge_images(sources, targets, batch_size=16):
    """
    Merges source and target image batches into a single image for visualization.

    Args:
    - sources (numpy array): Source images of shape (B, C, H, W).
    - targets (numpy array): Target images of shape (B, C, H, W).
    - batch_size (int): Number of images in each batch.

    Returns:
    - merged (numpy array): Merged image with source and target pairs side-by-side.
    """
    # Check if batch_size matches the number of images
    if len(sources) != batch_size or len(targets) != batch_size:
        raise ValueError("Batch size does not match the number of images in sources or targets.")

    # Get height and width from source images
    _, channels, height, width = sources.shape

    # Calculate number of rows for the merged image (square layout)
    row = int(np.sqrt(batch_size))

    # Initialize an empty array for the merged image
    # This will contain source and target pairs side-by-side
    merged = np.zeros((channels, row * height, row * width * 2))

    # Loop through the batches to fill the merged array
    for idx, (source, target) in enumerate(zip(sources, targets)):
        # Determine row and column index for placement
        row_idx = idx // row
        col_idx = idx % row

        # Place the source and target images into the merged array
        merged[:, row_idx * height:(row_idx + 1) * height, (col_idx * 2) * width:(col_idx * 2 + 1) * width] = source
        merged[:, row_idx * height:(row_idx + 1) * height, (col_idx * 2 + 1) * width:(col_idx * 2 + 2) * width] = target

    # Transpose the merged array for the correct (H, W, C) format
    merged = merged.transpose(1, 2, 0)

    return merged

# %%
def to_data(x):
    """converts variable to numpy."""
    if torch.cuda.is_available():
        x = x.cpu()
    x = x.data.numpy()
    x = ((x +1)*255 / (2)).astype(np.uint8) # rescale to 0-255
    return x

# %%
import os
import imageio
def save_samples(iteration, fixed_Y, fixed_X, G_YtoX, G_XtoY, batch_size=16, sample_dir='image_samples'):
    """saves samples from both generators X->Y and Y->X."""
    # move input data to correct device
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

    fake_X = G_YtoX(fixed_Y.to(device))
    fake_Y = G_XtoY(fixed_X.to(device))

    X, fake_X = to_data(fixed_X), to_data(fake_X)
    Y, fake_Y = to_data(fixed_Y), to_data(fake_Y)

    # Create directory if it doesn't exist
    os.makedirs(sample_dir, exist_ok=True)


    merged = merge_images(X, fake_Y, batch_size)
    merged = merged.astype(np.uint8)
    path = os.path.join(sample_dir, 'sample-{:06d}-X-Y.png'.format(iteration))
    imageio.imwrite(path, merged)
    print('Saved {}'.format(path))

    merged = merge_images(Y, fake_X, batch_size)
    merged = merged.astype(np.uint8)
    path = os.path.join(sample_dir, 'sample-{:06d}-Y-X.png'.format(iteration))
    imageio.imwrite(path, merged)
    print('Saved {}'.format(path))

# %%
def imshow(img):
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()

# %% [markdown]
# ### Training the Model

# %%
# helper scale function
def scale(x, feature_range=(-1, 1)):
    ''' Scale takes in an image x and returns that image, scaled
       with a feature_range of pixel values from -1 to 1.
       This function assumes that the input x is already scaled from 0-1.'''

    # scale from 0-1 to feature_range
    min, max = feature_range
    x = x * (max - min) + min
    return x

# %%
def unnormalize_images(images):
    """ Return tensor of images to [0:255] space from [-1:1] for plotting. """
    unnormalized = torch.zeros_like(images)
    t = transforms.Normalize(
        mean=[-0.5 / 0.5, -0.5 / 0.5, -0.5 / 0.5],
        std=[1 / 0.5, 1 / 0.5, 1 / 0.5])
    for i, image in enumerate(images):
        unnormalized[i] = t(image)*255
    return unnormalized

# %%
global epoch_d_x_loss
epoch_d_x_loss = 0
global epoch_d_y_loss
epoch_d_y_loss = 0
global epoch_g_loss
epoch_g_loss = 0

# %%
def training_loop(dataloader_X, dataloader_Y, test_dataloader_X, test_dataloader_Y, n_epochs=100):
    print_every=10


    # Create optimizers for the generators and discriminators
    g_optimizer = optim.Adam(g_params, lr, [beta1, beta2])
    d_x_optimizer = optim.Adam(D_X.parameters(), lr, [beta1, beta2])
    d_y_optimizer = optim.Adam(D_Y.parameters(), lr, [beta1, beta2])

    # keep track of losses over time
    losses = []

    test_iter_X = iter(test_dataloader_X)
    test_iter_Y = iter(test_dataloader_Y)

    # Get some fixed data from domains X and Y for sampling. These are images that are held
    # constant throughout training, that allow us to inspect the model's performance.
    fixed_X = next(test_iter_X)[0]
    fixed_Y = next(test_iter_Y)[0]
    fixed_X = scale(fixed_X) # make sure to scale to a range -1 to 1
    fixed_Y = scale(fixed_Y)

    # batches per epoch
    iter_X = iter(dataloader_X)
    iter_Y = iter(dataloader_Y)
    batches_per_epoch = min(len(iter_X), len(iter_Y))

    for epoch in range(1, n_epochs+1):
        # Reset iterators for each epoch
        if epoch % batches_per_epoch == 0:
            iter_X = iter(dataloader_X)
            iter_Y = iter(dataloader_Y)

        images_X, _ = next(iter_X)
        real_images = images_X
        images_X = scale(images_X) # make sure to scale to a range -1 to 1

        images_Y, _ = next(iter_Y)
        real_images = images_Y
        images_Y = scale(images_Y)

        # move images to GPU if available (otherwise stay on CPU)
        device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
        images_X = images_X.to(device)
        images_Y = images_Y.to(device)


        # ============================================
        #            TRAIN THE DISCRIMINATORS
        # ============================================

        ##   First: D_X, real and fake loss components   ##

        # Train with real images
        d_x_optimizer.zero_grad()

        # 1. Compute the discriminator losses on real images
        out_x = D_X(images_X)
        D_X_real_loss = real_mse_loss(out_x)

        # Train with fake images

        # 2. Generate fake images that look like domain X based on real images in domain Y
        fake_X = G_YtoX(images_Y)

        # 3. Compute the fake loss for D_X
        out_x = D_X(fake_X)
        D_X_fake_loss = fake_mse_loss(out_x)


        # 4. Compute the total loss and perform backprop
        d_x_loss = D_X_real_loss + D_X_fake_loss
        d_x_loss.backward()
        d_x_optimizer.step()


        ##   Second: D_Y, real and fake loss components   ##

        # Train with real images
        d_y_optimizer.zero_grad()

        # 1. Compute the discriminator losses on real images
        out_y = D_Y(images_Y)
        D_Y_real_loss = real_mse_loss(out_y)

        # Train with fake images

        # 2. Generate fake images that look like domain Y based on real images in domain X
        fake_Y = G_XtoY(images_X)

        # 3. Compute the fake loss for D_Y
        out_y = D_Y(fake_Y)
        D_Y_fake_loss = fake_mse_loss(out_y)

        # 4. Compute the total loss and perform backprop
        d_y_loss = D_Y_real_loss + D_Y_fake_loss
        d_y_loss.backward()
        d_y_optimizer.step()


        # =========================================
        #            TRAIN THE GENERATORS
        # =========================================

        ##    First: generate fake X images and reconstructed Y images    ##
        g_optimizer.zero_grad()

        # 1. Generate fake images that look like domain X based on real images in domain Y
        fake_X = G_YtoX(images_Y)

        # 2. Compute the generator loss based on domain X
        out_x = D_X(fake_X)
        g_YtoX_loss = real_mse_loss(out_x)

        # 3. Create a reconstructed y
        # 4. Compute the cycle consistency loss (the reconstruction loss)
        reconstructed_Y = G_XtoY(fake_X)

        reconstructed_y_loss = cycle_consistency_loss(images_Y, reconstructed_Y, lambda_weight=10)


        ##    Second: generate fake Y images and reconstructed X images    ##

        # 1. Generate fake images that look like domain Y based on real images in domain X
        fake_Y = G_XtoY(images_X)

        # 2. Compute the generator loss based on domain Y
        out_y = D_Y(fake_Y)
        g_XtoY_loss = real_mse_loss(out_y)

        # 3. Create a reconstructed x
        # 4. Compute the cycle consistency loss (the reconstruction loss)
        reconstructed_X = G_YtoX(fake_Y)
        reconstructed_x_loss = cycle_consistency_loss(images_X, reconstructed_X, lambda_weight=10)

        # 5. Add up all generator and reconstructed losses and perform backprop
        g_total_loss = g_YtoX_loss + g_XtoY_loss + reconstructed_y_loss + reconstructed_x_loss
        g_total_loss.backward()
        g_optimizer.step()
        global epoch_d_x_loss
        global epoch_d_y_loss
        global epoch_g_loss

        # Print the log info
        if epoch % print_every == 0:

            # append real and fake discriminator losses and the generator loss
            losses.append((d_x_loss.item(), d_y_loss.item(), g_total_loss.item()))
            print('Epoch [{:5d}/{:5d}] | d_X_loss: {:6.4f} | d_Y_loss: {:6.4f} | g_total_loss: {:6.4f}'.format(
                    epoch, n_epochs, d_x_loss.item(), d_y_loss.item(), g_total_loss.item()))

            # Sum calculating of losses
            epoch_d_x_loss += d_x_loss.item()
            epoch_d_y_loss += d_y_loss.item()
            epoch_g_loss += g_total_loss.item()

            # generate image
            X_fake = G_XtoY(images_X)
            X_fake = unnormalize_images(X_fake)
            images_X = unnormalize_images(images_X)
            grid_image_real = torchvision.utils.make_grid(images_X.cpu())
            grid_image_fake = torchvision.utils.make_grid(X_fake.cpu())
            grid_image = torch.cat((grid_image_real, grid_image_fake), 1)
            saveim = np.transpose(grid_image.data.numpy().astype(np.uint8), (1, 2, 0))
            # plt.figure(figsize=(20, 10))
            # plt.imshow(saveim)
            # plt.savefig(filename + '_' + 'XtoY.jpg')

            Y_fake = G_YtoX(images_Y)
            Y_fake = unnormalize_images(Y_fake)
            images_Y = unnormalize_images(images_Y)
            grid_image_real = torchvision.utils.make_grid(images_Y.cpu())
            grid_image_fake = torchvision.utils.make_grid(Y_fake.cpu())
            grid_image = torch.cat((grid_image_real, grid_image_fake), 1)
            saveim = np.transpose(grid_image.data.numpy().astype(np.uint8), (1, 2, 0))



        sample_every=100
        # Save the generated samples
        if epoch % sample_every == 0:
            G_YtoX.eval() # set generators to eval mode for sample generation
            G_XtoY.eval()
            save_samples(epoch, fixed_Y, fixed_X, G_YtoX, G_XtoY, batch_size=16)
            G_YtoX.train()
            G_XtoY.train()

        # uncomment these lines, if you want to save your model
        checkpoint_every=1000
        # Save the model parameters
        if epoch % checkpoint_every == 0:
            checkpoint(epoch, G_XtoY, G_YtoX, D_X, D_Y)

    return losses

# %%
n_epochs = 5000
losses = training_loop(dataloader_X, dataloader_Y, test_dataloader_X, test_dataloader_Y, n_epochs=n_epochs)
# Out:
# Epoch [   10/ 5000] | d_X_loss: 0.2037 | d_Y_loss: 0.1143 | g_total_loss: 9.1265
# Epoch [   20/ 5000] | d_X_loss: 0.2246 | d_Y_loss: 0.0521 | g_total_loss: 7.5885
# Epoch [   30/ 5000] | d_X_loss: 0.3867 | d_Y_loss: 0.0145 | g_total_loss: 6.6685
# Epoch [   40/ 5000] | d_X_loss: 0.2383 | d_Y_loss: 0.0286 | g_total_loss: 6.3645
# Epoch [   50/ 5000] | d_X_loss: 0.4094 | d_Y_loss: 0.0048 | g_total_loss: 6.1421
# Epoch [   60/ 5000] | d_X_loss: 0.0982 | d_Y_loss: 0.0016 | g_total_loss: 7.0483
# Epoch [   70/ 5000] | d_X_loss: 0.4810 | d_Y_loss: 0.6898 | g_total_loss: 5.8222
# Epoch [   80/ 5000] | d_X_loss: 0.2945 | d_Y_loss: 0.0300 | g_total_loss: 6.0253
# Epoch [   90/ 5000] | d_X_loss: 0.1173 | d_Y_loss: 0.0137 | g_total_loss: 5.7003
# Epoch [  100/ 5000] | d_X_loss: 0.4107 | d_Y_loss: 0.6061 | g_total_loss: 4.8855
# Saved image_samples/sample-000100-X-Y.png
# Saved image_samples/sample-000100-Y-X.png
# Epoch [  110/ 5000] | d_X_loss: 0.3987 | d_Y_loss: 0.0429 | g_total_loss: 5.5007
# Epoch [  120/ 5000] | d_X_loss: 0.2877 | d_Y_loss: 0.0636 | g_total_loss: 5.2064
# Epoch [  130/ 5000] | d_X_loss: 0.1869 | d_Y_loss: 0.0298 | g_total_loss: 5.4849
# Epoch [  140/ 5000] | d_X_loss: 0.2863 | d_Y_loss: 0.0205 | g_total_loss: 5.5438
# Epoch [  150/ 5000] | d_X_loss: 0.2214 | d_Y_loss: 0.6242 | g_total_loss: 5.1165
# Epoch [  160/ 5000] | d_X_loss: 0.2511 | d_Y_loss: 0.0174 | g_total_loss: 5.0250
# Epoch [  170/ 5000] | d_X_loss: 0.2883 | d_Y_loss: 0.0137 | g_total_loss: 5.4472
# Epoch [  180/ 5000] | d_X_loss: 0.2147 | d_Y_loss: 0.0166 | g_total_loss: 4.8627
# Epoch [  190/ 5000] | d_X_loss: 0.3155 | d_Y_loss: 0.0170 | g_total_loss: 4.8554
# Epoch [  200/ 5000] | d_X_loss: 0.3550 | d_Y_loss: 0.0267 | g_total_loss: 4.9158
# Saved image_samples/sample-000200-X-Y.png
# Saved image_samples/sample-000200-Y-X.png
# Epoch [  210/ 5000] | d_X_loss: 0.2336 | d_Y_loss: 0.1691 | g_total_loss: 4.9251
# Epoch [  220/ 5000] | d_X_loss: 0.1060 | d_Y_loss: 0.0029 | g_total_loss: 5.1687
# Epoch [  230/ 5000] | d_X_loss: 0.0989 | d_Y_loss: 0.0618 | g_total_loss: 5.3793
# Epoch [  240/ 5000] | d_X_loss: 0.2163 | d_Y_loss: 0.0144 | g_total_loss: 4.6782
# Epoch [  250/ 5000] | d_X_loss: 0.1330 | d_Y_loss: 0.1072 | g_total_loss: 4.6691
# Epoch [  260/ 5000] | d_X_loss: 0.1710 | d_Y_loss: 0.0027 | g_total_loss: 5.5278
# Epoch [  270/ 5000] | d_X_loss: 0.1510 | d_Y_loss: 0.0030 | g_total_loss: 4.8216
# Epoch [  280/ 5000] | d_X_loss: 0.1428 | d_Y_loss: 0.0200 | g_total_loss: 4.6701
# Epoch [  290/ 5000] | d_X_loss: 0.2448 | d_Y_loss: 0.2580 | g_total_loss: 5.6778
# Epoch [  300/ 5000] | d_X_loss: 0.0768 | d_Y_loss: 0.0157 | g_total_loss: 5.2889
# Saved image_samples/sample-000300-X-Y.png
# Saved image_samples/sample-000300-Y-X.png
# Epoch [  310/ 5000] | d_X_loss: 0.3440 | d_Y_loss: 0.0682 | g_total_loss: 5.1207
# Epoch [  320/ 5000] | d_X_loss: 0.2117 | d_Y_loss: 0.0151 | g_total_loss: 4.3384
# Epoch [  330/ 5000] | d_X_loss: 0.1095 | d_Y_loss: 0.0100 | g_total_loss: 4.6964
# Epoch [  340/ 5000] | d_X_loss: 0.4813 | d_Y_loss: 0.0671 | g_total_loss: 4.9450
# Epoch [  350/ 5000] | d_X_loss: 0.2859 | d_Y_loss: 0.0915 | g_total_loss: 5.2819
# Epoch [  360/ 5000] | d_X_loss: 0.1225 | d_Y_loss: 0.0117 | g_total_loss: 4.9416
# Epoch [  370/ 5000] | d_X_loss: 0.1203 | d_Y_loss: 0.0077 | g_total_loss: 5.0310
# Epoch [  380/ 5000] | d_X_loss: 0.3853 | d_Y_loss: 0.0374 | g_total_loss: 4.5252
# Epoch [  390/ 5000] | d_X_loss: 0.1521 | d_Y_loss: 0.1434 | g_total_loss: 4.9286
# Epoch [  400/ 5000] | d_X_loss: 0.2150 | d_Y_loss: 0.0052 | g_total_loss: 4.2900
# Saved image_samples/sample-000400-X-Y.png
# Saved image_samples/sample-000400-Y-X.png
# Epoch [  410/ 5000] | d_X_loss: 0.3917 | d_Y_loss: 0.1160 | g_total_loss: 4.6893
# Epoch [  420/ 5000] | d_X_loss: 0.0223 | d_Y_loss: 0.0516 | g_total_loss: 4.6898
# Epoch [  430/ 5000] | d_X_loss: 0.1073 | d_Y_loss: 0.2495 | g_total_loss: 4.6976
# Epoch [  440/ 5000] | d_X_loss: 0.1571 | d_Y_loss: 0.0084 | g_total_loss: 4.7408
# Epoch [  450/ 5000] | d_X_loss: 0.0487 | d_Y_loss: 0.0015 | g_total_loss: 5.1885
# Epoch [  460/ 5000] | d_X_loss: 0.0678 | d_Y_loss: 0.0028 | g_total_loss: 4.6980
# Epoch [  470/ 5000] | d_X_loss: 0.1217 | d_Y_loss: 0.0159 | g_total_loss: 5.5155
# Epoch [  480/ 5000] | d_X_loss: 0.1302 | d_Y_loss: 0.0045 | g_total_loss: 4.9747
# Epoch [  490/ 5000] | d_X_loss: 0.1392 | d_Y_loss: 0.0039 | g_total_loss: 4.9230
# Epoch [  500/ 5000] | d_X_loss: 0.0821 | d_Y_loss: 0.0027 | g_total_loss: 4.4368
# Saved image_samples/sample-000500-X-Y.png
# Saved image_samples/sample-000500-Y-X.png
# Epoch [  510/ 5000] | d_X_loss: 0.0850 | d_Y_loss: 0.0013 | g_total_loss: 4.6012
# Epoch [  520/ 5000] | d_X_loss: 0.0726 | d_Y_loss: 0.0003 | g_total_loss: 4.5653
# Epoch [  530/ 5000] | d_X_loss: 0.1280 | d_Y_loss: 0.0047 | g_total_loss: 4.7651
# Epoch [  540/ 5000] | d_X_loss: 0.0899 | d_Y_loss: 0.0317 | g_total_loss: 4.7767
# Epoch [  550/ 5000] | d_X_loss: 0.1330 | d_Y_loss: 0.0024 | g_total_loss: 4.7244
# Epoch [  560/ 5000] | d_X_loss: 0.0544 | d_Y_loss: 0.0216 | g_total_loss: 4.6002
# Epoch [  570/ 5000] | d_X_loss: 0.0668 | d_Y_loss: 0.0051 | g_total_loss: 4.6989
# Epoch [  580/ 5000] | d_X_loss: 0.0426 | d_Y_loss: 0.0345 | g_total_loss: 4.5020
# Epoch [  590/ 5000] | d_X_loss: 0.2068 | d_Y_loss: 0.1064 | g_total_loss: 4.4143
# Epoch [  600/ 5000] | d_X_loss: 0.1107 | d_Y_loss: 0.0216 | g_total_loss: 4.4267
# Saved image_samples/sample-000600-X-Y.png
# Saved image_samples/sample-000600-Y-X.png
# Epoch [  610/ 5000] | d_X_loss: 0.0860 | d_Y_loss: 0.0136 | g_total_loss: 4.8008
# Epoch [  620/ 5000] | d_X_loss: 0.2814 | d_Y_loss: 0.0056 | g_total_loss: 4.8743
# Epoch [  630/ 5000] | d_X_loss: 0.1038 | d_Y_loss: 0.9548 | g_total_loss: 4.5729
# Epoch [  640/ 5000] | d_X_loss: 0.0688 | d_Y_loss: 0.0129 | g_total_loss: 4.5600
# Epoch [  650/ 5000] | d_X_loss: 0.1228 | d_Y_loss: 0.0477 | g_total_loss: 5.0433
# Epoch [  660/ 5000] | d_X_loss: 0.1032 | d_Y_loss: 0.0052 | g_total_loss: 4.6420
# Epoch [  670/ 5000] | d_X_loss: 0.1364 | d_Y_loss: 0.0182 | g_total_loss: 4.7352
# Epoch [  680/ 5000] | d_X_loss: 0.0965 | d_Y_loss: 0.1769 | g_total_loss: 4.4690
# Epoch [  690/ 5000] | d_X_loss: 0.0231 | d_Y_loss: 0.0111 | g_total_loss: 4.8176
# Epoch [  700/ 5000] | d_X_loss: 0.0793 | d_Y_loss: 0.0029 | g_total_loss: 4.5582
# Saved image_samples/sample-000700-X-Y.png
# Saved image_samples/sample-000700-Y-X.png
# Epoch [  710/ 5000] | d_X_loss: 0.0519 | d_Y_loss: 0.0003 | g_total_loss: 4.7949
# Epoch [  720/ 5000] | d_X_loss: 0.0423 | d_Y_loss: 0.0113 | g_total_loss: 4.3037
# Epoch [  730/ 5000] | d_X_loss: 0.0212 | d_Y_loss: 0.0110 | g_total_loss: 4.6010
# Epoch [  740/ 5000] | d_X_loss: 0.0310 | d_Y_loss: 0.0008 | g_total_loss: 4.5279
# Epoch [  750/ 5000] | d_X_loss: 0.0278 | d_Y_loss: 0.0512 | g_total_loss: 4.4857
# Epoch [  760/ 5000] | d_X_loss: 0.1276 | d_Y_loss: 0.0060 | g_total_loss: 4.3707
# Epoch [  770/ 5000] | d_X_loss: 0.2369 | d_Y_loss: 0.4358 | g_total_loss: 4.7847
# Epoch [  780/ 5000] | d_X_loss: 0.0653 | d_Y_loss: 0.0015 | g_total_loss: 4.2736
# Epoch [  790/ 5000] | d_X_loss: 0.1138 | d_Y_loss: 0.0424 | g_total_loss: 4.2653
# Epoch [  800/ 5000] | d_X_loss: 0.0509 | d_Y_loss: 0.0140 | g_total_loss: 4.8002
# Saved image_samples/sample-000800-X-Y.png
# Saved image_samples/sample-000800-Y-X.png
# Epoch [  810/ 5000] | d_X_loss: 0.0804 | d_Y_loss: 0.0277 | g_total_loss: 4.6834
# Epoch [  820/ 5000] | d_X_loss: 0.0507 | d_Y_loss: 0.0299 | g_total_loss: 4.3610
# Epoch [  830/ 5000] | d_X_loss: 0.0364 | d_Y_loss: 0.0161 | g_total_loss: 4.4564
# Epoch [  840/ 5000] | d_X_loss: 0.0223 | d_Y_loss: 0.0060 | g_total_loss: 4.3122
# Epoch [  850/ 5000] | d_X_loss: 0.0526 | d_Y_loss: 0.4876 | g_total_loss: 4.4169
# Epoch [  860/ 5000] | d_X_loss: 0.0058 | d_Y_loss: 0.0143 | g_total_loss: 4.2626
# Epoch [  870/ 5000] | d_X_loss: 0.0568 | d_Y_loss: 0.0239 | g_total_loss: 4.4020
# Epoch [  880/ 5000] | d_X_loss: 0.0402 | d_Y_loss: 0.4375 | g_total_loss: 4.3556
# Epoch [  890/ 5000] | d_X_loss: 0.0770 | d_Y_loss: 0.0186 | g_total_loss: 4.3731
# Epoch [  900/ 5000] | d_X_loss: 0.0597 | d_Y_loss: 0.0283 | g_total_loss: 4.2980
# Saved image_samples/sample-000900-X-Y.png
# Saved image_samples/sample-000900-Y-X.png
# Epoch [  910/ 5000] | d_X_loss: 0.0232 | d_Y_loss: 0.1485 | g_total_loss: 4.3636
# Epoch [  920/ 5000] | d_X_loss: 0.0283 | d_Y_loss: 0.0047 | g_total_loss: 4.3033
# Epoch [  930/ 5000] | d_X_loss: 0.1165 | d_Y_loss: 0.0104 | g_total_loss: 4.2881
# Epoch [  940/ 5000] | d_X_loss: 0.0564 | d_Y_loss: 0.0180 | g_total_loss: 4.5666
# Epoch [  950/ 5000] | d_X_loss: 0.0580 | d_Y_loss: 0.0076 | g_total_loss: 4.4031
# Epoch [  960/ 5000] | d_X_loss: 0.1297 | d_Y_loss: 0.0119 | g_total_loss: 4.3326
# Epoch [  970/ 5000] | d_X_loss: 0.3069 | d_Y_loss: 0.5917 | g_total_loss: 4.0456
# Epoch [  980/ 5000] | d_X_loss: 0.0165 | d_Y_loss: 0.0006 | g_total_loss: 5.0186
# Epoch [  990/ 5000] | d_X_loss: 0.0166 | d_Y_loss: 0.0086 | g_total_loss: 4.7609
# Epoch [ 1000/ 5000] | d_X_loss: 0.1466 | d_Y_loss: 0.0053 | g_total_loss: 4.5300
# Saved image_samples/sample-001000-X-Y.png
# Saved image_samples/sample-001000-Y-X.png
# Epoch [ 1010/ 5000] | d_X_loss: 0.0348 | d_Y_loss: 0.0016 | g_total_loss: 4.4575
# Epoch [ 1020/ 5000] | d_X_loss: 0.0175 | d_Y_loss: 0.0003 | g_total_loss: 4.4226
# Epoch [ 1030/ 5000] | d_X_loss: 0.0172 | d_Y_loss: 0.0103 | g_total_loss: 4.5256
# Epoch [ 1040/ 5000] | d_X_loss: 0.0274 | d_Y_loss: 0.0076 | g_total_loss: 4.3963
# Epoch [ 1050/ 5000] | d_X_loss: 0.0677 | d_Y_loss: 0.0022 | g_total_loss: 4.1102
# Epoch [ 1060/ 5000] | d_X_loss: 0.0186 | d_Y_loss: 0.0027 | g_total_loss: 4.8320
# Epoch [ 1070/ 5000] | d_X_loss: 0.0096 | d_Y_loss: 0.0172 | g_total_loss: 4.7304
# Epoch [ 1080/ 5000] | d_X_loss: 0.1828 | d_Y_loss: 0.0053 | g_total_loss: 4.9055
# Epoch [ 1090/ 5000] | d_X_loss: 0.4802 | d_Y_loss: 0.0116 | g_total_loss: 4.3482
# Epoch [ 1100/ 5000] | d_X_loss: 0.0527 | d_Y_loss: 0.0093 | g_total_loss: 4.3525
# Saved image_samples/sample-001100-X-Y.png
# Saved image_samples/sample-001100-Y-X.png
# Epoch [ 1110/ 5000] | d_X_loss: 0.0598 | d_Y_loss: 0.0057 | g_total_loss: 4.0290
# Epoch [ 1120/ 5000] | d_X_loss: 0.0355 | d_Y_loss: 0.0047 | g_total_loss: 4.0954
# Epoch [ 1130/ 5000] | d_X_loss: 0.1732 | d_Y_loss: 0.0032 | g_total_loss: 4.1348
# Epoch [ 1140/ 5000] | d_X_loss: 0.1409 | d_Y_loss: 0.0413 | g_total_loss: 4.1286
# Epoch [ 1150/ 5000] | d_X_loss: 0.0260 | d_Y_loss: 0.0484 | g_total_loss: 4.2537
# Epoch [ 1160/ 5000] | d_X_loss: 0.0141 | d_Y_loss: 0.0101 | g_total_loss: 4.7062
# Epoch [ 1170/ 5000] | d_X_loss: 0.0233 | d_Y_loss: 0.0062 | g_total_loss: 4.0050
# Epoch [ 1180/ 5000] | d_X_loss: 0.1848 | d_Y_loss: 0.0242 | g_total_loss: 4.2437
# Epoch [ 1190/ 5000] | d_X_loss: 0.0003 | d_Y_loss: 0.0013 | g_total_loss: 4.5318
# Epoch [ 1200/ 5000] | d_X_loss: 0.0024 | d_Y_loss: 0.0192 | g_total_loss: 4.1140
# Saved image_samples/sample-001200-X-Y.png
# Saved image_samples/sample-001200-Y-X.png
# Epoch [ 1210/ 5000] | d_X_loss: 0.0048 | d_Y_loss: 0.0123 | g_total_loss: 4.0892
# Epoch [ 1220/ 5000] | d_X_loss: 0.0159 | d_Y_loss: 0.0378 | g_total_loss: 4.2732
# Epoch [ 1230/ 5000] | d_X_loss: 0.0048 | d_Y_loss: 0.0147 | g_total_loss: 4.3518
# Epoch [ 1240/ 5000] | d_X_loss: 0.0250 | d_Y_loss: 0.1659 | g_total_loss: 4.7607
# Epoch [ 1250/ 5000] | d_X_loss: 0.0132 | d_Y_loss: 0.0048 | g_total_loss: 3.9936
# Epoch [ 1260/ 5000] | d_X_loss: 0.0202 | d_Y_loss: 0.0190 | g_total_loss: 4.4756
# Epoch [ 1270/ 5000] | d_X_loss: 0.0206 | d_Y_loss: 0.0080 | g_total_loss: 4.7821
# Epoch [ 1280/ 5000] | d_X_loss: 0.0572 | d_Y_loss: 0.0008 | g_total_loss: 4.1500
# Epoch [ 1290/ 5000] | d_X_loss: 0.0194 | d_Y_loss: 0.0064 | g_total_loss: 4.0823
# Epoch [ 1300/ 5000] | d_X_loss: 0.0062 | d_Y_loss: 0.0011 | g_total_loss: 4.6914
# Saved image_samples/sample-001300-X-Y.png
# Saved image_samples/sample-001300-Y-X.png
# Epoch [ 1310/ 5000] | d_X_loss: 0.0152 | d_Y_loss: 0.0002 | g_total_loss: 4.7056
# Epoch [ 1320/ 5000] | d_X_loss: 0.0014 | d_Y_loss: 0.0001 | g_total_loss: 4.3509
# Epoch [ 1330/ 5000] | d_X_loss: 0.0060 | d_Y_loss: 0.0001 | g_total_loss: 4.4391
# Epoch [ 1340/ 5000] | d_X_loss: 0.0282 | d_Y_loss: 0.0001 | g_total_loss: 4.6972
# Epoch [ 1350/ 5000] | d_X_loss: 0.0078 | d_Y_loss: 0.0001 | g_total_loss: 4.1039
# Epoch [ 1360/ 5000] | d_X_loss: 0.0426 | d_Y_loss: 0.0004 | g_total_loss: 4.1978
# Epoch [ 1370/ 5000] | d_X_loss: 0.0145 | d_Y_loss: 0.0095 | g_total_loss: 3.9386
# Epoch [ 1380/ 5000] | d_X_loss: 0.0496 | d_Y_loss: 0.0105 | g_total_loss: 3.9267
# Epoch [ 1390/ 5000] | d_X_loss: 0.0134 | d_Y_loss: 0.0107 | g_total_loss: 4.2359
# Epoch [ 1400/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 0.0001 | g_total_loss: 4.9244
# Saved image_samples/sample-001400-X-Y.png
# Saved image_samples/sample-001400-Y-X.png
# Epoch [ 1410/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 0.0000 | g_total_loss: 4.6820
# Epoch [ 1420/ 5000] | d_X_loss: 0.0004 | d_Y_loss: 0.0000 | g_total_loss: 5.1250
# Epoch [ 1430/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 4.7383
# Epoch [ 1440/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 4.2522
# Epoch [ 1450/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 4.4438
# Epoch [ 1460/ 5000] | d_X_loss: 0.0003 | d_Y_loss: 0.0000 | g_total_loss: 4.4162
# Epoch [ 1470/ 5000] | d_X_loss: 0.0003 | d_Y_loss: 0.0000 | g_total_loss: 3.9856
# Epoch [ 1480/ 5000] | d_X_loss: 0.0003 | d_Y_loss: 0.0000 | g_total_loss: 4.2172
# Epoch [ 1490/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 4.0557
# Epoch [ 1500/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.9814
# Saved image_samples/sample-001500-X-Y.png
# Saved image_samples/sample-001500-Y-X.png
# Epoch [ 1510/ 5000] | d_X_loss: 0.0071 | d_Y_loss: 0.0000 | g_total_loss: 4.1127
# Epoch [ 1520/ 5000] | d_X_loss: 0.0007 | d_Y_loss: 0.0000 | g_total_loss: 4.4833
# Epoch [ 1530/ 5000] | d_X_loss: 0.0016 | d_Y_loss: 0.0000 | g_total_loss: 4.0756
# Epoch [ 1540/ 5000] | d_X_loss: 0.0008 | d_Y_loss: 0.0000 | g_total_loss: 4.0082
# Epoch [ 1550/ 5000] | d_X_loss: 0.0051 | d_Y_loss: 0.0001 | g_total_loss: 4.2621
# Epoch [ 1560/ 5000] | d_X_loss: 0.0108 | d_Y_loss: 0.0004 | g_total_loss: 4.5435
# Epoch [ 1570/ 5000] | d_X_loss: 0.0045 | d_Y_loss: 0.0003 | g_total_loss: 3.9870
# Epoch [ 1580/ 5000] | d_X_loss: 0.0023 | d_Y_loss: 0.0002 | g_total_loss: 4.4962
# Epoch [ 1590/ 5000] | d_X_loss: 0.0246 | d_Y_loss: 0.0009 | g_total_loss: 4.1225
# Epoch [ 1600/ 5000] | d_X_loss: 0.0012 | d_Y_loss: 0.0018 | g_total_loss: 4.1224
# Saved image_samples/sample-001600-X-Y.png
# Saved image_samples/sample-001600-Y-X.png
# Epoch [ 1610/ 5000] | d_X_loss: 0.0070 | d_Y_loss: 0.0006 | g_total_loss: 4.1209
# Epoch [ 1620/ 5000] | d_X_loss: 0.0056 | d_Y_loss: 0.0064 | g_total_loss: 4.1376
# Epoch [ 1630/ 5000] | d_X_loss: 0.0008 | d_Y_loss: 0.0009 | g_total_loss: 4.2082
# Epoch [ 1640/ 5000] | d_X_loss: 0.0043 | d_Y_loss: 0.0008 | g_total_loss: 4.0848
# Epoch [ 1650/ 5000] | d_X_loss: 0.0100 | d_Y_loss: 0.0031 | g_total_loss: 3.9258
# Epoch [ 1660/ 5000] | d_X_loss: 0.0065 | d_Y_loss: 0.0024 | g_total_loss: 4.4525
# Epoch [ 1670/ 5000] | d_X_loss: 0.0016 | d_Y_loss: 0.0021 | g_total_loss: 3.8874
# Epoch [ 1680/ 5000] | d_X_loss: 0.0052 | d_Y_loss: 0.0018 | g_total_loss: 3.8544
# Epoch [ 1690/ 5000] | d_X_loss: 0.0011 | d_Y_loss: 0.0009 | g_total_loss: 4.1666
# Epoch [ 1700/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0002 | g_total_loss: 4.7439
# Saved image_samples/sample-001700-X-Y.png
# Saved image_samples/sample-001700-Y-X.png
# Epoch [ 1710/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0032 | g_total_loss: 3.9650
# Epoch [ 1720/ 5000] | d_X_loss: 0.0124 | d_Y_loss: 0.0016 | g_total_loss: 3.9075
# Epoch [ 1730/ 5000] | d_X_loss: 0.0007 | d_Y_loss: 0.0040 | g_total_loss: 3.9762
# Epoch [ 1740/ 5000] | d_X_loss: 0.1659 | d_Y_loss: 0.0031 | g_total_loss: 3.5643
# Epoch [ 1750/ 5000] | d_X_loss: 0.0185 | d_Y_loss: 0.0034 | g_total_loss: 4.3202
# Epoch [ 1760/ 5000] | d_X_loss: 0.0061 | d_Y_loss: 0.0039 | g_total_loss: 3.9714
# Epoch [ 1770/ 5000] | d_X_loss: 0.0319 | d_Y_loss: 0.0306 | g_total_loss: 3.8819
# Epoch [ 1780/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0007 | g_total_loss: 4.0852
# Epoch [ 1790/ 5000] | d_X_loss: 0.0004 | d_Y_loss: 0.0015 | g_total_loss: 3.9125
# Epoch [ 1800/ 5000] | d_X_loss: 0.0137 | d_Y_loss: 0.0017 | g_total_loss: 4.2254
# Saved image_samples/sample-001800-X-Y.png
# Saved image_samples/sample-001800-Y-X.png
# Epoch [ 1810/ 5000] | d_X_loss: 0.0193 | d_Y_loss: 0.0015 | g_total_loss: 4.0746
# Epoch [ 1820/ 5000] | d_X_loss: 0.0099 | d_Y_loss: 0.0024 | g_total_loss: 4.0853
# Epoch [ 1830/ 5000] | d_X_loss: 0.0804 | d_Y_loss: 0.0005 | g_total_loss: 3.9502
# Epoch [ 1840/ 5000] | d_X_loss: 0.2536 | d_Y_loss: 0.0060 | g_total_loss: 4.3447
# Epoch [ 1850/ 5000] | d_X_loss: 1.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.9800
# Epoch [ 1860/ 5000] | d_X_loss: 1.0000 | d_Y_loss: 0.0005 | g_total_loss: 4.1608
# Epoch [ 1870/ 5000] | d_X_loss: 0.9976 | d_Y_loss: 0.0010 | g_total_loss: 4.4784
# Epoch [ 1880/ 5000] | d_X_loss: 1.0000 | d_Y_loss: 0.0016 | g_total_loss: 3.8937
# Epoch [ 1890/ 5000] | d_X_loss: 0.9999 | d_Y_loss: 0.5706 | g_total_loss: 4.1353
# Epoch [ 1900/ 5000] | d_X_loss: 1.0000 | d_Y_loss: 0.0540 | g_total_loss: 4.0535
# Saved image_samples/sample-001900-X-Y.png
# Saved image_samples/sample-001900-Y-X.png
# Epoch [ 1910/ 5000] | d_X_loss: 0.9504 | d_Y_loss: 0.1021 | g_total_loss: 4.2311
# Epoch [ 1920/ 5000] | d_X_loss: 1.0211 | d_Y_loss: 0.2033 | g_total_loss: 4.0846
# Epoch [ 1930/ 5000] | d_X_loss: 0.4501 | d_Y_loss: 0.0053 | g_total_loss: 3.8385
# Epoch [ 1940/ 5000] | d_X_loss: 0.0406 | d_Y_loss: 0.0166 | g_total_loss: 3.8966
# Epoch [ 1950/ 5000] | d_X_loss: 0.1400 | d_Y_loss: 0.0098 | g_total_loss: 3.8903
# Epoch [ 1960/ 5000] | d_X_loss: 0.0003 | d_Y_loss: 0.0792 | g_total_loss: 4.8495
# Epoch [ 1970/ 5000] | d_X_loss: 0.0078 | d_Y_loss: 0.0045 | g_total_loss: 3.8555
# Epoch [ 1980/ 5000] | d_X_loss: 0.0114 | d_Y_loss: 0.0290 | g_total_loss: 4.4855
# Epoch [ 1990/ 5000] | d_X_loss: 0.0065 | d_Y_loss: 0.0509 | g_total_loss: 4.2491
# Epoch [ 2000/ 5000] | d_X_loss: 0.0420 | d_Y_loss: 0.0099 | g_total_loss: 4.1171
# Saved image_samples/sample-002000-X-Y.png
# Saved image_samples/sample-002000-Y-X.png
# Epoch [ 2010/ 5000] | d_X_loss: 0.0082 | d_Y_loss: 0.0093 | g_total_loss: 3.9985
# Epoch [ 2020/ 5000] | d_X_loss: 0.0020 | d_Y_loss: 0.0027 | g_total_loss: 4.5009
# Epoch [ 2030/ 5000] | d_X_loss: 0.0064 | d_Y_loss: 0.0052 | g_total_loss: 3.9336
# Epoch [ 2040/ 5000] | d_X_loss: 0.0009 | d_Y_loss: 0.0018 | g_total_loss: 3.9389
# Epoch [ 2050/ 5000] | d_X_loss: 0.0253 | d_Y_loss: 0.0037 | g_total_loss: 3.9402
# Epoch [ 2060/ 5000] | d_X_loss: 0.0035 | d_Y_loss: 0.0004 | g_total_loss: 3.9251
# Epoch [ 2070/ 5000] | d_X_loss: 0.8596 | d_Y_loss: 0.0014 | g_total_loss: 4.1139
# Epoch [ 2080/ 5000] | d_X_loss: 0.0112 | d_Y_loss: 0.0033 | g_total_loss: 3.8919
# Epoch [ 2090/ 5000] | d_X_loss: 0.0047 | d_Y_loss: 0.0022 | g_total_loss: 3.9606
# Epoch [ 2100/ 5000] | d_X_loss: 0.0365 | d_Y_loss: 0.0120 | g_total_loss: 3.9437
# Saved image_samples/sample-002100-X-Y.png
# Saved image_samples/sample-002100-Y-X.png
# Epoch [ 2110/ 5000] | d_X_loss: 0.0152 | d_Y_loss: 0.4145 | g_total_loss: 3.9834
# Epoch [ 2120/ 5000] | d_X_loss: 0.0121 | d_Y_loss: 0.5737 | g_total_loss: 4.0128
# Epoch [ 2130/ 5000] | d_X_loss: 0.0251 | d_Y_loss: 0.0259 | g_total_loss: 3.7349
# Epoch [ 2140/ 5000] | d_X_loss: 0.0515 | d_Y_loss: 0.0026 | g_total_loss: 3.8963
# Epoch [ 2150/ 5000] | d_X_loss: 0.0281 | d_Y_loss: 0.0072 | g_total_loss: 3.9974
# Epoch [ 2160/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0372 | g_total_loss: 4.0880
# Epoch [ 2170/ 5000] | d_X_loss: 0.0005 | d_Y_loss: 0.0070 | g_total_loss: 3.9003
# Epoch [ 2180/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0057 | g_total_loss: 4.3722
# Epoch [ 2190/ 5000] | d_X_loss: 0.0041 | d_Y_loss: 0.0036 | g_total_loss: 4.0564
# Epoch [ 2200/ 5000] | d_X_loss: 0.0116 | d_Y_loss: 0.0014 | g_total_loss: 3.6948
# Saved image_samples/sample-002200-X-Y.png
# Saved image_samples/sample-002200-Y-X.png
# Epoch [ 2210/ 5000] | d_X_loss: 0.0019 | d_Y_loss: 0.0026 | g_total_loss: 4.0338
# Epoch [ 2220/ 5000] | d_X_loss: 0.0003 | d_Y_loss: 0.0111 | g_total_loss: 3.9164
# Epoch [ 2230/ 5000] | d_X_loss: 0.0119 | d_Y_loss: 0.0026 | g_total_loss: 4.1605
# Epoch [ 2240/ 5000] | d_X_loss: 0.0089 | d_Y_loss: 0.0027 | g_total_loss: 3.8051
# Epoch [ 2250/ 5000] | d_X_loss: 0.3689 | d_Y_loss: 0.0103 | g_total_loss: 3.0771
# Epoch [ 2260/ 5000] | d_X_loss: 0.1716 | d_Y_loss: 0.0096 | g_total_loss: 3.4186
# Epoch [ 2270/ 5000] | d_X_loss: 0.0231 | d_Y_loss: 0.0254 | g_total_loss: 4.0957
# Epoch [ 2280/ 5000] | d_X_loss: 0.0005 | d_Y_loss: 0.0014 | g_total_loss: 4.0176
# Epoch [ 2290/ 5000] | d_X_loss: 0.0085 | d_Y_loss: 0.0022 | g_total_loss: 3.7773
# Epoch [ 2300/ 5000] | d_X_loss: 0.0045 | d_Y_loss: 0.0072 | g_total_loss: 3.7895
# Saved image_samples/sample-002300-X-Y.png
# Saved image_samples/sample-002300-Y-X.png
# Epoch [ 2310/ 5000] | d_X_loss: 0.0058 | d_Y_loss: 0.0011 | g_total_loss: 5.4438
# Epoch [ 2320/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0023 | g_total_loss: 4.3426
# Epoch [ 2330/ 5000] | d_X_loss: 0.0170 | d_Y_loss: 0.0021 | g_total_loss: 4.2139
# Epoch [ 2340/ 5000] | d_X_loss: 0.0013 | d_Y_loss: 0.0001 | g_total_loss: 4.3965
# Epoch [ 2350/ 5000] | d_X_loss: 0.0007 | d_Y_loss: 0.0006 | g_total_loss: 4.7205
# Epoch [ 2360/ 5000] | d_X_loss: 0.0015 | d_Y_loss: 0.0001 | g_total_loss: 3.8254
# Epoch [ 2370/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 4.1202
# Epoch [ 2380/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.9428
# Epoch [ 2390/ 5000] | d_X_loss: 0.0014 | d_Y_loss: 0.0000 | g_total_loss: 4.0726
# Epoch [ 2400/ 5000] | d_X_loss: 0.0048 | d_Y_loss: 0.0000 | g_total_loss: 3.8522
# Saved image_samples/sample-002400-X-Y.png
# Saved image_samples/sample-002400-Y-X.png
# Epoch [ 2410/ 5000] | d_X_loss: 0.0018 | d_Y_loss: 0.0000 | g_total_loss: 4.1550
# Epoch [ 2420/ 5000] | d_X_loss: 0.0095 | d_Y_loss: 0.0000 | g_total_loss: 3.9483
# Epoch [ 2430/ 5000] | d_X_loss: 0.0014 | d_Y_loss: 0.0000 | g_total_loss: 4.0317
# Epoch [ 2440/ 5000] | d_X_loss: 0.0056 | d_Y_loss: 0.0001 | g_total_loss: 4.0263
# Epoch [ 2450/ 5000] | d_X_loss: 0.0009 | d_Y_loss: 0.0004 | g_total_loss: 3.7158
# Epoch [ 2460/ 5000] | d_X_loss: 0.0073 | d_Y_loss: 0.0001 | g_total_loss: 3.9192
# Epoch [ 2470/ 5000] | d_X_loss: 0.0037 | d_Y_loss: 0.0005 | g_total_loss: 3.7185
# Epoch [ 2480/ 5000] | d_X_loss: 0.0044 | d_Y_loss: 0.0016 | g_total_loss: 3.7526
# Epoch [ 2490/ 5000] | d_X_loss: 0.0252 | d_Y_loss: 0.0019 | g_total_loss: 4.4299
# Epoch [ 2500/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0017 | g_total_loss: 4.1857
# Saved image_samples/sample-002500-X-Y.png
# Saved image_samples/sample-002500-Y-X.png
# Epoch [ 2510/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0014 | g_total_loss: 3.8554
# Epoch [ 2520/ 5000] | d_X_loss: 0.0068 | d_Y_loss: 0.0014 | g_total_loss: 3.6493
# Epoch [ 2530/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0003 | g_total_loss: 3.7953
# Epoch [ 2540/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0008 | g_total_loss: 3.6633
# Epoch [ 2550/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0021 | g_total_loss: 4.3520
# Epoch [ 2560/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0002 | g_total_loss: 3.7163
# Epoch [ 2570/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0023 | g_total_loss: 3.7316
# Epoch [ 2580/ 5000] | d_X_loss: 0.0017 | d_Y_loss: 0.0009 | g_total_loss: 3.9430
# Epoch [ 2590/ 5000] | d_X_loss: 0.0104 | d_Y_loss: 0.0019 | g_total_loss: 3.7572
# Epoch [ 2600/ 5000] | d_X_loss: 0.0036 | d_Y_loss: 0.0016 | g_total_loss: 4.1552
# Saved image_samples/sample-002600-X-Y.png
# Saved image_samples/sample-002600-Y-X.png
# Epoch [ 2610/ 5000] | d_X_loss: 0.0325 | d_Y_loss: 0.0148 | g_total_loss: 3.8923
# Epoch [ 2620/ 5000] | d_X_loss: 0.0007 | d_Y_loss: 0.0010 | g_total_loss: 3.9074
# Epoch [ 2630/ 5000] | d_X_loss: 0.0003 | d_Y_loss: 0.0001 | g_total_loss: 3.8478
# Epoch [ 2640/ 5000] | d_X_loss: 0.0039 | d_Y_loss: 0.0002 | g_total_loss: 3.7115
# Epoch [ 2650/ 5000] | d_X_loss: 0.0016 | d_Y_loss: 0.0090 | g_total_loss: 4.0492
# Epoch [ 2660/ 5000] | d_X_loss: 0.0012 | d_Y_loss: 0.0003 | g_total_loss: 3.8577
# Epoch [ 2670/ 5000] | d_X_loss: 0.0006 | d_Y_loss: 0.0051 | g_total_loss: 3.8882
# Epoch [ 2680/ 5000] | d_X_loss: 0.0005 | d_Y_loss: 0.0012 | g_total_loss: 3.9023
# Epoch [ 2690/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0022 | g_total_loss: 3.9929
# Epoch [ 2700/ 5000] | d_X_loss: 0.0029 | d_Y_loss: 0.0052 | g_total_loss: 3.8904
# Saved image_samples/sample-002700-X-Y.png
# Saved image_samples/sample-002700-Y-X.png
# Epoch [ 2710/ 5000] | d_X_loss: 0.0008 | d_Y_loss: 1.0000 | g_total_loss: 3.8349
# Epoch [ 2720/ 5000] | d_X_loss: 0.0003 | d_Y_loss: 1.0000 | g_total_loss: 3.7884
# Epoch [ 2730/ 5000] | d_X_loss: 0.0123 | d_Y_loss: 1.0000 | g_total_loss: 4.2607
# Epoch [ 2740/ 5000] | d_X_loss: 0.0004 | d_Y_loss: 1.0000 | g_total_loss: 3.8514
# Epoch [ 2750/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 1.0000 | g_total_loss: 3.7842
# Epoch [ 2760/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 1.0000 | g_total_loss: 3.8595
# Epoch [ 2770/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 1.0000 | g_total_loss: 3.7017
# Epoch [ 2780/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 1.0000 | g_total_loss: 3.9503
# Epoch [ 2790/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 1.0000 | g_total_loss: 3.6532
# Epoch [ 2800/ 5000] | d_X_loss: 0.0013 | d_Y_loss: 1.0000 | g_total_loss: 3.6320
# Saved image_samples/sample-002800-X-Y.png
# Saved image_samples/sample-002800-Y-X.png
# Epoch [ 2810/ 5000] | d_X_loss: 0.0010 | d_Y_loss: 1.0000 | g_total_loss: 3.8866
# Epoch [ 2820/ 5000] | d_X_loss: 0.0003 | d_Y_loss: 1.0000 | g_total_loss: 3.7932
# Epoch [ 2830/ 5000] | d_X_loss: 0.0157 | d_Y_loss: 1.0000 | g_total_loss: 3.7037
# Epoch [ 2840/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 1.0000 | g_total_loss: 3.7538
# Epoch [ 2850/ 5000] | d_X_loss: 0.0071 | d_Y_loss: 1.0000 | g_total_loss: 3.7023
# Epoch [ 2860/ 5000] | d_X_loss: 0.0012 | d_Y_loss: 1.0000 | g_total_loss: 3.6060
# Epoch [ 2870/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 1.0000 | g_total_loss: 3.8540
# Epoch [ 2880/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 1.0000 | g_total_loss: 3.6680
# Epoch [ 2890/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 1.0000 | g_total_loss: 3.8584
# Epoch [ 2900/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 1.0000 | g_total_loss: 3.7592
# Saved image_samples/sample-002900-X-Y.png
# Saved image_samples/sample-002900-Y-X.png
# Epoch [ 2910/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 1.0000 | g_total_loss: 3.9295
# Epoch [ 2920/ 5000] | d_X_loss: 0.0008 | d_Y_loss: 1.0000 | g_total_loss: 3.7546
# Epoch [ 2930/ 5000] | d_X_loss: 0.0028 | d_Y_loss: 1.0000 | g_total_loss: 3.9111
# Epoch [ 2940/ 5000] | d_X_loss: 0.0077 | d_Y_loss: 1.0000 | g_total_loss: 3.6169
# Epoch [ 2950/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 1.0000 | g_total_loss: 3.7963
# Epoch [ 2960/ 5000] | d_X_loss: 0.0165 | d_Y_loss: 1.0000 | g_total_loss: 3.5747
# Epoch [ 2970/ 5000] | d_X_loss: 0.0006 | d_Y_loss: 1.0000 | g_total_loss: 3.8964
# Epoch [ 2980/ 5000] | d_X_loss: 0.0029 | d_Y_loss: 1.0000 | g_total_loss: 3.6993
# Epoch [ 2990/ 5000] | d_X_loss: 0.0008 | d_Y_loss: 1.0000 | g_total_loss: 3.9055
# Epoch [ 3000/ 5000] | d_X_loss: 0.0017 | d_Y_loss: 1.0000 | g_total_loss: 3.7390
# Saved image_samples/sample-003000-X-Y.png
# Saved image_samples/sample-003000-Y-X.png
# Epoch [ 3010/ 5000] | d_X_loss: 0.0058 | d_Y_loss: 1.0000 | g_total_loss: 3.6125
# Epoch [ 3020/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 1.0000 | g_total_loss: 4.1244
# Epoch [ 3030/ 5000] | d_X_loss: 0.0132 | d_Y_loss: 1.0000 | g_total_loss: 3.4531
# Epoch [ 3040/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 1.0000 | g_total_loss: 4.4674
# Epoch [ 3050/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 1.0000 | g_total_loss: 3.6842
# Epoch [ 3060/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 1.0000 | g_total_loss: 3.6242
# Epoch [ 3070/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 1.0000 | g_total_loss: 3.7127
# Epoch [ 3080/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 1.0000 | g_total_loss: 3.7151
# Epoch [ 3090/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 1.0000 | g_total_loss: 3.5991
# Epoch [ 3100/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 1.0000 | g_total_loss: 3.7926
# Saved image_samples/sample-003100-X-Y.png
# Saved image_samples/sample-003100-Y-X.png
# Epoch [ 3110/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 1.0000 | g_total_loss: 3.7266
# Epoch [ 3120/ 5000] | d_X_loss: 0.0071 | d_Y_loss: 1.0000 | g_total_loss: 3.6004
# Epoch [ 3130/ 5000] | d_X_loss: 0.0026 | d_Y_loss: 1.0000 | g_total_loss: 3.6466
# Epoch [ 3140/ 5000] | d_X_loss: 0.0004 | d_Y_loss: 1.0000 | g_total_loss: 3.8376
# Epoch [ 3150/ 5000] | d_X_loss: 0.0016 | d_Y_loss: 1.0000 | g_total_loss: 3.8150
# Epoch [ 3160/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 1.0000 | g_total_loss: 3.5692
# Epoch [ 3170/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 1.0000 | g_total_loss: 3.7594
# Epoch [ 3180/ 5000] | d_X_loss: 0.0004 | d_Y_loss: 1.0000 | g_total_loss: 3.7016
# Epoch [ 3190/ 5000] | d_X_loss: 0.0005 | d_Y_loss: 1.0000 | g_total_loss: 3.6934
# Epoch [ 3200/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 1.0000 | g_total_loss: 3.8098
# Saved image_samples/sample-003200-X-Y.png
# Saved image_samples/sample-003200-Y-X.png
# Epoch [ 3210/ 5000] | d_X_loss: 0.0013 | d_Y_loss: 1.0000 | g_total_loss: 3.4708
# Epoch [ 3220/ 5000] | d_X_loss: 0.0008 | d_Y_loss: 1.0000 | g_total_loss: 3.7741
# Epoch [ 3230/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 1.0000 | g_total_loss: 3.7271
# Epoch [ 3240/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 1.0000 | g_total_loss: 3.6180
# Epoch [ 3250/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 1.0000 | g_total_loss: 4.1022
# Epoch [ 3260/ 5000] | d_X_loss: 0.0011 | d_Y_loss: 1.0000 | g_total_loss: 3.7051
# Epoch [ 3270/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 1.0000 | g_total_loss: 3.5409
# Epoch [ 3280/ 5000] | d_X_loss: 0.0034 | d_Y_loss: 1.0000 | g_total_loss: 3.7475
# Epoch [ 3290/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 1.0000 | g_total_loss: 3.8822
# Epoch [ 3300/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 1.0000 | g_total_loss: 3.7397
# Saved image_samples/sample-003300-X-Y.png
# Saved image_samples/sample-003300-Y-X.png
# Epoch [ 3310/ 5000] | d_X_loss: 0.0072 | d_Y_loss: 1.0000 | g_total_loss: 3.8995
# Epoch [ 3320/ 5000] | d_X_loss: 0.0024 | d_Y_loss: 1.0000 | g_total_loss: 3.6205
# Epoch [ 3330/ 5000] | d_X_loss: 0.0004 | d_Y_loss: 1.0000 | g_total_loss: 3.5603
# Epoch [ 3340/ 5000] | d_X_loss: 0.0006 | d_Y_loss: 1.0000 | g_total_loss: 3.7156
# Epoch [ 3350/ 5000] | d_X_loss: 0.0004 | d_Y_loss: 1.0000 | g_total_loss: 3.7665
# Epoch [ 3360/ 5000] | d_X_loss: 0.0014 | d_Y_loss: 1.0000 | g_total_loss: 3.6118
# Epoch [ 3370/ 5000] | d_X_loss: 0.0055 | d_Y_loss: 1.0000 | g_total_loss: 3.6666
# Epoch [ 3380/ 5000] | d_X_loss: 0.0004 | d_Y_loss: 1.0000 | g_total_loss: 3.5589
# Epoch [ 3390/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 1.0000 | g_total_loss: 3.7650
# Epoch [ 3400/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 1.0000 | g_total_loss: 3.4202
# Saved image_samples/sample-003400-X-Y.png
# Saved image_samples/sample-003400-Y-X.png
# Epoch [ 3410/ 5000] | d_X_loss: 0.9430 | d_Y_loss: 1.0000 | g_total_loss: 3.3912
# Epoch [ 3420/ 5000] | d_X_loss: 0.0327 | d_Y_loss: 1.0000 | g_total_loss: 3.6508
# Epoch [ 3430/ 5000] | d_X_loss: 0.0039 | d_Y_loss: 1.0000 | g_total_loss: 3.9385
# Epoch [ 3440/ 5000] | d_X_loss: 0.0109 | d_Y_loss: 1.0000 | g_total_loss: 3.6580
# Epoch [ 3450/ 5000] | d_X_loss: 0.2540 | d_Y_loss: 1.0000 | g_total_loss: 3.5225
# Epoch [ 3460/ 5000] | d_X_loss: 0.2544 | d_Y_loss: 1.0000 | g_total_loss: 3.5378
# Epoch [ 3470/ 5000] | d_X_loss: 0.0894 | d_Y_loss: 1.0000 | g_total_loss: 3.5535
# Epoch [ 3480/ 5000] | d_X_loss: 0.0196 | d_Y_loss: 1.0000 | g_total_loss: 3.8312
# Epoch [ 3490/ 5000] | d_X_loss: 0.0091 | d_Y_loss: 1.0000 | g_total_loss: 3.6434
# Epoch [ 3500/ 5000] | d_X_loss: 0.1029 | d_Y_loss: 1.0000 | g_total_loss: 3.7218
# Saved image_samples/sample-003500-X-Y.png
# Saved image_samples/sample-003500-Y-X.png
# Epoch [ 3510/ 5000] | d_X_loss: 0.0057 | d_Y_loss: 1.0000 | g_total_loss: 3.4711
# Epoch [ 3520/ 5000] | d_X_loss: 0.0147 | d_Y_loss: 1.0000 | g_total_loss: 3.6235
# Epoch [ 3530/ 5000] | d_X_loss: 0.0018 | d_Y_loss: 1.0000 | g_total_loss: 3.8399
# Epoch [ 3540/ 5000] | d_X_loss: 0.0068 | d_Y_loss: 1.0000 | g_total_loss: 3.5630
# Epoch [ 3550/ 5000] | d_X_loss: 0.0628 | d_Y_loss: 1.0000 | g_total_loss: 3.7973
# Epoch [ 3560/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 1.0000 | g_total_loss: 3.9158
# Epoch [ 3570/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 1.0000 | g_total_loss: 3.5259
# Epoch [ 3580/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 1.0000 | g_total_loss: 3.7407
# Epoch [ 3590/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 1.0000 | g_total_loss: 3.6162
# Epoch [ 3600/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 1.0000 | g_total_loss: 3.8619
# Saved image_samples/sample-003600-X-Y.png
# Saved image_samples/sample-003600-Y-X.png
# Epoch [ 3610/ 5000] | d_X_loss: 0.0011 | d_Y_loss: 1.0000 | g_total_loss: 3.6186
# Epoch [ 3620/ 5000] | d_X_loss: 0.0028 | d_Y_loss: 1.0000 | g_total_loss: 3.4924
# Epoch [ 3630/ 5000] | d_X_loss: 0.0014 | d_Y_loss: 1.0000 | g_total_loss: 3.5512
# Epoch [ 3640/ 5000] | d_X_loss: 0.0003 | d_Y_loss: 1.0000 | g_total_loss: 3.6499
# Epoch [ 3650/ 5000] | d_X_loss: 0.0130 | d_Y_loss: 1.0000 | g_total_loss: 3.5142
# Epoch [ 3660/ 5000] | d_X_loss: 0.0003 | d_Y_loss: 1.0000 | g_total_loss: 3.4628
# Epoch [ 3670/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 1.0000 | g_total_loss: 3.5359
# Epoch [ 3680/ 5000] | d_X_loss: 0.0029 | d_Y_loss: 1.0000 | g_total_loss: 3.5446
# Epoch [ 3690/ 5000] | d_X_loss: 0.0022 | d_Y_loss: 1.0000 | g_total_loss: 3.5077
# Epoch [ 3700/ 5000] | d_X_loss: 0.0005 | d_Y_loss: 1.0000 | g_total_loss: 3.4667
# Saved image_samples/sample-003700-X-Y.png
# Saved image_samples/sample-003700-Y-X.png
# Epoch [ 3710/ 5000] | d_X_loss: 0.0007 | d_Y_loss: 1.0000 | g_total_loss: 3.5321
# Epoch [ 3720/ 5000] | d_X_loss: 0.0033 | d_Y_loss: 1.0000 | g_total_loss: 3.6372
# Epoch [ 3730/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 1.0000 | g_total_loss: 3.6242
# Epoch [ 3740/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 1.0000 | g_total_loss: 3.6134
# Epoch [ 3750/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 1.0000 | g_total_loss: 3.6775
# Epoch [ 3760/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 1.0000 | g_total_loss: 3.8239
# Epoch [ 3770/ 5000] | d_X_loss: 0.0024 | d_Y_loss: 1.0000 | g_total_loss: 3.5602
# Epoch [ 3780/ 5000] | d_X_loss: 0.0042 | d_Y_loss: 1.0000 | g_total_loss: 3.6855
# Epoch [ 3790/ 5000] | d_X_loss: 0.0024 | d_Y_loss: 1.0000 | g_total_loss: 3.6348
# Epoch [ 3800/ 5000] | d_X_loss: 0.0015 | d_Y_loss: 1.0000 | g_total_loss: 3.6270
# Saved image_samples/sample-003800-X-Y.png
# Saved image_samples/sample-003800-Y-X.png
# Epoch [ 3810/ 5000] | d_X_loss: 0.0037 | d_Y_loss: 1.0000 | g_total_loss: 3.5049
# Epoch [ 3820/ 5000] | d_X_loss: 0.0012 | d_Y_loss: 1.0000 | g_total_loss: 3.4893
# Epoch [ 3830/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 1.0000 | g_total_loss: 3.7177
# Epoch [ 3840/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 1.0000 | g_total_loss: 3.7428
# Epoch [ 3850/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 1.0000 | g_total_loss: 3.6729
# Epoch [ 3860/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 1.0000 | g_total_loss: 3.6850
# Epoch [ 3870/ 5000] | d_X_loss: 0.0011 | d_Y_loss: 1.0000 | g_total_loss: 3.6022
# Epoch [ 3880/ 5000] | d_X_loss: 0.0010 | d_Y_loss: 1.0000 | g_total_loss: 3.5871
# Epoch [ 3890/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 1.0000 | g_total_loss: 3.4569
# Epoch [ 3900/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 1.0000 | g_total_loss: 3.5685
# Saved image_samples/sample-003900-X-Y.png
# Saved image_samples/sample-003900-Y-X.png
# Epoch [ 3910/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 1.0000 | g_total_loss: 3.7490
# Epoch [ 3920/ 5000] | d_X_loss: 0.0005 | d_Y_loss: 1.0000 | g_total_loss: 3.8501
# Epoch [ 3930/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 1.0000 | g_total_loss: 3.4376
# Epoch [ 3940/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 1.0000 | g_total_loss: 3.5716
# Epoch [ 3950/ 5000] | d_X_loss: 0.0017 | d_Y_loss: 1.0000 | g_total_loss: 3.5813
# Epoch [ 3960/ 5000] | d_X_loss: 0.0186 | d_Y_loss: 1.0000 | g_total_loss: 3.3506
# Epoch [ 3970/ 5000] | d_X_loss: 0.0034 | d_Y_loss: 1.0000 | g_total_loss: 3.5601
# Epoch [ 3980/ 5000] | d_X_loss: 0.0007 | d_Y_loss: 1.0000 | g_total_loss: 3.4080
# Epoch [ 3990/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 1.0000 | g_total_loss: 3.4789
# Epoch [ 4000/ 5000] | d_X_loss: 0.0052 | d_Y_loss: 1.0000 | g_total_loss: 3.5454
# Saved image_samples/sample-004000-X-Y.png
# Saved image_samples/sample-004000-Y-X.png
# Epoch [ 4010/ 5000] | d_X_loss: 0.0016 | d_Y_loss: 1.0000 | g_total_loss: 3.6452
# Epoch [ 4020/ 5000] | d_X_loss: 0.0006 | d_Y_loss: 1.0000 | g_total_loss: 3.3826
# Epoch [ 4030/ 5000] | d_X_loss: 0.0008 | d_Y_loss: 1.0000 | g_total_loss: 3.3786
# Epoch [ 4040/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 1.0000 | g_total_loss: 3.5800
# Epoch [ 4050/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 1.0000 | g_total_loss: 3.3968
# Epoch [ 4060/ 5000] | d_X_loss: 0.0121 | d_Y_loss: 1.0000 | g_total_loss: 3.6656
# Epoch [ 4070/ 5000] | d_X_loss: 0.0010 | d_Y_loss: 1.0000 | g_total_loss: 3.3794
# Epoch [ 4080/ 5000] | d_X_loss: 0.0017 | d_Y_loss: 1.0000 | g_total_loss: 3.3736
# Epoch [ 4090/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 1.0000 | g_total_loss: 3.7468
# Epoch [ 4100/ 5000] | d_X_loss: 0.0005 | d_Y_loss: 1.0000 | g_total_loss: 3.6345
# Saved image_samples/sample-004100-X-Y.png
# Saved image_samples/sample-004100-Y-X.png
# Epoch [ 4110/ 5000] | d_X_loss: 0.0005 | d_Y_loss: 1.0000 | g_total_loss: 3.6440
# Epoch [ 4120/ 5000] | d_X_loss: 0.0007 | d_Y_loss: 1.0000 | g_total_loss: 3.4830
# Epoch [ 4130/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 1.0000 | g_total_loss: 3.4823
# Epoch [ 4140/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 1.0000 | g_total_loss: 3.5214
# Epoch [ 4150/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 1.0000 | g_total_loss: 3.5859
# Epoch [ 4160/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 1.0000 | g_total_loss: 3.6594
# Epoch [ 4170/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 1.0000 | g_total_loss: 3.7350
# Epoch [ 4180/ 5000] | d_X_loss: 0.0006 | d_Y_loss: 1.0000 | g_total_loss: 3.4324
# Epoch [ 4190/ 5000] | d_X_loss: 0.8942 | d_Y_loss: 1.0000 | g_total_loss: 4.1302
# Epoch [ 4200/ 5000] | d_X_loss: 0.0010 | d_Y_loss: 1.0000 | g_total_loss: 3.5709
# Saved image_samples/sample-004200-X-Y.png
# Saved image_samples/sample-004200-Y-X.png
# Epoch [ 4210/ 5000] | d_X_loss: 0.1384 | d_Y_loss: 1.0000 | g_total_loss: 3.7577
# Epoch [ 4220/ 5000] | d_X_loss: 0.0217 | d_Y_loss: 1.0000 | g_total_loss: 3.7265
# Epoch [ 4230/ 5000] | d_X_loss: 0.0130 | d_Y_loss: 1.0000 | g_total_loss: 3.6847
# Epoch [ 4240/ 5000] | d_X_loss: 0.0109 | d_Y_loss: 1.0000 | g_total_loss: 3.8095
# Epoch [ 4250/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 1.0000 | g_total_loss: 3.9377
# Epoch [ 4260/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 1.0000 | g_total_loss: 3.6317
# Epoch [ 4270/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 1.0000 | g_total_loss: 3.5685
# Epoch [ 4280/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 1.0000 | g_total_loss: 3.5042
# Epoch [ 4290/ 5000] | d_X_loss: 0.0018 | d_Y_loss: 1.0000 | g_total_loss: 3.3826
# Epoch [ 4300/ 5000] | d_X_loss: 0.0193 | d_Y_loss: 1.0000 | g_total_loss: 3.4448
# Saved image_samples/sample-004300-X-Y.png
# Saved image_samples/sample-004300-Y-X.png
# Epoch [ 4310/ 5000] | d_X_loss: 0.0021 | d_Y_loss: 1.0000 | g_total_loss: 3.6941
# Epoch [ 4320/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 1.0000 | g_total_loss: 3.6624
# Epoch [ 4330/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 1.0000 | g_total_loss: 3.5289
# Epoch [ 4340/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 1.0000 | g_total_loss: 3.6336
# Epoch [ 4350/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 1.0000 | g_total_loss: 3.4638
# Epoch [ 4360/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 1.0000 | g_total_loss: 3.8055
# Epoch [ 4370/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 1.0000 | g_total_loss: 3.5461
# Epoch [ 4380/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 1.0000 | g_total_loss: 3.4469
# Epoch [ 4390/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 1.0000 | g_total_loss: 3.5122
# Epoch [ 4400/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 1.0000 | g_total_loss: 3.5316
# Saved image_samples/sample-004400-X-Y.png
# Saved image_samples/sample-004400-Y-X.png
# Epoch [ 4410/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 1.0000 | g_total_loss: 3.7063
# Epoch [ 4420/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 1.0000 | g_total_loss: 3.4491
# Epoch [ 4430/ 5000] | d_X_loss: 0.0011 | d_Y_loss: 1.0000 | g_total_loss: 3.4868
# Epoch [ 4440/ 5000] | d_X_loss: 0.0006 | d_Y_loss: 1.0000 | g_total_loss: 3.7048
# Epoch [ 4450/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 1.0000 | g_total_loss: 3.6228
# Epoch [ 4460/ 5000] | d_X_loss: 0.0007 | d_Y_loss: 1.0000 | g_total_loss: 3.4405
# Epoch [ 4470/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 1.0000 | g_total_loss: 3.4976
# Epoch [ 4480/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 1.0000 | g_total_loss: 3.5304
# Epoch [ 4490/ 5000] | d_X_loss: 0.0003 | d_Y_loss: 1.0000 | g_total_loss: 3.6513
# Epoch [ 4500/ 5000] | d_X_loss: 0.0082 | d_Y_loss: 1.0000 | g_total_loss: 3.3817
# Saved image_samples/sample-004500-X-Y.png
# Saved image_samples/sample-004500-Y-X.png
# Epoch [ 4510/ 5000] | d_X_loss: 0.0023 | d_Y_loss: 1.0000 | g_total_loss: 3.4951
# Epoch [ 4520/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 1.0000 | g_total_loss: 3.4074
# Epoch [ 4530/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 1.0000 | g_total_loss: 3.5510
# Epoch [ 4540/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 1.0000 | g_total_loss: 3.4968
# Epoch [ 4550/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 1.0000 | g_total_loss: 3.4204
# Epoch [ 4560/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 1.0000 | g_total_loss: 3.9978
# Epoch [ 4570/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 1.0000 | g_total_loss: 3.4809
# Epoch [ 4580/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 1.0000 | g_total_loss: 3.3691
# Epoch [ 4590/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 1.0000 | g_total_loss: 3.7355
# Epoch [ 4600/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 1.0000 | g_total_loss: 3.5398
# Saved image_samples/sample-004600-X-Y.png
# Saved image_samples/sample-004600-Y-X.png
# Epoch [ 4610/ 5000] | d_X_loss: 0.1078 | d_Y_loss: 1.0000 | g_total_loss: 3.4700
# Epoch [ 4620/ 5000] | d_X_loss: 0.0058 | d_Y_loss: 1.0000 | g_total_loss: 3.4010
# Epoch [ 4630/ 5000] | d_X_loss: 0.8244 | d_Y_loss: 1.0000 | g_total_loss: 3.5108
# Epoch [ 4640/ 5000] | d_X_loss: 0.1234 | d_Y_loss: 1.0000 | g_total_loss: 3.4553
# Epoch [ 4650/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 1.0000 | g_total_loss: 3.7164
# Epoch [ 4660/ 5000] | d_X_loss: 0.0640 | d_Y_loss: 1.0000 | g_total_loss: 3.5284
# Epoch [ 4670/ 5000] | d_X_loss: 0.0550 | d_Y_loss: 1.0000 | g_total_loss: 3.5972
# Epoch [ 4680/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 1.0000 | g_total_loss: 3.5135
# Epoch [ 4690/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 1.0000 | g_total_loss: 3.4579
# Epoch [ 4700/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.9999 | g_total_loss: 3.2831
# Saved image_samples/sample-004700-X-Y.png
# Saved image_samples/sample-004700-Y-X.png
# Epoch [ 4710/ 5000] | d_X_loss: 0.0138 | d_Y_loss: 1.0000 | g_total_loss: 3.5272
# Epoch [ 4720/ 5000] | d_X_loss: 0.0064 | d_Y_loss: 1.0000 | g_total_loss: 3.5947
# Epoch [ 4730/ 5000] | d_X_loss: 0.0033 | d_Y_loss: 0.9479 | g_total_loss: 3.4990
# Epoch [ 4740/ 5000] | d_X_loss: 0.0004 | d_Y_loss: 0.5722 | g_total_loss: 3.5470
# Epoch [ 4750/ 5000] | d_X_loss: 0.0012 | d_Y_loss: 0.0191 | g_total_loss: 3.6532
# Epoch [ 4760/ 5000] | d_X_loss: 0.0067 | d_Y_loss: 0.0153 | g_total_loss: 3.3741
# Epoch [ 4770/ 5000] | d_X_loss: 0.0047 | d_Y_loss: 0.0468 | g_total_loss: 3.6419
# Epoch [ 4780/ 5000] | d_X_loss: 0.0071 | d_Y_loss: 0.0429 | g_total_loss: 3.4843
# Epoch [ 4790/ 5000] | d_X_loss: 0.0057 | d_Y_loss: 0.0650 | g_total_loss: 3.6349
# Epoch [ 4800/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0015 | g_total_loss: 3.6463
# Saved image_samples/sample-004800-X-Y.png
# Saved image_samples/sample-004800-Y-X.png
# Epoch [ 4810/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0152 | g_total_loss: 3.4349
# Epoch [ 4820/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0070 | g_total_loss: 3.3738
# Epoch [ 4830/ 5000] | d_X_loss: 0.0023 | d_Y_loss: 0.0058 | g_total_loss: 3.4019
# Epoch [ 4840/ 5000] | d_X_loss: 0.0026 | d_Y_loss: 0.0057 | g_total_loss: 3.4894
# Epoch [ 4850/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0009 | g_total_loss: 3.5687
# Epoch [ 4860/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0009 | g_total_loss: 3.5074
# Epoch [ 4870/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0004 | g_total_loss: 3.4389
# Epoch [ 4880/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0003 | g_total_loss: 3.4102
# Epoch [ 4890/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0060 | g_total_loss: 3.5058
# Epoch [ 4900/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0041 | g_total_loss: 3.5268
# Saved image_samples/sample-004900-X-Y.png
# Saved image_samples/sample-004900-Y-X.png
# Epoch [ 4910/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0007 | g_total_loss: 3.4727
# Epoch [ 4920/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0032 | g_total_loss: 3.6138
# Epoch [ 4930/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0136 | g_total_loss: 3.4923
# Epoch [ 4940/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0025 | g_total_loss: 3.6492
# Epoch [ 4950/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0059 | g_total_loss: 3.5437
# Epoch [ 4960/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0200 | g_total_loss: 3.6647
# Epoch [ 4970/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0013 | g_total_loss: 3.5010
# Epoch [ 4980/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0044 | g_total_loss: 3.3227
# Epoch [ 4990/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0007 | g_total_loss: 3.4308
# Epoch [ 5000/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0050 | g_total_loss: 3.4223
# Saved image_samples/sample-005000-X-Y.png
# Saved image_samples/sample-005000-Y-X.png

# %%
print('Average D_X:', epoch_d_x_loss/500)
print('Average D_Y:', epoch_d_y_loss/500)
print('Average GANs:', epoch_g_loss/500)
# Out:
# Average D_X: 0.06551374058472907
# Average D_Y: 0.4295631342536726
# Average GANs: 4.057869992733002

# %% [markdown]
# #### Training and Loss Patterns

# %%
fig, ax = plt.subplots(figsize=(12,8))
losses = np.array(losses)
plt.plot(losses.T[0], label='Discriminator, X', alpha=0.5)
plt.plot(losses.T[1], label='Discriminator, Y', alpha=0.5)
plt.plot(losses.T[2], label='Generators', alpha=0.5)
plt.title("Training Losses")
plt.legend()

# %% [markdown]
# ### Results

# %%
import matplotlib.image as mpimg

# %%
def view_samples(iteration, sample_dir='/content/image_samples'):
    # samples are named by iteration
    path_XtoY = os.path.join(sample_dir, 'sample-{:06d}-X-Y.png'.format(iteration))
    path_YtoX = os.path.join(sample_dir, 'sample-{:06d}-Y-X.png'.format(iteration))

    # read in those samples
    x2y, y2x = None, None
    try:
        x2y = mpimg.imread(path_XtoY)
        y2x = mpimg.imread(path_YtoX)
    except:
        print('Invalid number of iterations.')

    fig, (ax1, ax2) = plt.subplots(figsize=(18,20), nrows=2, ncols=1, sharey=True, sharex=True)
    ax1.imshow(x2y)
    ax1.set_title('X to Y')
    ax2.imshow(y2x)
    ax2.set_title('Y to X')

# %%
# view samples at iteration 100
view_samples(100)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
    # view samples at iteration 5000
view_samples(5000)
# Out:
# Output hidden; open in https://colab.research.google.com to view.
