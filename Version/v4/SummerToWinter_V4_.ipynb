# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import matplotlib.pyplot as plt
import warnings
import os

# %%
import torch
from torch.utils.data import DataLoader
import torchvision
import torchvision.datasets as datasets
import torchvision.transforms as transforms
import torch.nn.functional as F
from torch import nn, optim

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = "retina"

# %% [markdown]
# ### Loading Data

# %%
from PIL import Image

def get_data_loader(image_type, image_dir='/content/drive/MyDrive/ColabNotebooks/DataSet/summer2winter', image_size=128, batch_size=16, num_workers=0):
    """returns: training and test data loaders for a given image type, either summer or winter"""

    # Resize and normalize the images
    transform = transforms.Compose([
        transforms.Resize((image_size, image_size), interpolation=Image.BICUBIC),  # Resize images to have dimensions (image_size, image_size)
        transforms.ToTensor()  # Convert images to PyTorch tensors
    ])

    # Get training and test directories
    train_path = os.path.join(image_dir, image_type)
    test_path = os.path.join(image_dir, 'test_{}'.format(image_type))

    # Define datasets using ImageFolder
    train_dataset = datasets.ImageFolder(train_path, transform)
    test_dataset = datasets.ImageFolder(test_path, transform)

    # Create and return DataLoaders
    train_loader = DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True, num_workers=num_workers)
    test_loader = DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=False, num_workers=num_workers)

    # Retrieve a sample image from the training dataset for visualization
    sample_image, _ = train_dataset[2]


    # Visualize the sample image

    # Display the raw image and transformed image side by side
    plt.figure(figsize=(12, 8))

    plt.subplot(1, 5, 2)
    plt.imshow(sample_image.permute(1, 2, 0))
    plt.title('Original Image')
    plt.axis('off')

    # Display the transformed image
    plt.subplot(1, 5, 4)
    np_image = sample_image.numpy().transpose((1, 2, 0))
    plt.imshow(np_image)
    plt.title('Transformed Image')
    plt.axis('off')

    plt.show()

    return train_loader, test_loader

# %% [markdown]
# ####Resize and Normalize Output Check

# %%
dataloader_X, test_dataloader_X = get_data_loader(image_type='summer')
dataloader_Y, test_dataloader_Y = get_data_loader(image_type='winter')

# %%
# display sample images
def imshow(img):
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))

# %%
import torch
import torchvision
import matplotlib.pyplot as plt

# Assuming dataloader_X is your DataLoader
dataiter = iter(dataloader_X)
images, _ = next(dataiter)  # Use next() directly to get the next batch

# Visualize the batch of images
fig = plt.figure(figsize=(12, 8))
imshow(torchvision.utils.make_grid(images))
plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
import torch
import torchvision
import matplotlib.pyplot as plt

# Assuming dataloader_Y is your DataLoader
dataiter = iter(dataloader_Y)

# Get the first batch from the dataloader
for images, _ in dataiter:
    break

# Visualize the batch of images
fig = plt.figure(figsize=(12, 8))
imshow(torchvision.utils.make_grid(images))
plt.show()

# %% [markdown]
# ### Building the Model

# %%
img = images[3]
print('min: ', img.min())
print('max: ', img.max())
# Out:
# min:  tensor(0.)
# max:  tensor(1.)

# %%
# Define a helper function for creating convolutional layers
def conv(in_channels, out_channels, kernel_size=4, stride=2, padding=1, batch_norm=True):
    layers = []
    conv_layer = nn.Conv2d(in_channels, out_channels, kernel_size, stride, padding, bias=False)
    layers.append(conv_layer)
    if batch_norm:
        layers.append(nn.BatchNorm2d(out_channels))
    return nn.Sequential(*layers)

# %% [markdown]
# #### Discriminator

# %%
# Discriminator Class
class Discriminator(nn.Module):
    def __init__(self, conv_dim=64):
        super(Discriminator, self).__init__()
        # Define all convolutional layers
        self.conv1 = conv(3, conv_dim, 4, stride=2, padding=1, batch_norm=False)  # 64x64x64
        self.conv2 = conv(conv_dim, conv_dim * 2, 4, stride=2, padding=1)  # 32x32x128
        self.conv3 = conv(conv_dim * 2, conv_dim * 4, 4, stride=2, padding=1)  # 16x16x256
        self.conv4 = conv(conv_dim * 4, conv_dim * 8, 4, stride=2, padding=1)  # 8x8x512
        # Final layer
        self.conv5 = nn.Conv2d(conv_dim * 8, 1, 4, stride=1, padding=0, bias=False)  # 1x1x1

    def forward(self, x):
        out = nn.ReLU()(self.conv1(x))
        out = nn.ReLU()(self.conv2(out))
        out = nn.ReLU()(self.conv3(out))
        out = nn.ReLU()(self.conv4(out))
        out = self.conv5(out)
        out = torch.sigmoid(out)  # Add sigmoid for output
        return out.view(-1)  # Flatten to 1D for output

# %%
# Residual block definition
class ResidualBlock(nn.Module):
    def __init__(self, dim):
        super(ResidualBlock, self).__init__()
        self.conv1 = conv(dim, dim, kernel_size=3, stride=1, padding=1)
        self.conv2 = conv(dim, dim, kernel_size=3, stride=1, padding=1, batch_norm=False)

    def forward(self, x):
        residual = x
        x = nn.ReLU()(self.conv1(x))
        x = self.conv2(x)
        return x + residual  # Adding residual for skip connection

# %%
def deconv(in_channels, out_channels, kernel_size=4, stride=2, padding=1, batch_norm=True):
    layers = []
    deconv_layer = nn.ConvTranspose2d(in_channels, out_channels, kernel_size, stride, padding, bias=False)
    layers.append(deconv_layer)
    if batch_norm:
        layers.append(nn.BatchNorm2d(out_channels))
    return nn.Sequential(*layers)

# %% [markdown]
# #### CycleGenerator

# %%
# CycleGenerator Class
class CycleGenerator(nn.Module):
    def __init__(self, conv_dim=64, n_res_blocks=6):
        super(CycleGenerator, self).__init__()
        # 1. Encoder
        self.conv1 = conv(3, conv_dim, 4, stride=2, padding=1)  # 128x128 -> 64x64
        self.conv2 = conv(conv_dim, conv_dim * 2, 4, stride=2, padding=1)  # 64x64 -> 32x32
        self.conv3 = conv(conv_dim * 2, conv_dim * 4, 4, stride=2, padding=1)  # 32x32 -> 16x16

        # 2. Residual blocks
        res_layers = []
        for _ in range(n_res_blocks):
            res_layers.append(ResidualBlock(conv_dim * 4))
        self.res_blocks = nn.Sequential(*res_layers)

        # 3. Decoder
        self.deconv1 = deconv(conv_dim * 4, conv_dim * 2, 4, stride=2, padding=1)  # 16x16 -> 32x32
        self.deconv2 = deconv(conv_dim * 2, conv_dim, 4, stride=2, padding=1)  # 32x32 -> 64x64
        self.deconv3 = deconv(conv_dim, 3, 4, stride=2, padding=1, batch_norm=False)  # 64x64 -> 128x128

    def forward(self, x):
        """Transforms an image and returns it."""
        out = nn.ReLU()(self.conv1(x))
        out = nn.ReLU()(self.conv2(out))
        out = nn.ReLU()(self.conv3(out))
        out = self.res_blocks(out)
        out = nn.ReLU()(self.deconv1(out))
        out = nn.ReLU()(self.deconv2(out))
        # Apply tanh activation to the final output
        out = nn.Tanh()(self.deconv3(out))
        return out

# %% [markdown]
# ### Complete Network

# %%
# Assuming CycleGenerator and Discriminator are defined elsewhere

def create_model(
    g_conv_dim=64,
    d_conv_dim=64,
    n_res_blocks=6,
    device=None
):
    """Builds and initializes generators and discriminators for CycleGAN."""
    # Assign the device if not provided
    if device is None:
        device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

    # Instantiate generators
    G_XtoY = CycleGenerator(conv_dim=g_conv_dim, n_res_blocks=n_res_blocks).to(device)
    G_YtoX = CycleGenerator(conv_dim=g_conv_dim, n_res_blocks=n_res_blocks).to(device)

    # Instantiate discriminators
    D_X = Discriminator(conv_dim=d_conv_dim).to(device)
    D_Y = Discriminator(conv_dim=d_conv_dim).to(device)

    # Log the device information
    if device.type == "cuda":
        print(f"Models moved to GPU: {torch.cuda.get_device_name(device)}.")
    else:
        print("Models using CPU.")

    # Return the initialized models
    return G_XtoY, G_YtoX, D_X, D_Y

# %%
G_XtoY, G_YtoX, D_X, D_Y = create_model()
# Out:
# Models moved to GPU: Tesla T4.

# %%
def print_models(G_XtoY, G_YtoX, D_X, D_Y):
    """Prints model information for the generators and discriminators.
    """
    print("                     G_XtoY                    ")
    print("-----------------------------------------------")
    print(G_XtoY)
    print()

    print("                     G_YtoX                    ")
    print("-----------------------------------------------")
    print(G_YtoX)
    print()

    print("                      D_X                      ")
    print("-----------------------------------------------")
    print(D_X)
    print()

    print("                      D_Y                      ")
    print("-----------------------------------------------")
    print(D_Y)
    print()


# print all of the models
print_models(G_XtoY, G_YtoX, D_X, D_Y)
# Out:
#                      G_XtoY
# -----------------------------------------------
# CycleGenerator(
#   (conv1): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv3): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (res_blocks): Sequential(
#     (0): ResidualBlock(
#       (conv1): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (1): ResidualBlock(
#       (conv1): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (2): ResidualBlock(
#       (conv1): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (3): ResidualBlock(
#       (conv1): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (4): ResidualBlock(
#       (conv1): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (5): ResidualBlock(
#       (conv1): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#   )
#   (deconv1): Sequential(
#     (0): ConvTranspose2d(256, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (deconv2): Sequential(
#     (0): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (deconv3): Sequential(
#     (0): ConvTranspose2d(64, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   )
# )
#
#                      G_YtoX
# -----------------------------------------------
# CycleGenerator(
#   (conv1): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv3): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (res_blocks): Sequential(
#     (0): ResidualBlock(
#       (conv1): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (1): ResidualBlock(
#       (conv1): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (2): ResidualBlock(
#       (conv1): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (3): ResidualBlock(
#       (conv1): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (4): ResidualBlock(
#       (conv1): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (5): ResidualBlock(
#       (conv1): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#   )
#   (deconv1): Sequential(
#     (0): ConvTranspose2d(256, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (deconv2): Sequential(
#     (0): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (deconv3): Sequential(
#     (0): ConvTranspose2d(64, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   )
# )
#
#                       D_X
# -----------------------------------------------
# Discriminator(
#   (conv1): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv3): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv4): Sequential(
#     (0): Conv2d(256, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv5): Conv2d(512, 1, kernel_size=(4, 4), stride=(1, 1), bias=False)
# )
#
#                       D_Y
# -----------------------------------------------
# Discriminator(
#   (conv1): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv3): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv4): Sequential(
#     (0): Conv2d(256, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv5): Conv2d(512, 1, kernel_size=(4, 4), stride=(1, 1), bias=False)
# )

# %% [markdown]
# #### GANs loss

# %%
def real_mse_loss(D_out):
    # how close is the produced output from being "real"?
    return torch.mean((D_out-1)**2)

# %%
def fake_mse_loss(D_out):
    # how close is the produced output from being "fake"?
    return torch.mean(D_out**2)

# %%
def cycle_consistency_loss(real_im, reconstructed_im, lambda_weight):
    # calculate reconstruction loss
    # as absolute value difference between the real and reconstructed images
    reconstr_loss = torch.mean(torch.abs(real_im - reconstructed_im))
    # return weighted loss
    return lambda_weight*reconstr_loss

# %% [markdown]
# ### Optimizers

# %%
# hyperparams for Adam optimizer
lr=0.0002
beta1=0.5
beta2=0.999 # default value

# %%
# Get generator parameters
g_params = list(G_XtoY.parameters()) + list(G_YtoX.parameters())

# %%
# Create optimizers for the generators and discriminators
g_optimizer = optim.Adam(g_params, lr, [beta1, beta2])
d_x_optimizer = optim.Adam(D_X.parameters(), lr, [beta1, beta2])
d_y_optimizer = optim.Adam(D_Y.parameters(), lr, [beta1, beta2])

# %% [markdown]
# ### Helper functions

# %%
import pdb
import pickle
import argparse
import scipy
import scipy.misc

# %%
warnings.filterwarnings("ignore")

# %%
def checkpoint(iteration, G_XtoY, G_YtoX, D_X, D_Y, checkpoint_dir='/content/drive/MyDrive/ColabNotebooks/model_checkpoints'):
    """saves the parameters of both generators G_YtoX, G_XtoY and discriminators D_X, D_Y"""
    G_XtoY_path = os.path.join(checkpoint_dir, 'G_XtoY.pkl')
    G_YtoX_path = os.path.join(checkpoint_dir, 'G_YtoX.pkl')
    D_X_path = os.path.join(checkpoint_dir, 'D_X.pkl')
    D_Y_path = os.path.join(checkpoint_dir, 'D_Y.pkl')
    torch.save(G_XtoY.state_dict(), G_XtoY_path)
    torch.save(G_YtoX.state_dict(), G_YtoX_path)
    torch.save(D_X.state_dict(), D_X_path)
    torch.save(D_Y.state_dict(), D_Y_path)

# %%
import numpy as np

def merge_images(sources, targets, batch_size=16):
    """
    Merges source and target image batches into a single image for visualization.

    Args:
    - sources (numpy array): Source images of shape (B, C, H, W).
    - targets (numpy array): Target images of shape (B, C, H, W).
    - batch_size (int): Number of images in each batch.

    Returns:
    - merged (numpy array): Merged image with source and target pairs side-by-side.
    """
    # Check if batch_size matches the number of images
    if len(sources) != batch_size or len(targets) != batch_size:
        raise ValueError("Batch size does not match the number of images in sources or targets.")

    # Get height and width from source images
    _, channels, height, width = sources.shape

    # Calculate number of rows for the merged image (square layout)
    row = int(np.sqrt(batch_size))

    # Initialize an empty array for the merged image
    # This will contain source and target pairs side-by-side
    merged = np.zeros((channels, row * height, row * width * 2))

    # Loop through the batches to fill the merged array
    for idx, (source, target) in enumerate(zip(sources, targets)):
        # Determine row and column index for placement
        row_idx = idx // row
        col_idx = idx % row

        # Place the source and target images into the merged array
        merged[:, row_idx * height:(row_idx + 1) * height, (col_idx * 2) * width:(col_idx * 2 + 1) * width] = source
        merged[:, row_idx * height:(row_idx + 1) * height, (col_idx * 2 + 1) * width:(col_idx * 2 + 2) * width] = target

    # Transpose the merged array for the correct (H, W, C) format
    merged = merged.transpose(1, 2, 0)

    return merged

# %%
def to_data(x):
    """converts variable to numpy."""
    if torch.cuda.is_available():
        x = x.cpu()
    x = x.data.numpy()
    x = ((x +1)*255 / (2)).astype(np.uint8) # rescale to 0-255
    return x

# %%
import os
import imageio
def save_samples(iteration, fixed_Y, fixed_X, G_YtoX, G_XtoY, batch_size=16, sample_dir='image_samples'):
    """saves samples from both generators X->Y and Y->X."""
    # move input data to correct device
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

    fake_X = G_YtoX(fixed_Y.to(device))
    fake_Y = G_XtoY(fixed_X.to(device))

    X, fake_X = to_data(fixed_X), to_data(fake_X)
    Y, fake_Y = to_data(fixed_Y), to_data(fake_Y)

    # Create directory if it doesn't exist
    os.makedirs(sample_dir, exist_ok=True)


    merged = merge_images(X, fake_Y, batch_size)
    merged = merged.astype(np.uint8)
    path = os.path.join(sample_dir, 'sample-{:06d}-X-Y.png'.format(iteration))
    imageio.imwrite(path, merged)
    print('Saved {}'.format(path))

    merged = merge_images(Y, fake_X, batch_size)
    merged = merged.astype(np.uint8)
    path = os.path.join(sample_dir, 'sample-{:06d}-Y-X.png'.format(iteration))
    imageio.imwrite(path, merged)
    print('Saved {}'.format(path))

# %%
def imshow(img):
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()

# %% [markdown]
# ### Training the Model

# %%
# helper scale function
def scale(x, feature_range=(-1, 1)):
    ''' Scale takes in an image x and returns that image, scaled
       with a feature_range of pixel values from -1 to 1.
       This function assumes that the input x is already scaled from 0-1.'''

    # scale from 0-1 to feature_range
    min, max = feature_range
    x = x * (max - min) + min
    return x

# %%
def unnormalize_images(images):
    """ Return tensor of images to [0:255] space from [-1:1] for plotting. """
    unnormalized = torch.zeros_like(images)
    t = transforms.Normalize(
        mean=[-0.5 / 0.5, -0.5 / 0.5, -0.5 / 0.5],
        std=[1 / 0.5, 1 / 0.5, 1 / 0.5])
    for i, image in enumerate(images):
        unnormalized[i] = t(image)*255
    return unnormalized

# %%
def training_loop(dataloader_X, dataloader_Y, test_dataloader_X, test_dataloader_Y, n_epochs=100):
    print_every=10


    # Create optimizers for the generators and discriminators
    g_optimizer = optim.Adam(g_params, lr, [beta1, beta2])
    d_x_optimizer = optim.Adam(D_X.parameters(), lr, [beta1, beta2])
    d_y_optimizer = optim.Adam(D_Y.parameters(), lr, [beta1, beta2])

    # keep track of losses over time
    losses = []

    test_iter_X = iter(test_dataloader_X)
    test_iter_Y = iter(test_dataloader_Y)

    # Get some fixed data from domains X and Y for sampling. These are images that are held
    # constant throughout training, that allow us to inspect the model's performance.
    fixed_X = next(test_iter_X)[0]
    fixed_Y = next(test_iter_Y)[0]
    fixed_X = scale(fixed_X) # make sure to scale to a range -1 to 1
    fixed_Y = scale(fixed_Y)

    # batches per epoch
    iter_X = iter(dataloader_X)
    iter_Y = iter(dataloader_Y)
    batches_per_epoch = min(len(iter_X), len(iter_Y))

    for epoch in range(1, n_epochs+1):
        # Reset iterators for each epoch
        if epoch % batches_per_epoch == 0:
            iter_X = iter(dataloader_X)
            iter_Y = iter(dataloader_Y)

        images_X, _ = next(iter_X)
        real_images = images_X
        images_X = scale(images_X) # make sure to scale to a range -1 to 1

        images_Y, _ = next(iter_Y)
        real_images = images_Y
        images_Y = scale(images_Y)

        # move images to GPU if available (otherwise stay on CPU)
        device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
        images_X = images_X.to(device)
        images_Y = images_Y.to(device)


        # ============================================
        #            TRAIN THE DISCRIMINATORS
        # ============================================

        ##   First: D_X, real and fake loss components   ##

        # Train with real images
        d_x_optimizer.zero_grad()

        # 1. Compute the discriminator losses on real images
        out_x = D_X(images_X)
        D_X_real_loss = real_mse_loss(out_x)

        # Train with fake images

        # 2. Generate fake images that look like domain X based on real images in domain Y
        fake_X = G_YtoX(images_Y)

        # 3. Compute the fake loss for D_X
        out_x = D_X(fake_X)
        D_X_fake_loss = fake_mse_loss(out_x)


        # 4. Compute the total loss and perform backprop
        d_x_loss = D_X_real_loss + D_X_fake_loss
        d_x_loss.backward()
        d_x_optimizer.step()


        ##   Second: D_Y, real and fake loss components   ##

        # Train with real images
        d_y_optimizer.zero_grad()

        # 1. Compute the discriminator losses on real images
        out_y = D_Y(images_Y)
        D_Y_real_loss = real_mse_loss(out_y)

        # Train with fake images

        # 2. Generate fake images that look like domain Y based on real images in domain X
        fake_Y = G_XtoY(images_X)

        # 3. Compute the fake loss for D_Y
        out_y = D_Y(fake_Y)
        D_Y_fake_loss = fake_mse_loss(out_y)

        # 4. Compute the total loss and perform backprop
        d_y_loss = D_Y_real_loss + D_Y_fake_loss
        d_y_loss.backward()
        d_y_optimizer.step()


        # =========================================
        #            TRAIN THE GENERATORS
        # =========================================

        ##    First: generate fake X images and reconstructed Y images    ##
        g_optimizer.zero_grad()

        # 1. Generate fake images that look like domain X based on real images in domain Y
        fake_X = G_YtoX(images_Y)

        # 2. Compute the generator loss based on domain X
        out_x = D_X(fake_X)
        g_YtoX_loss = real_mse_loss(out_x)

        # 3. Create a reconstructed y
        # 4. Compute the cycle consistency loss (the reconstruction loss)
        reconstructed_Y = G_XtoY(fake_X)

        reconstructed_y_loss = cycle_consistency_loss(images_Y, reconstructed_Y, lambda_weight=10)


        ##    Second: generate fake Y images and reconstructed X images    ##

        # 1. Generate fake images that look like domain Y based on real images in domain X
        fake_Y = G_XtoY(images_X)

        # 2. Compute the generator loss based on domain Y
        out_y = D_Y(fake_Y)
        g_XtoY_loss = real_mse_loss(out_y)

        # 3. Create a reconstructed x
        # 4. Compute the cycle consistency loss (the reconstruction loss)
        reconstructed_X = G_YtoX(fake_Y)
        reconstructed_x_loss = cycle_consistency_loss(images_X, reconstructed_X, lambda_weight=10)

        # 5. Add up all generator and reconstructed losses and perform backprop
        g_total_loss = g_YtoX_loss + g_XtoY_loss + reconstructed_y_loss + reconstructed_x_loss
        g_total_loss.backward()
        g_optimizer.step()


        # Print the log info
        if epoch % print_every == 0:

            # append real and fake discriminator losses and the generator loss
            losses.append((d_x_loss.item(), d_y_loss.item(), g_total_loss.item()))
            print('Epoch [{:5d}/{:5d}] | d_X_loss: {:6.4f} | d_Y_loss: {:6.4f} | g_total_loss: {:6.4f}'.format(
                    epoch, n_epochs, d_x_loss.item(), d_y_loss.item(), g_total_loss.item()))

             # generate image
            X_fake = G_XtoY(images_X)
            X_fake = unnormalize_images(X_fake)
            images_X = unnormalize_images(images_X)
            grid_image_real = torchvision.utils.make_grid(images_X.cpu())
            grid_image_fake = torchvision.utils.make_grid(X_fake.cpu())
            grid_image = torch.cat((grid_image_real, grid_image_fake), 1)
            saveim = np.transpose(grid_image.data.numpy().astype(np.uint8), (1, 2, 0))
            # plt.figure(figsize=(20, 10))
            # plt.imshow(saveim)
            # plt.savefig(filename + '_' + 'XtoY.jpg')

            Y_fake = G_YtoX(images_Y)
            Y_fake = unnormalize_images(Y_fake)
            images_Y = unnormalize_images(images_Y)
            grid_image_real = torchvision.utils.make_grid(images_Y.cpu())
            grid_image_fake = torchvision.utils.make_grid(Y_fake.cpu())
            grid_image = torch.cat((grid_image_real, grid_image_fake), 1)
            saveim = np.transpose(grid_image.data.numpy().astype(np.uint8), (1, 2, 0))



        sample_every=100
        # Save the generated samples
        if epoch % sample_every == 0:
            G_YtoX.eval() # set generators to eval mode for sample generation
            G_XtoY.eval()
            save_samples(epoch, fixed_Y, fixed_X, G_YtoX, G_XtoY, batch_size=16)
            G_YtoX.train()
            G_XtoY.train()

        # uncomment these lines, if you want to save your model
        checkpoint_every=1000
        # Save the model parameters
        if epoch % checkpoint_every == 0:
            checkpoint(epoch, G_XtoY, G_YtoX, D_X, D_Y)

    return losses

# %%
n_epochs = 5000
losses = training_loop(dataloader_X, dataloader_Y, test_dataloader_X, test_dataloader_Y, n_epochs=n_epochs)
# Out:
# Epoch [   10/ 5000] | d_X_loss: 0.1695 | d_Y_loss: 0.1640 | g_total_loss: 8.5028
# Epoch [   20/ 5000] | d_X_loss: 0.0588 | d_Y_loss: 0.0627 | g_total_loss: 7.1117
# Epoch [   30/ 5000] | d_X_loss: 0.4336 | d_Y_loss: 0.0356 | g_total_loss: 6.1748
# Epoch [   40/ 5000] | d_X_loss: 0.3495 | d_Y_loss: 0.0880 | g_total_loss: 6.1442
# Epoch [   50/ 5000] | d_X_loss: 0.4316 | d_Y_loss: 0.0297 | g_total_loss: 6.1197
# Epoch [   60/ 5000] | d_X_loss: 0.4164 | d_Y_loss: 0.4533 | g_total_loss: 5.4363
# Epoch [   70/ 5000] | d_X_loss: 0.1915 | d_Y_loss: 0.2720 | g_total_loss: 5.6886
# Epoch [   80/ 5000] | d_X_loss: 0.5725 | d_Y_loss: 0.2431 | g_total_loss: 5.7364
# Epoch [   90/ 5000] | d_X_loss: 0.3051 | d_Y_loss: 0.4301 | g_total_loss: 5.1069
# Epoch [  100/ 5000] | d_X_loss: 0.4070 | d_Y_loss: 0.3441 | g_total_loss: 5.4571
# Saved image_samples/sample-000100-X-Y.png
# Saved image_samples/sample-000100-Y-X.png
# Epoch [  110/ 5000] | d_X_loss: 0.3679 | d_Y_loss: 0.4761 | g_total_loss: 5.0700
# Epoch [  120/ 5000] | d_X_loss: 0.5139 | d_Y_loss: 0.4843 | g_total_loss: 5.0950
# Epoch [  130/ 5000] | d_X_loss: 0.1633 | d_Y_loss: 0.3290 | g_total_loss: 5.0412
# Epoch [  140/ 5000] | d_X_loss: 0.1534 | d_Y_loss: 0.6664 | g_total_loss: 5.0683
# Epoch [  150/ 5000] | d_X_loss: 0.2805 | d_Y_loss: 0.2007 | g_total_loss: 5.8383
# Epoch [  160/ 5000] | d_X_loss: 0.2894 | d_Y_loss: 0.3911 | g_total_loss: 4.6596
# Epoch [  170/ 5000] | d_X_loss: 0.3685 | d_Y_loss: 0.3421 | g_total_loss: 5.5558
# Epoch [  180/ 5000] | d_X_loss: 0.4107 | d_Y_loss: 0.6149 | g_total_loss: 4.9678
# Epoch [  190/ 5000] | d_X_loss: 0.1200 | d_Y_loss: 0.6632 | g_total_loss: 4.9535
# Epoch [  200/ 5000] | d_X_loss: 0.4905 | d_Y_loss: 0.2060 | g_total_loss: 5.2646
# Saved image_samples/sample-000200-X-Y.png
# Saved image_samples/sample-000200-Y-X.png
# Epoch [  210/ 5000] | d_X_loss: 0.2732 | d_Y_loss: 0.5645 | g_total_loss: 5.0381
# Epoch [  220/ 5000] | d_X_loss: 0.0830 | d_Y_loss: 0.2854 | g_total_loss: 5.1244
# Epoch [  230/ 5000] | d_X_loss: 0.2079 | d_Y_loss: 0.2492 | g_total_loss: 4.9944
# Epoch [  240/ 5000] | d_X_loss: 0.1420 | d_Y_loss: 0.2634 | g_total_loss: 4.9221
# Epoch [  250/ 5000] | d_X_loss: 0.0355 | d_Y_loss: 0.2801 | g_total_loss: 4.4762
# Epoch [  260/ 5000] | d_X_loss: 0.0897 | d_Y_loss: 0.3532 | g_total_loss: 5.0100
# Epoch [  270/ 5000] | d_X_loss: 0.3133 | d_Y_loss: 0.2639 | g_total_loss: 4.8580
# Epoch [  280/ 5000] | d_X_loss: 0.1497 | d_Y_loss: 0.2408 | g_total_loss: 4.7512
# Epoch [  290/ 5000] | d_X_loss: 0.4546 | d_Y_loss: 0.1195 | g_total_loss: 4.6732
# Epoch [  300/ 5000] | d_X_loss: 0.4453 | d_Y_loss: 0.1795 | g_total_loss: 5.0871
# Saved image_samples/sample-000300-X-Y.png
# Saved image_samples/sample-000300-Y-X.png
# Epoch [  310/ 5000] | d_X_loss: 0.0376 | d_Y_loss: 0.2948 | g_total_loss: 5.7084
# Epoch [  320/ 5000] | d_X_loss: 0.0122 | d_Y_loss: 0.2199 | g_total_loss: 5.5108
# Epoch [  330/ 5000] | d_X_loss: 0.2936 | d_Y_loss: 0.1338 | g_total_loss: 4.8478
# Epoch [  340/ 5000] | d_X_loss: 0.0294 | d_Y_loss: 0.2496 | g_total_loss: 4.9246
# Epoch [  350/ 5000] | d_X_loss: 0.0501 | d_Y_loss: 0.0658 | g_total_loss: 5.0997
# Epoch [  360/ 5000] | d_X_loss: 0.0257 | d_Y_loss: 0.2610 | g_total_loss: 5.2053
# Epoch [  370/ 5000] | d_X_loss: 0.2936 | d_Y_loss: 0.1991 | g_total_loss: 5.0654
# Epoch [  380/ 5000] | d_X_loss: 0.0082 | d_Y_loss: 0.1104 | g_total_loss: 5.3095
# Epoch [  390/ 5000] | d_X_loss: 0.0519 | d_Y_loss: 0.2953 | g_total_loss: 4.4454
# Epoch [  400/ 5000] | d_X_loss: 0.2247 | d_Y_loss: 0.3826 | g_total_loss: 5.5802
# Saved image_samples/sample-000400-X-Y.png
# Saved image_samples/sample-000400-Y-X.png
# Epoch [  410/ 5000] | d_X_loss: 0.0872 | d_Y_loss: 0.1488 | g_total_loss: 4.8623
# Epoch [  420/ 5000] | d_X_loss: 0.0893 | d_Y_loss: 0.2710 | g_total_loss: 5.0180
# Epoch [  430/ 5000] | d_X_loss: 0.0244 | d_Y_loss: 0.3008 | g_total_loss: 4.7025
# Epoch [  440/ 5000] | d_X_loss: 0.1323 | d_Y_loss: 0.1441 | g_total_loss: 4.8376
# Epoch [  450/ 5000] | d_X_loss: 0.0180 | d_Y_loss: 0.5038 | g_total_loss: 5.0590
# Epoch [  460/ 5000] | d_X_loss: 0.0423 | d_Y_loss: 0.0889 | g_total_loss: 5.5701
# Epoch [  470/ 5000] | d_X_loss: 0.1368 | d_Y_loss: 0.0358 | g_total_loss: 4.6938
# Epoch [  480/ 5000] | d_X_loss: 0.1134 | d_Y_loss: 0.0476 | g_total_loss: 4.9948
# Epoch [  490/ 5000] | d_X_loss: 0.1436 | d_Y_loss: 0.1422 | g_total_loss: 4.9812
# Epoch [  500/ 5000] | d_X_loss: 0.2590 | d_Y_loss: 0.0421 | g_total_loss: 4.6636
# Saved image_samples/sample-000500-X-Y.png
# Saved image_samples/sample-000500-Y-X.png
# Epoch [  510/ 5000] | d_X_loss: 0.1521 | d_Y_loss: 0.0706 | g_total_loss: 5.6766
# Epoch [  520/ 5000] | d_X_loss: 0.1887 | d_Y_loss: 0.0047 | g_total_loss: 4.8173
# Epoch [  530/ 5000] | d_X_loss: 0.1750 | d_Y_loss: 0.0092 | g_total_loss: 4.8487
# Epoch [  540/ 5000] | d_X_loss: 0.0712 | d_Y_loss: 0.0209 | g_total_loss: 4.8051
# Epoch [  550/ 5000] | d_X_loss: 0.1501 | d_Y_loss: 0.0616 | g_total_loss: 4.7380
# Epoch [  560/ 5000] | d_X_loss: 0.1937 | d_Y_loss: 0.0210 | g_total_loss: 4.5590
# Epoch [  570/ 5000] | d_X_loss: 0.0587 | d_Y_loss: 0.0359 | g_total_loss: 4.8159
# Epoch [  580/ 5000] | d_X_loss: 0.0640 | d_Y_loss: 0.0668 | g_total_loss: 4.9342
# Epoch [  590/ 5000] | d_X_loss: 0.0478 | d_Y_loss: 0.0703 | g_total_loss: 4.7487
# Epoch [  600/ 5000] | d_X_loss: 0.2407 | d_Y_loss: 0.2704 | g_total_loss: 4.8893
# Saved image_samples/sample-000600-X-Y.png
# Saved image_samples/sample-000600-Y-X.png
# Epoch [  610/ 5000] | d_X_loss: 0.0881 | d_Y_loss: 0.1726 | g_total_loss: 5.0185
# Epoch [  620/ 5000] | d_X_loss: 0.0832 | d_Y_loss: 0.0628 | g_total_loss: 4.8453
# Epoch [  630/ 5000] | d_X_loss: 0.0392 | d_Y_loss: 0.0048 | g_total_loss: 4.7407
# Epoch [  640/ 5000] | d_X_loss: 0.0854 | d_Y_loss: 0.0443 | g_total_loss: 4.9404
# Epoch [  650/ 5000] | d_X_loss: 0.0784 | d_Y_loss: 0.0724 | g_total_loss: 4.8860
# Epoch [  660/ 5000] | d_X_loss: 0.1862 | d_Y_loss: 0.0376 | g_total_loss: 4.9850
# Epoch [  670/ 5000] | d_X_loss: 0.0185 | d_Y_loss: 0.0599 | g_total_loss: 4.8988
# Epoch [  680/ 5000] | d_X_loss: 0.0417 | d_Y_loss: 0.0798 | g_total_loss: 4.7224
# Epoch [  690/ 5000] | d_X_loss: 0.0137 | d_Y_loss: 0.1135 | g_total_loss: 4.8012
# Epoch [  700/ 5000] | d_X_loss: 0.0381 | d_Y_loss: 0.0290 | g_total_loss: 4.5797
# Saved image_samples/sample-000700-X-Y.png
# Saved image_samples/sample-000700-Y-X.png
# Epoch [  710/ 5000] | d_X_loss: 0.0204 | d_Y_loss: 0.0995 | g_total_loss: 5.2084
# Epoch [  720/ 5000] | d_X_loss: 0.0028 | d_Y_loss: 0.0303 | g_total_loss: 5.0059
# Epoch [  730/ 5000] | d_X_loss: 0.0058 | d_Y_loss: 0.6627 | g_total_loss: 4.6668
# Epoch [  740/ 5000] | d_X_loss: 0.0494 | d_Y_loss: 0.0545 | g_total_loss: 4.6657
# Epoch [  750/ 5000] | d_X_loss: 0.0003 | d_Y_loss: 0.0955 | g_total_loss: 4.7515
# Epoch [  760/ 5000] | d_X_loss: 0.0261 | d_Y_loss: 0.1471 | g_total_loss: 5.2674
# Epoch [  770/ 5000] | d_X_loss: 0.0651 | d_Y_loss: 0.0848 | g_total_loss: 4.3391
# Epoch [  780/ 5000] | d_X_loss: 0.0062 | d_Y_loss: 0.0080 | g_total_loss: 4.9759
# Epoch [  790/ 5000] | d_X_loss: 0.0068 | d_Y_loss: 0.0490 | g_total_loss: 4.8429
# Epoch [  800/ 5000] | d_X_loss: 0.0107 | d_Y_loss: 0.0598 | g_total_loss: 4.9903
# Saved image_samples/sample-000800-X-Y.png
# Saved image_samples/sample-000800-Y-X.png
# Epoch [  810/ 5000] | d_X_loss: 0.0066 | d_Y_loss: 0.1402 | g_total_loss: 4.8973
# Epoch [  820/ 5000] | d_X_loss: 0.1631 | d_Y_loss: 0.0438 | g_total_loss: 4.1657
# Epoch [  830/ 5000] | d_X_loss: 0.0743 | d_Y_loss: 0.0328 | g_total_loss: 4.7108
# Epoch [  840/ 5000] | d_X_loss: 0.2383 | d_Y_loss: 0.0231 | g_total_loss: 4.6197
# Epoch [  850/ 5000] | d_X_loss: 0.0630 | d_Y_loss: 0.1062 | g_total_loss: 4.4605
# Epoch [  860/ 5000] | d_X_loss: 0.0275 | d_Y_loss: 0.0094 | g_total_loss: 4.6828
# Epoch [  870/ 5000] | d_X_loss: 0.1654 | d_Y_loss: 0.0435 | g_total_loss: 4.7459
# Epoch [  880/ 5000] | d_X_loss: 0.0888 | d_Y_loss: 0.1590 | g_total_loss: 4.7102
# Epoch [  890/ 5000] | d_X_loss: 0.0576 | d_Y_loss: 0.1918 | g_total_loss: 5.0677
# Epoch [  900/ 5000] | d_X_loss: 0.0399 | d_Y_loss: 0.0712 | g_total_loss: 4.7077
# Saved image_samples/sample-000900-X-Y.png
# Saved image_samples/sample-000900-Y-X.png
# Epoch [  910/ 5000] | d_X_loss: 0.0791 | d_Y_loss: 0.2767 | g_total_loss: 4.6909
# Epoch [  920/ 5000] | d_X_loss: 0.0390 | d_Y_loss: 0.0181 | g_total_loss: 4.9107
# Epoch [  930/ 5000] | d_X_loss: 0.1077 | d_Y_loss: 0.1165 | g_total_loss: 5.5599
# Epoch [  940/ 5000] | d_X_loss: 0.0419 | d_Y_loss: 0.0189 | g_total_loss: 4.9948
# Epoch [  950/ 5000] | d_X_loss: 0.0087 | d_Y_loss: 0.0032 | g_total_loss: 4.8316
# Epoch [  960/ 5000] | d_X_loss: 0.0129 | d_Y_loss: 0.0022 | g_total_loss: 4.5648
# Epoch [  970/ 5000] | d_X_loss: 0.0227 | d_Y_loss: 0.0629 | g_total_loss: 4.8050
# Epoch [  980/ 5000] | d_X_loss: 0.0139 | d_Y_loss: 0.1073 | g_total_loss: 4.5678
# Epoch [  990/ 5000] | d_X_loss: 0.0159 | d_Y_loss: 0.0774 | g_total_loss: 4.8268
# Epoch [ 1000/ 5000] | d_X_loss: 0.0080 | d_Y_loss: 0.1621 | g_total_loss: 4.8415
# Saved image_samples/sample-001000-X-Y.png
# Saved image_samples/sample-001000-Y-X.png
# Epoch [ 1010/ 5000] | d_X_loss: 0.0065 | d_Y_loss: 0.1033 | g_total_loss: 4.3075
# Epoch [ 1020/ 5000] | d_X_loss: 0.4909 | d_Y_loss: 0.0809 | g_total_loss: 4.6845
# Epoch [ 1030/ 5000] | d_X_loss: 0.0739 | d_Y_loss: 0.0358 | g_total_loss: 4.7581
# Epoch [ 1040/ 5000] | d_X_loss: 0.3092 | d_Y_loss: 0.0755 | g_total_loss: 4.8113
# Epoch [ 1050/ 5000] | d_X_loss: 0.0145 | d_Y_loss: 0.0534 | g_total_loss: 4.5537
# Epoch [ 1060/ 5000] | d_X_loss: 0.0224 | d_Y_loss: 0.1214 | g_total_loss: 4.6118
# Epoch [ 1070/ 5000] | d_X_loss: 0.0121 | d_Y_loss: 0.2486 | g_total_loss: 4.6635
# Epoch [ 1080/ 5000] | d_X_loss: 0.0691 | d_Y_loss: 0.0532 | g_total_loss: 4.4010
# Epoch [ 1090/ 5000] | d_X_loss: 0.0345 | d_Y_loss: 0.0034 | g_total_loss: 4.8679
# Epoch [ 1100/ 5000] | d_X_loss: 0.3147 | d_Y_loss: 0.0081 | g_total_loss: 4.7520
# Saved image_samples/sample-001100-X-Y.png
# Saved image_samples/sample-001100-Y-X.png
# Epoch [ 1110/ 5000] | d_X_loss: 0.0858 | d_Y_loss: 0.0496 | g_total_loss: 5.0261
# Epoch [ 1120/ 5000] | d_X_loss: 0.0408 | d_Y_loss: 0.0362 | g_total_loss: 4.7059
# Epoch [ 1130/ 5000] | d_X_loss: 0.0528 | d_Y_loss: 0.1297 | g_total_loss: 4.2783
# Epoch [ 1140/ 5000] | d_X_loss: 0.0177 | d_Y_loss: 0.3455 | g_total_loss: 4.8875
# Epoch [ 1150/ 5000] | d_X_loss: 0.0170 | d_Y_loss: 0.1072 | g_total_loss: 4.3805
# Epoch [ 1160/ 5000] | d_X_loss: 0.1023 | d_Y_loss: 0.0902 | g_total_loss: 4.3988
# Epoch [ 1170/ 5000] | d_X_loss: 0.0076 | d_Y_loss: 0.0175 | g_total_loss: 4.8321
# Epoch [ 1180/ 5000] | d_X_loss: 0.0294 | d_Y_loss: 0.0244 | g_total_loss: 5.1356
# Epoch [ 1190/ 5000] | d_X_loss: 0.0825 | d_Y_loss: 0.0643 | g_total_loss: 4.5353
# Epoch [ 1200/ 5000] | d_X_loss: 0.0194 | d_Y_loss: 0.0490 | g_total_loss: 4.4945
# Saved image_samples/sample-001200-X-Y.png
# Saved image_samples/sample-001200-Y-X.png
# Epoch [ 1210/ 5000] | d_X_loss: 0.0533 | d_Y_loss: 0.0569 | g_total_loss: 4.5042
# Epoch [ 1220/ 5000] | d_X_loss: 0.0250 | d_Y_loss: 0.0572 | g_total_loss: 4.6444
# Epoch [ 1230/ 5000] | d_X_loss: 0.0070 | d_Y_loss: 0.0226 | g_total_loss: 4.6076
# Epoch [ 1240/ 5000] | d_X_loss: 0.0023 | d_Y_loss: 0.3916 | g_total_loss: 4.6136
# Epoch [ 1250/ 5000] | d_X_loss: 0.0085 | d_Y_loss: 0.0311 | g_total_loss: 4.4126
# Epoch [ 1260/ 5000] | d_X_loss: 0.0057 | d_Y_loss: 0.1145 | g_total_loss: 4.5996
# Epoch [ 1270/ 5000] | d_X_loss: 0.1247 | d_Y_loss: 0.0815 | g_total_loss: 4.9148
# Epoch [ 1280/ 5000] | d_X_loss: 0.0164 | d_Y_loss: 0.0115 | g_total_loss: 4.5819
# Epoch [ 1290/ 5000] | d_X_loss: 0.0021 | d_Y_loss: 0.0008 | g_total_loss: 4.6840
# Epoch [ 1300/ 5000] | d_X_loss: 0.0075 | d_Y_loss: 0.0150 | g_total_loss: 4.6545
# Saved image_samples/sample-001300-X-Y.png
# Saved image_samples/sample-001300-Y-X.png
# Epoch [ 1310/ 5000] | d_X_loss: 0.0143 | d_Y_loss: 0.1128 | g_total_loss: 5.0912
# Epoch [ 1320/ 5000] | d_X_loss: 0.0158 | d_Y_loss: 0.0451 | g_total_loss: 4.2591
# Epoch [ 1330/ 5000] | d_X_loss: 0.0190 | d_Y_loss: 0.0565 | g_total_loss: 4.1540
# Epoch [ 1340/ 5000] | d_X_loss: 0.0369 | d_Y_loss: 0.0321 | g_total_loss: 4.4122
# Epoch [ 1350/ 5000] | d_X_loss: 0.0216 | d_Y_loss: 0.0282 | g_total_loss: 4.4791
# Epoch [ 1360/ 5000] | d_X_loss: 0.0129 | d_Y_loss: 0.1644 | g_total_loss: 4.4293
# Epoch [ 1370/ 5000] | d_X_loss: 0.0128 | d_Y_loss: 0.0370 | g_total_loss: 4.4020
# Epoch [ 1380/ 5000] | d_X_loss: 0.0086 | d_Y_loss: 0.0201 | g_total_loss: 4.8112
# Epoch [ 1390/ 5000] | d_X_loss: 0.1195 | d_Y_loss: 0.0658 | g_total_loss: 4.5391
# Epoch [ 1400/ 5000] | d_X_loss: 0.0666 | d_Y_loss: 0.0426 | g_total_loss: 4.5826
# Saved image_samples/sample-001400-X-Y.png
# Saved image_samples/sample-001400-Y-X.png
# Epoch [ 1410/ 5000] | d_X_loss: 0.0056 | d_Y_loss: 0.0076 | g_total_loss: 4.7742
# Epoch [ 1420/ 5000] | d_X_loss: 0.0081 | d_Y_loss: 0.0884 | g_total_loss: 4.1393
# Epoch [ 1430/ 5000] | d_X_loss: 0.0113 | d_Y_loss: 0.0658 | g_total_loss: 4.4005
# Epoch [ 1440/ 5000] | d_X_loss: 0.0084 | d_Y_loss: 0.0162 | g_total_loss: 4.3795
# Epoch [ 1450/ 5000] | d_X_loss: 0.0131 | d_Y_loss: 0.1323 | g_total_loss: 4.3878
# Epoch [ 1460/ 5000] | d_X_loss: 0.0201 | d_Y_loss: 0.0118 | g_total_loss: 4.4774
# Epoch [ 1470/ 5000] | d_X_loss: 0.0245 | d_Y_loss: 0.2944 | g_total_loss: 4.4755
# Epoch [ 1480/ 5000] | d_X_loss: 0.0143 | d_Y_loss: 0.0572 | g_total_loss: 4.4048
# Epoch [ 1490/ 5000] | d_X_loss: 0.0010 | d_Y_loss: 0.0870 | g_total_loss: 4.8026
# Epoch [ 1500/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0688 | g_total_loss: 4.7836
# Saved image_samples/sample-001500-X-Y.png
# Saved image_samples/sample-001500-Y-X.png
# Epoch [ 1510/ 5000] | d_X_loss: 0.0005 | d_Y_loss: 0.0101 | g_total_loss: 4.9394
# Epoch [ 1520/ 5000] | d_X_loss: 0.0035 | d_Y_loss: 0.0586 | g_total_loss: 4.4891
# Epoch [ 1530/ 5000] | d_X_loss: 0.0006 | d_Y_loss: 0.0040 | g_total_loss: 4.4448
# Epoch [ 1540/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 0.0096 | g_total_loss: 4.4235
# Epoch [ 1550/ 5000] | d_X_loss: 0.0016 | d_Y_loss: 0.0837 | g_total_loss: 4.3027
# Epoch [ 1560/ 5000] | d_X_loss: 0.0159 | d_Y_loss: 0.1340 | g_total_loss: 4.0863
# Epoch [ 1570/ 5000] | d_X_loss: 0.0047 | d_Y_loss: 0.0561 | g_total_loss: 4.6775
# Epoch [ 1580/ 5000] | d_X_loss: 0.0076 | d_Y_loss: 0.0314 | g_total_loss: 4.6820
# Epoch [ 1590/ 5000] | d_X_loss: 0.0044 | d_Y_loss: 0.0432 | g_total_loss: 4.6332
# Epoch [ 1600/ 5000] | d_X_loss: 0.0309 | d_Y_loss: 0.2173 | g_total_loss: 4.4042
# Saved image_samples/sample-001600-X-Y.png
# Saved image_samples/sample-001600-Y-X.png
# Epoch [ 1610/ 5000] | d_X_loss: 0.0113 | d_Y_loss: 0.2567 | g_total_loss: 4.3537
# Epoch [ 1620/ 5000] | d_X_loss: 0.0122 | d_Y_loss: 0.0168 | g_total_loss: 4.6394
# Epoch [ 1630/ 5000] | d_X_loss: 0.0054 | d_Y_loss: 0.0346 | g_total_loss: 4.6174
# Epoch [ 1640/ 5000] | d_X_loss: 0.0248 | d_Y_loss: 0.0720 | g_total_loss: 4.3802
# Epoch [ 1650/ 5000] | d_X_loss: 0.1214 | d_Y_loss: 0.0212 | g_total_loss: 4.6382
# Epoch [ 1660/ 5000] | d_X_loss: 0.0081 | d_Y_loss: 0.0444 | g_total_loss: 4.3457
# Epoch [ 1670/ 5000] | d_X_loss: 0.0147 | d_Y_loss: 0.0440 | g_total_loss: 4.2947
# Epoch [ 1680/ 5000] | d_X_loss: 0.0340 | d_Y_loss: 0.0283 | g_total_loss: 4.3674
# Epoch [ 1690/ 5000] | d_X_loss: 0.0254 | d_Y_loss: 0.0299 | g_total_loss: 4.3114
# Epoch [ 1700/ 5000] | d_X_loss: 0.0476 | d_Y_loss: 0.0456 | g_total_loss: 4.3565
# Saved image_samples/sample-001700-X-Y.png
# Saved image_samples/sample-001700-Y-X.png
# Epoch [ 1710/ 5000] | d_X_loss: 0.0167 | d_Y_loss: 0.0088 | g_total_loss: 4.4465
# Epoch [ 1720/ 5000] | d_X_loss: 0.0179 | d_Y_loss: 0.0203 | g_total_loss: 4.4971
# Epoch [ 1730/ 5000] | d_X_loss: 0.0580 | d_Y_loss: 0.0145 | g_total_loss: 4.3762
# Epoch [ 1740/ 5000] | d_X_loss: 0.0087 | d_Y_loss: 0.0682 | g_total_loss: 4.4122
# Epoch [ 1750/ 5000] | d_X_loss: 0.0566 | d_Y_loss: 0.0269 | g_total_loss: 4.4665
# Epoch [ 1760/ 5000] | d_X_loss: 0.0078 | d_Y_loss: 0.0481 | g_total_loss: 4.6402
# Epoch [ 1770/ 5000] | d_X_loss: 0.0166 | d_Y_loss: 0.0204 | g_total_loss: 4.5234
# Epoch [ 1780/ 5000] | d_X_loss: 0.0003 | d_Y_loss: 0.0011 | g_total_loss: 5.0983
# Epoch [ 1790/ 5000] | d_X_loss: 0.0047 | d_Y_loss: 0.0004 | g_total_loss: 4.4530
# Epoch [ 1800/ 5000] | d_X_loss: 0.0157 | d_Y_loss: 0.0008 | g_total_loss: 4.6334
# Saved image_samples/sample-001800-X-Y.png
# Saved image_samples/sample-001800-Y-X.png
# Epoch [ 1810/ 5000] | d_X_loss: 0.0190 | d_Y_loss: 0.0009 | g_total_loss: 4.8221
# Epoch [ 1820/ 5000] | d_X_loss: 0.0128 | d_Y_loss: 0.0145 | g_total_loss: 4.5457
# Epoch [ 1830/ 5000] | d_X_loss: 0.0333 | d_Y_loss: 0.0064 | g_total_loss: 4.2949
# Epoch [ 1840/ 5000] | d_X_loss: 0.0160 | d_Y_loss: 0.0152 | g_total_loss: 4.4825
# Epoch [ 1850/ 5000] | d_X_loss: 0.0054 | d_Y_loss: 0.0108 | g_total_loss: 4.6915
# Epoch [ 1860/ 5000] | d_X_loss: 0.0055 | d_Y_loss: 0.0306 | g_total_loss: 4.6259
# Epoch [ 1870/ 5000] | d_X_loss: 0.0766 | d_Y_loss: 0.0228 | g_total_loss: 4.2826
# Epoch [ 1880/ 5000] | d_X_loss: 0.0078 | d_Y_loss: 0.0099 | g_total_loss: 4.5135
# Epoch [ 1890/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 0.0008 | g_total_loss: 4.4766
# Epoch [ 1900/ 5000] | d_X_loss: 0.0006 | d_Y_loss: 0.0128 | g_total_loss: 4.5430
# Saved image_samples/sample-001900-X-Y.png
# Saved image_samples/sample-001900-Y-X.png
# Epoch [ 1910/ 5000] | d_X_loss: 0.0010 | d_Y_loss: 0.0563 | g_total_loss: 4.5853
# Epoch [ 1920/ 5000] | d_X_loss: 0.0044 | d_Y_loss: 0.0388 | g_total_loss: 4.3101
# Epoch [ 1930/ 5000] | d_X_loss: 0.0049 | d_Y_loss: 0.0297 | g_total_loss: 4.6966
# Epoch [ 1940/ 5000] | d_X_loss: 0.0029 | d_Y_loss: 0.2843 | g_total_loss: 4.3897
# Epoch [ 1950/ 5000] | d_X_loss: 0.0016 | d_Y_loss: 0.0245 | g_total_loss: 4.2658
# Epoch [ 1960/ 5000] | d_X_loss: 0.0116 | d_Y_loss: 0.0365 | g_total_loss: 4.3230
# Epoch [ 1970/ 5000] | d_X_loss: 0.0155 | d_Y_loss: 0.0847 | g_total_loss: 4.5316
# Epoch [ 1980/ 5000] | d_X_loss: 0.0140 | d_Y_loss: 0.0127 | g_total_loss: 4.4395
# Epoch [ 1990/ 5000] | d_X_loss: 0.0243 | d_Y_loss: 0.0365 | g_total_loss: 4.4559
# Epoch [ 2000/ 5000] | d_X_loss: 0.0179 | d_Y_loss: 0.0172 | g_total_loss: 4.1809
# Saved image_samples/sample-002000-X-Y.png
# Saved image_samples/sample-002000-Y-X.png
# Epoch [ 2010/ 5000] | d_X_loss: 0.0076 | d_Y_loss: 0.0693 | g_total_loss: 4.8387
# Epoch [ 2020/ 5000] | d_X_loss: 0.0464 | d_Y_loss: 0.0649 | g_total_loss: 4.3963
# Epoch [ 2030/ 5000] | d_X_loss: 0.0079 | d_Y_loss: 0.0599 | g_total_loss: 4.3773
# Epoch [ 2040/ 5000] | d_X_loss: 0.1455 | d_Y_loss: 0.0060 | g_total_loss: 4.6749
# Epoch [ 2050/ 5000] | d_X_loss: 0.0178 | d_Y_loss: 0.0200 | g_total_loss: 5.0487
# Epoch [ 2060/ 5000] | d_X_loss: 0.0234 | d_Y_loss: 0.0159 | g_total_loss: 4.2922
# Epoch [ 2070/ 5000] | d_X_loss: 0.0137 | d_Y_loss: 0.0181 | g_total_loss: 4.4023
# Epoch [ 2080/ 5000] | d_X_loss: 0.0019 | d_Y_loss: 0.0010 | g_total_loss: 4.5559
# Epoch [ 2090/ 5000] | d_X_loss: 0.0083 | d_Y_loss: 0.0005 | g_total_loss: 4.5431
# Epoch [ 2100/ 5000] | d_X_loss: 0.0026 | d_Y_loss: 0.0001 | g_total_loss: 4.4572
# Saved image_samples/sample-002100-X-Y.png
# Saved image_samples/sample-002100-Y-X.png
# Epoch [ 2110/ 5000] | d_X_loss: 0.0108 | d_Y_loss: 0.0002 | g_total_loss: 4.2026
# Epoch [ 2120/ 5000] | d_X_loss: 0.0172 | d_Y_loss: 0.0008 | g_total_loss: 4.1748
# Epoch [ 2130/ 5000] | d_X_loss: 0.0039 | d_Y_loss: 0.0021 | g_total_loss: 4.1048
# Epoch [ 2140/ 5000] | d_X_loss: 0.0091 | d_Y_loss: 0.0060 | g_total_loss: 4.3963
# Epoch [ 2150/ 5000] | d_X_loss: 0.0053 | d_Y_loss: 0.0116 | g_total_loss: 4.3247
# Epoch [ 2160/ 5000] | d_X_loss: 0.0048 | d_Y_loss: 0.0128 | g_total_loss: 4.4075
# Epoch [ 2170/ 5000] | d_X_loss: 0.0031 | d_Y_loss: 0.0260 | g_total_loss: 4.5734
# Epoch [ 2180/ 5000] | d_X_loss: 0.0045 | d_Y_loss: 0.0274 | g_total_loss: 4.1369
# Epoch [ 2190/ 5000] | d_X_loss: 0.0029 | d_Y_loss: 0.0154 | g_total_loss: 4.4461
# Epoch [ 2200/ 5000] | d_X_loss: 0.0033 | d_Y_loss: 0.0212 | g_total_loss: 4.3699
# Saved image_samples/sample-002200-X-Y.png
# Saved image_samples/sample-002200-Y-X.png
# Epoch [ 2210/ 5000] | d_X_loss: 0.0015 | d_Y_loss: 0.0212 | g_total_loss: 4.1076
# Epoch [ 2220/ 5000] | d_X_loss: 0.0035 | d_Y_loss: 0.0135 | g_total_loss: 4.2125
# Epoch [ 2230/ 5000] | d_X_loss: 0.0047 | d_Y_loss: 0.0722 | g_total_loss: 3.9354
# Epoch [ 2240/ 5000] | d_X_loss: 0.0029 | d_Y_loss: 0.0231 | g_total_loss: 4.7636
# Epoch [ 2250/ 5000] | d_X_loss: 0.0057 | d_Y_loss: 0.0594 | g_total_loss: 4.3024
# Epoch [ 2260/ 5000] | d_X_loss: 0.0071 | d_Y_loss: 0.0215 | g_total_loss: 4.5562
# Epoch [ 2270/ 5000] | d_X_loss: 0.0105 | d_Y_loss: 0.0154 | g_total_loss: 4.3689
# Epoch [ 2280/ 5000] | d_X_loss: 0.0040 | d_Y_loss: 0.0220 | g_total_loss: 4.5084
# Epoch [ 2290/ 5000] | d_X_loss: 0.0026 | d_Y_loss: 0.0181 | g_total_loss: 4.4696
# Epoch [ 2300/ 5000] | d_X_loss: 0.0014 | d_Y_loss: 0.0071 | g_total_loss: 4.1667
# Saved image_samples/sample-002300-X-Y.png
# Saved image_samples/sample-002300-Y-X.png
# Epoch [ 2310/ 5000] | d_X_loss: 0.0379 | d_Y_loss: 0.0257 | g_total_loss: 4.6993
# Epoch [ 2320/ 5000] | d_X_loss: 0.0805 | d_Y_loss: 0.0204 | g_total_loss: 4.3033
# Epoch [ 2330/ 5000] | d_X_loss: 0.1093 | d_Y_loss: 0.0337 | g_total_loss: 4.2049
# Epoch [ 2340/ 5000] | d_X_loss: 0.0134 | d_Y_loss: 0.0903 | g_total_loss: 4.1461
# Epoch [ 2350/ 5000] | d_X_loss: 0.0148 | d_Y_loss: 0.0613 | g_total_loss: 4.3270
# Epoch [ 2360/ 5000] | d_X_loss: 0.0335 | d_Y_loss: 0.0545 | g_total_loss: 4.2305
# Epoch [ 2370/ 5000] | d_X_loss: 0.0004 | d_Y_loss: 0.1056 | g_total_loss: 4.1835
# Epoch [ 2380/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 0.0181 | g_total_loss: 4.1191
# Epoch [ 2390/ 5000] | d_X_loss: 0.0015 | d_Y_loss: 0.0384 | g_total_loss: 4.1928
# Epoch [ 2400/ 5000] | d_X_loss: 0.0101 | d_Y_loss: 0.0370 | g_total_loss: 4.0810
# Saved image_samples/sample-002400-X-Y.png
# Saved image_samples/sample-002400-Y-X.png
# Epoch [ 2410/ 5000] | d_X_loss: 0.0438 | d_Y_loss: 0.0219 | g_total_loss: 4.4099
# Epoch [ 2420/ 5000] | d_X_loss: 0.0231 | d_Y_loss: 0.0277 | g_total_loss: 3.9250
# Epoch [ 2430/ 5000] | d_X_loss: 0.0130 | d_Y_loss: 0.0076 | g_total_loss: 4.3451
# Epoch [ 2440/ 5000] | d_X_loss: 0.0051 | d_Y_loss: 0.0133 | g_total_loss: 4.4065
# Epoch [ 2450/ 5000] | d_X_loss: 0.0115 | d_Y_loss: 0.0065 | g_total_loss: 4.0349
# Epoch [ 2460/ 5000] | d_X_loss: 0.0155 | d_Y_loss: 0.0106 | g_total_loss: 4.4500
# Epoch [ 2470/ 5000] | d_X_loss: 0.0082 | d_Y_loss: 0.0142 | g_total_loss: 4.1340
# Epoch [ 2480/ 5000] | d_X_loss: 0.0052 | d_Y_loss: 0.0307 | g_total_loss: 4.3724
# Epoch [ 2490/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 0.0445 | g_total_loss: 4.5020
# Epoch [ 2500/ 5000] | d_X_loss: 0.0046 | d_Y_loss: 0.0268 | g_total_loss: 4.1582
# Saved image_samples/sample-002500-X-Y.png
# Saved image_samples/sample-002500-Y-X.png
# Epoch [ 2510/ 5000] | d_X_loss: 0.0016 | d_Y_loss: 0.0278 | g_total_loss: 4.4069
# Epoch [ 2520/ 5000] | d_X_loss: 0.0003 | d_Y_loss: 0.0198 | g_total_loss: 4.2574
# Epoch [ 2530/ 5000] | d_X_loss: 0.0019 | d_Y_loss: 0.0290 | g_total_loss: 4.6862
# Epoch [ 2540/ 5000] | d_X_loss: 0.0056 | d_Y_loss: 0.0263 | g_total_loss: 4.2768
# Epoch [ 2550/ 5000] | d_X_loss: 0.0007 | d_Y_loss: 0.0855 | g_total_loss: 4.0228
# Epoch [ 2560/ 5000] | d_X_loss: 0.0067 | d_Y_loss: 0.0451 | g_total_loss: 4.6802
# Epoch [ 2570/ 5000] | d_X_loss: 0.0004 | d_Y_loss: 0.0085 | g_total_loss: 4.2621
# Epoch [ 2580/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0142 | g_total_loss: 4.2268
# Epoch [ 2590/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0259 | g_total_loss: 4.1860
# Epoch [ 2600/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 0.0234 | g_total_loss: 4.0527
# Saved image_samples/sample-002600-X-Y.png
# Saved image_samples/sample-002600-Y-X.png
# Epoch [ 2610/ 5000] | d_X_loss: 0.0019 | d_Y_loss: 0.0347 | g_total_loss: 4.0646
# Epoch [ 2620/ 5000] | d_X_loss: 0.0158 | d_Y_loss: 0.0437 | g_total_loss: 3.9875
# Epoch [ 2630/ 5000] | d_X_loss: 0.0020 | d_Y_loss: 0.0133 | g_total_loss: 4.1227
# Epoch [ 2640/ 5000] | d_X_loss: 0.0082 | d_Y_loss: 0.0173 | g_total_loss: 4.4386
# Epoch [ 2650/ 5000] | d_X_loss: 0.0023 | d_Y_loss: 0.0293 | g_total_loss: 4.0536
# Epoch [ 2660/ 5000] | d_X_loss: 0.0015 | d_Y_loss: 0.0076 | g_total_loss: 4.2729
# Epoch [ 2670/ 5000] | d_X_loss: 0.0041 | d_Y_loss: 0.0342 | g_total_loss: 4.4608
# Epoch [ 2680/ 5000] | d_X_loss: 0.0021 | d_Y_loss: 0.0051 | g_total_loss: 3.9431
# Epoch [ 2690/ 5000] | d_X_loss: 0.0065 | d_Y_loss: 0.0063 | g_total_loss: 4.6272
# Epoch [ 2700/ 5000] | d_X_loss: 0.0004 | d_Y_loss: 0.0110 | g_total_loss: 4.4663
# Saved image_samples/sample-002700-X-Y.png
# Saved image_samples/sample-002700-Y-X.png
# Epoch [ 2710/ 5000] | d_X_loss: 0.0007 | d_Y_loss: 0.0072 | g_total_loss: 5.2829
# Epoch [ 2720/ 5000] | d_X_loss: 0.0039 | d_Y_loss: 0.0173 | g_total_loss: 4.0790
# Epoch [ 2730/ 5000] | d_X_loss: 0.0077 | d_Y_loss: 0.0123 | g_total_loss: 4.2707
# Epoch [ 2740/ 5000] | d_X_loss: 0.0014 | d_Y_loss: 0.0112 | g_total_loss: 4.2371
# Epoch [ 2750/ 5000] | d_X_loss: 0.0058 | d_Y_loss: 0.0103 | g_total_loss: 3.9804
# Epoch [ 2760/ 5000] | d_X_loss: 0.0077 | d_Y_loss: 0.1181 | g_total_loss: 4.0487
# Epoch [ 2770/ 5000] | d_X_loss: 0.0035 | d_Y_loss: 0.0083 | g_total_loss: 4.2528
# Epoch [ 2780/ 5000] | d_X_loss: 0.0150 | d_Y_loss: 0.0041 | g_total_loss: 4.4208
# Epoch [ 2790/ 5000] | d_X_loss: 0.0462 | d_Y_loss: 0.0209 | g_total_loss: 4.3853
# Epoch [ 2800/ 5000] | d_X_loss: 0.2142 | d_Y_loss: 0.0047 | g_total_loss: 3.7690
# Saved image_samples/sample-002800-X-Y.png
# Saved image_samples/sample-002800-Y-X.png
# Epoch [ 2810/ 5000] | d_X_loss: 0.0328 | d_Y_loss: 0.0227 | g_total_loss: 4.7212
# Epoch [ 2820/ 5000] | d_X_loss: 0.0046 | d_Y_loss: 0.0181 | g_total_loss: 4.1818
# Epoch [ 2830/ 5000] | d_X_loss: 0.0059 | d_Y_loss: 0.0015 | g_total_loss: 5.2173
# Epoch [ 2840/ 5000] | d_X_loss: 0.0003 | d_Y_loss: 0.0029 | g_total_loss: 4.7231
# Epoch [ 2850/ 5000] | d_X_loss: 0.0035 | d_Y_loss: 0.0236 | g_total_loss: 4.5650
# Epoch [ 2860/ 5000] | d_X_loss: 0.0012 | d_Y_loss: 0.0090 | g_total_loss: 4.3227
# Epoch [ 2870/ 5000] | d_X_loss: 0.0194 | d_Y_loss: 0.0108 | g_total_loss: 4.4402
# Epoch [ 2880/ 5000] | d_X_loss: 0.0003 | d_Y_loss: 0.0133 | g_total_loss: 4.2150
# Epoch [ 2890/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0327 | g_total_loss: 4.0420
# Epoch [ 2900/ 5000] | d_X_loss: 0.0010 | d_Y_loss: 0.0073 | g_total_loss: 4.0599
# Saved image_samples/sample-002900-X-Y.png
# Saved image_samples/sample-002900-Y-X.png
# Epoch [ 2910/ 5000] | d_X_loss: 0.0055 | d_Y_loss: 0.0400 | g_total_loss: 4.3027
# Epoch [ 2920/ 5000] | d_X_loss: 0.0028 | d_Y_loss: 0.0201 | g_total_loss: 4.1914
# Epoch [ 2930/ 5000] | d_X_loss: 0.0018 | d_Y_loss: 0.0075 | g_total_loss: 4.2161
# Epoch [ 2940/ 5000] | d_X_loss: 0.0330 | d_Y_loss: 0.0326 | g_total_loss: 4.1857
# Epoch [ 2950/ 5000] | d_X_loss: 0.0065 | d_Y_loss: 0.0322 | g_total_loss: 4.2381
# Epoch [ 2960/ 5000] | d_X_loss: 0.0008 | d_Y_loss: 0.0131 | g_total_loss: 4.8868
# Epoch [ 2970/ 5000] | d_X_loss: 0.0073 | d_Y_loss: 0.0086 | g_total_loss: 3.9909
# Epoch [ 2980/ 5000] | d_X_loss: 0.0074 | d_Y_loss: 0.0071 | g_total_loss: 4.2748
# Epoch [ 2990/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 0.0260 | g_total_loss: 4.1377
# Epoch [ 3000/ 5000] | d_X_loss: 0.0034 | d_Y_loss: 0.0098 | g_total_loss: 4.2107
# Saved image_samples/sample-003000-X-Y.png
# Saved image_samples/sample-003000-Y-X.png
# Epoch [ 3010/ 5000] | d_X_loss: 0.0074 | d_Y_loss: 0.3096 | g_total_loss: 3.7824
# Epoch [ 3020/ 5000] | d_X_loss: 0.0115 | d_Y_loss: 0.0745 | g_total_loss: 4.3337
# Epoch [ 3030/ 5000] | d_X_loss: 0.0024 | d_Y_loss: 0.0554 | g_total_loss: 4.0947
# Epoch [ 3040/ 5000] | d_X_loss: 0.0030 | d_Y_loss: 0.0241 | g_total_loss: 4.2592
# Epoch [ 3050/ 5000] | d_X_loss: 0.0029 | d_Y_loss: 0.0116 | g_total_loss: 4.2750
# Epoch [ 3060/ 5000] | d_X_loss: 0.0042 | d_Y_loss: 0.0092 | g_total_loss: 4.1368
# Epoch [ 3070/ 5000] | d_X_loss: 0.0043 | d_Y_loss: 0.0686 | g_total_loss: 4.1530
# Epoch [ 3080/ 5000] | d_X_loss: 0.0085 | d_Y_loss: 0.0223 | g_total_loss: 3.9797
# Epoch [ 3090/ 5000] | d_X_loss: 0.0007 | d_Y_loss: 0.0165 | g_total_loss: 4.2407
# Epoch [ 3100/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0200 | g_total_loss: 4.1079
# Saved image_samples/sample-003100-X-Y.png
# Saved image_samples/sample-003100-Y-X.png
# Epoch [ 3110/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0217 | g_total_loss: 3.8688
# Epoch [ 3120/ 5000] | d_X_loss: 0.0008 | d_Y_loss: 0.0305 | g_total_loss: 4.0684
# Epoch [ 3130/ 5000] | d_X_loss: 0.0011 | d_Y_loss: 0.0087 | g_total_loss: 4.2401
# Epoch [ 3140/ 5000] | d_X_loss: 0.0014 | d_Y_loss: 0.0068 | g_total_loss: 3.9834
# Epoch [ 3150/ 5000] | d_X_loss: 0.0026 | d_Y_loss: 0.0192 | g_total_loss: 4.0884
# Epoch [ 3160/ 5000] | d_X_loss: 0.0079 | d_Y_loss: 0.0128 | g_total_loss: 4.2596
# Epoch [ 3170/ 5000] | d_X_loss: 0.0005 | d_Y_loss: 0.0135 | g_total_loss: 4.1888
# Epoch [ 3180/ 5000] | d_X_loss: 0.0042 | d_Y_loss: 0.0075 | g_total_loss: 4.3315
# Epoch [ 3190/ 5000] | d_X_loss: 0.0007 | d_Y_loss: 0.0054 | g_total_loss: 4.1256
# Epoch [ 3200/ 5000] | d_X_loss: 0.0037 | d_Y_loss: 0.0090 | g_total_loss: 4.0058
# Saved image_samples/sample-003200-X-Y.png
# Saved image_samples/sample-003200-Y-X.png
# Epoch [ 3210/ 5000] | d_X_loss: 0.0010 | d_Y_loss: 0.0099 | g_total_loss: 4.0265
# Epoch [ 3220/ 5000] | d_X_loss: 0.0020 | d_Y_loss: 0.0031 | g_total_loss: 4.1817
# Epoch [ 3230/ 5000] | d_X_loss: 0.0068 | d_Y_loss: 0.0117 | g_total_loss: 4.0064
# Epoch [ 3240/ 5000] | d_X_loss: 0.0009 | d_Y_loss: 0.0113 | g_total_loss: 4.1200
# Epoch [ 3250/ 5000] | d_X_loss: 0.0040 | d_Y_loss: 0.0204 | g_total_loss: 3.9936
# Epoch [ 3260/ 5000] | d_X_loss: 0.0016 | d_Y_loss: 0.0114 | g_total_loss: 3.9228
# Epoch [ 3270/ 5000] | d_X_loss: 0.0032 | d_Y_loss: 0.0193 | g_total_loss: 4.4943
# Epoch [ 3280/ 5000] | d_X_loss: 0.0016 | d_Y_loss: 0.0062 | g_total_loss: 3.9805
# Epoch [ 3290/ 5000] | d_X_loss: 0.0003 | d_Y_loss: 0.0602 | g_total_loss: 4.6631
# Epoch [ 3300/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0086 | g_total_loss: 4.4934
# Saved image_samples/sample-003300-X-Y.png
# Saved image_samples/sample-003300-Y-X.png
# Epoch [ 3310/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0213 | g_total_loss: 4.3915
# Epoch [ 3320/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0194 | g_total_loss: 4.0304
# Epoch [ 3330/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0122 | g_total_loss: 3.9969
# Epoch [ 3340/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0108 | g_total_loss: 4.2506
# Epoch [ 3350/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0104 | g_total_loss: 3.9669
# Epoch [ 3360/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0287 | g_total_loss: 4.2417
# Epoch [ 3370/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0194 | g_total_loss: 4.2636
# Epoch [ 3380/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0093 | g_total_loss: 4.2070
# Epoch [ 3390/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0087 | g_total_loss: 4.0195
# Epoch [ 3400/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0223 | g_total_loss: 4.1382
# Saved image_samples/sample-003400-X-Y.png
# Saved image_samples/sample-003400-Y-X.png
# Epoch [ 3410/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 0.0204 | g_total_loss: 4.3347
# Epoch [ 3420/ 5000] | d_X_loss: 0.0004 | d_Y_loss: 0.0042 | g_total_loss: 4.2094
# Epoch [ 3430/ 5000] | d_X_loss: 0.0004 | d_Y_loss: 0.0172 | g_total_loss: 4.0167
# Epoch [ 3440/ 5000] | d_X_loss: 0.0003 | d_Y_loss: 0.0075 | g_total_loss: 4.1318
# Epoch [ 3450/ 5000] | d_X_loss: 0.0029 | d_Y_loss: 0.0073 | g_total_loss: 4.0692
# Epoch [ 3460/ 5000] | d_X_loss: 0.0024 | d_Y_loss: 0.0133 | g_total_loss: 4.1685
# Epoch [ 3470/ 5000] | d_X_loss: 0.0005 | d_Y_loss: 0.0239 | g_total_loss: 4.0701
# Epoch [ 3480/ 5000] | d_X_loss: 0.0021 | d_Y_loss: 0.0078 | g_total_loss: 4.2158
# Epoch [ 3490/ 5000] | d_X_loss: 0.0015 | d_Y_loss: 0.0300 | g_total_loss: 4.2162
# Epoch [ 3500/ 5000] | d_X_loss: 0.0018 | d_Y_loss: 0.1177 | g_total_loss: 4.1897
# Saved image_samples/sample-003500-X-Y.png
# Saved image_samples/sample-003500-Y-X.png
# Epoch [ 3510/ 5000] | d_X_loss: 0.0020 | d_Y_loss: 0.0226 | g_total_loss: 3.9366
# Epoch [ 3520/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0474 | g_total_loss: 3.8586
# Epoch [ 3530/ 5000] | d_X_loss: 0.0011 | d_Y_loss: 0.0473 | g_total_loss: 4.1495
# Epoch [ 3540/ 5000] | d_X_loss: 0.0012 | d_Y_loss: 0.0147 | g_total_loss: 4.0840
# Epoch [ 3550/ 5000] | d_X_loss: 0.0004 | d_Y_loss: 0.0082 | g_total_loss: 4.0298
# Epoch [ 3560/ 5000] | d_X_loss: 0.0044 | d_Y_loss: 0.0155 | g_total_loss: 4.0286
# Epoch [ 3570/ 5000] | d_X_loss: 0.0022 | d_Y_loss: 0.0235 | g_total_loss: 4.5417
# Epoch [ 3580/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0006 | g_total_loss: 4.1653
# Epoch [ 3590/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0232 | g_total_loss: 4.4929
# Epoch [ 3600/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0038 | g_total_loss: 3.9689
# Saved image_samples/sample-003600-X-Y.png
# Saved image_samples/sample-003600-Y-X.png
# Epoch [ 3610/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0107 | g_total_loss: 4.2023
# Epoch [ 3620/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0062 | g_total_loss: 4.1386
# Epoch [ 3630/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0028 | g_total_loss: 4.2913
# Epoch [ 3640/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0117 | g_total_loss: 4.3053
# Epoch [ 3650/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0051 | g_total_loss: 4.2301
# Epoch [ 3660/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0074 | g_total_loss: 3.9026
# Epoch [ 3670/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0083 | g_total_loss: 4.0890
# Epoch [ 3680/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0188 | g_total_loss: 3.9869
# Epoch [ 3690/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0059 | g_total_loss: 3.9171
# Epoch [ 3700/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0041 | g_total_loss: 3.9290
# Saved image_samples/sample-003700-X-Y.png
# Saved image_samples/sample-003700-Y-X.png
# Epoch [ 3710/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0073 | g_total_loss: 4.0451
# Epoch [ 3720/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 0.0292 | g_total_loss: 4.2778
# Epoch [ 3730/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0691 | g_total_loss: 4.3728
# Epoch [ 3740/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0171 | g_total_loss: 4.2923
# Epoch [ 3750/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0529 | g_total_loss: 4.1837
# Epoch [ 3760/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0160 | g_total_loss: 4.1034
# Epoch [ 3770/ 5000] | d_X_loss: 0.0007 | d_Y_loss: 0.0453 | g_total_loss: 4.1612
# Epoch [ 3780/ 5000] | d_X_loss: 0.0004 | d_Y_loss: 0.0124 | g_total_loss: 3.8785
# Epoch [ 3790/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0160 | g_total_loss: 3.9410
# Epoch [ 3800/ 5000] | d_X_loss: 0.0012 | d_Y_loss: 0.0212 | g_total_loss: 4.0706
# Saved image_samples/sample-003800-X-Y.png
# Saved image_samples/sample-003800-Y-X.png
# Epoch [ 3810/ 5000] | d_X_loss: 0.0009 | d_Y_loss: 0.0123 | g_total_loss: 4.2181
# Epoch [ 3820/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0167 | g_total_loss: 4.4075
# Epoch [ 3830/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 0.0701 | g_total_loss: 3.8776
# Epoch [ 3840/ 5000] | d_X_loss: 0.0004 | d_Y_loss: 0.0110 | g_total_loss: 4.1869
# Epoch [ 3850/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 0.0208 | g_total_loss: 4.4122
# Epoch [ 3860/ 5000] | d_X_loss: 0.0003 | d_Y_loss: 0.0181 | g_total_loss: 4.1052
# Epoch [ 3870/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0071 | g_total_loss: 4.0857
# Epoch [ 3880/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0102 | g_total_loss: 3.8138
# Epoch [ 3890/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0125 | g_total_loss: 4.1505
# Epoch [ 3900/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0147 | g_total_loss: 4.2245
# Saved image_samples/sample-003900-X-Y.png
# Saved image_samples/sample-003900-Y-X.png
# Epoch [ 3910/ 5000] | d_X_loss: 0.0003 | d_Y_loss: 0.0152 | g_total_loss: 4.0747
# Epoch [ 3920/ 5000] | d_X_loss: 0.0008 | d_Y_loss: 0.0235 | g_total_loss: 4.0236
# Epoch [ 3930/ 5000] | d_X_loss: 0.0007 | d_Y_loss: 0.0247 | g_total_loss: 3.8347
# Epoch [ 3940/ 5000] | d_X_loss: 0.0003 | d_Y_loss: 0.0091 | g_total_loss: 3.8471
# Epoch [ 3950/ 5000] | d_X_loss: 0.0008 | d_Y_loss: 0.0091 | g_total_loss: 4.1852
# Epoch [ 3960/ 5000] | d_X_loss: 0.0003 | d_Y_loss: 0.0083 | g_total_loss: 4.3584
# Epoch [ 3970/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0213 | g_total_loss: 3.7013
# Epoch [ 3980/ 5000] | d_X_loss: 0.0004 | d_Y_loss: 0.0161 | g_total_loss: 3.9959
# Epoch [ 3990/ 5000] | d_X_loss: 0.0003 | d_Y_loss: 0.0154 | g_total_loss: 4.5267
# Epoch [ 4000/ 5000] | d_X_loss: 0.0003 | d_Y_loss: 0.0090 | g_total_loss: 4.1674
# Saved image_samples/sample-004000-X-Y.png
# Saved image_samples/sample-004000-Y-X.png
# Epoch [ 4010/ 5000] | d_X_loss: 0.0012 | d_Y_loss: 0.0083 | g_total_loss: 4.5399
# Epoch [ 4020/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 0.0187 | g_total_loss: 4.0651
# Epoch [ 4030/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 0.0106 | g_total_loss: 4.1182
# Epoch [ 4040/ 5000] | d_X_loss: 0.0017 | d_Y_loss: 0.0158 | g_total_loss: 4.0102
# Epoch [ 4050/ 5000] | d_X_loss: 0.0003 | d_Y_loss: 0.0075 | g_total_loss: 4.0360
# Epoch [ 4060/ 5000] | d_X_loss: 0.0003 | d_Y_loss: 0.0071 | g_total_loss: 4.2920
# Epoch [ 4070/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0105 | g_total_loss: 4.0249
# Epoch [ 4080/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0112 | g_total_loss: 3.9432
# Epoch [ 4090/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0137 | g_total_loss: 3.8566
# Epoch [ 4100/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 0.0059 | g_total_loss: 4.9012
# Saved image_samples/sample-004100-X-Y.png
# Saved image_samples/sample-004100-Y-X.png
# Epoch [ 4110/ 5000] | d_X_loss: 0.0059 | d_Y_loss: 0.0068 | g_total_loss: 4.1756
# Epoch [ 4120/ 5000] | d_X_loss: 0.0006 | d_Y_loss: 0.0035 | g_total_loss: 4.1765
# Epoch [ 4130/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 0.0087 | g_total_loss: 3.9905
# Epoch [ 4140/ 5000] | d_X_loss: 0.0005 | d_Y_loss: 0.0066 | g_total_loss: 3.9711
# Epoch [ 4150/ 5000] | d_X_loss: 0.0007 | d_Y_loss: 0.0235 | g_total_loss: 3.9569
# Epoch [ 4160/ 5000] | d_X_loss: 0.0003 | d_Y_loss: 0.0057 | g_total_loss: 3.7195
# Epoch [ 4170/ 5000] | d_X_loss: 0.3759 | d_Y_loss: 0.0137 | g_total_loss: 3.3106
# Epoch [ 4180/ 5000] | d_X_loss: 0.8490 | d_Y_loss: 0.0108 | g_total_loss: 3.8783
# Epoch [ 4190/ 5000] | d_X_loss: 0.4558 | d_Y_loss: 0.0379 | g_total_loss: 4.7042
# Epoch [ 4200/ 5000] | d_X_loss: 0.2653 | d_Y_loss: 0.3979 | g_total_loss: 4.3080
# Saved image_samples/sample-004200-X-Y.png
# Saved image_samples/sample-004200-Y-X.png
# Epoch [ 4210/ 5000] | d_X_loss: 0.0881 | d_Y_loss: 0.0085 | g_total_loss: 4.1826
# Epoch [ 4220/ 5000] | d_X_loss: 0.1484 | d_Y_loss: 0.0094 | g_total_loss: 4.1170
# Epoch [ 4230/ 5000] | d_X_loss: 0.0483 | d_Y_loss: 0.0151 | g_total_loss: 4.0401
# Epoch [ 4240/ 5000] | d_X_loss: 0.0240 | d_Y_loss: 0.0013 | g_total_loss: 3.8823
# Epoch [ 4250/ 5000] | d_X_loss: 0.0271 | d_Y_loss: 0.0163 | g_total_loss: 4.3336
# Epoch [ 4260/ 5000] | d_X_loss: 0.0085 | d_Y_loss: 0.0512 | g_total_loss: 3.9601
# Epoch [ 4270/ 5000] | d_X_loss: 0.0040 | d_Y_loss: 0.0155 | g_total_loss: 3.7356
# Epoch [ 4280/ 5000] | d_X_loss: 0.0288 | d_Y_loss: 0.0249 | g_total_loss: 3.8234
# Epoch [ 4290/ 5000] | d_X_loss: 0.0766 | d_Y_loss: 0.0287 | g_total_loss: 3.9895
# Epoch [ 4300/ 5000] | d_X_loss: 0.0265 | d_Y_loss: 0.0162 | g_total_loss: 4.1155
# Saved image_samples/sample-004300-X-Y.png
# Saved image_samples/sample-004300-Y-X.png
# Epoch [ 4310/ 5000] | d_X_loss: 0.0175 | d_Y_loss: 0.0150 | g_total_loss: 4.0637
# Epoch [ 4320/ 5000] | d_X_loss: 0.0169 | d_Y_loss: 0.0085 | g_total_loss: 3.8087
# Epoch [ 4330/ 5000] | d_X_loss: 0.0120 | d_Y_loss: 0.0081 | g_total_loss: 4.3988
# Epoch [ 4340/ 5000] | d_X_loss: 0.0008 | d_Y_loss: 0.0079 | g_total_loss: 3.9570
# Epoch [ 4350/ 5000] | d_X_loss: 0.0056 | d_Y_loss: 0.0042 | g_total_loss: 3.9178
# Epoch [ 4360/ 5000] | d_X_loss: 0.0088 | d_Y_loss: 0.0066 | g_total_loss: 3.9257
# Epoch [ 4370/ 5000] | d_X_loss: 0.0024 | d_Y_loss: 0.0073 | g_total_loss: 3.9676
# Epoch [ 4380/ 5000] | d_X_loss: 0.0031 | d_Y_loss: 0.0121 | g_total_loss: 4.1408
# Epoch [ 4390/ 5000] | d_X_loss: 0.0050 | d_Y_loss: 0.0105 | g_total_loss: 3.7759
# Epoch [ 4400/ 5000] | d_X_loss: 0.0029 | d_Y_loss: 0.0698 | g_total_loss: 3.9172
# Saved image_samples/sample-004400-X-Y.png
# Saved image_samples/sample-004400-Y-X.png
# Epoch [ 4410/ 5000] | d_X_loss: 0.0087 | d_Y_loss: 0.0670 | g_total_loss: 4.0513
# Epoch [ 4420/ 5000] | d_X_loss: 0.0004 | d_Y_loss: 0.0119 | g_total_loss: 4.3530
# Epoch [ 4430/ 5000] | d_X_loss: 0.0013 | d_Y_loss: 0.0101 | g_total_loss: 4.0124
# Epoch [ 4440/ 5000] | d_X_loss: 0.0017 | d_Y_loss: 0.0103 | g_total_loss: 4.0853
# Epoch [ 4450/ 5000] | d_X_loss: 0.0056 | d_Y_loss: 0.0026 | g_total_loss: 4.1609
# Epoch [ 4460/ 5000] | d_X_loss: 0.0016 | d_Y_loss: 0.0016 | g_total_loss: 3.9195
# Epoch [ 4470/ 5000] | d_X_loss: 0.0013 | d_Y_loss: 0.0080 | g_total_loss: 4.0897
# Epoch [ 4480/ 5000] | d_X_loss: 0.0006 | d_Y_loss: 0.0021 | g_total_loss: 4.3511
# Epoch [ 4490/ 5000] | d_X_loss: 0.0361 | d_Y_loss: 0.0016 | g_total_loss: 4.2193
# Epoch [ 4500/ 5000] | d_X_loss: 0.0010 | d_Y_loss: 0.0028 | g_total_loss: 4.1371
# Saved image_samples/sample-004500-X-Y.png
# Saved image_samples/sample-004500-Y-X.png
# Epoch [ 4510/ 5000] | d_X_loss: 0.0015 | d_Y_loss: 0.0027 | g_total_loss: 3.8650
# Epoch [ 4520/ 5000] | d_X_loss: 0.0071 | d_Y_loss: 0.0027 | g_total_loss: 3.8491
# Epoch [ 4530/ 5000] | d_X_loss: 0.0084 | d_Y_loss: 0.0098 | g_total_loss: 4.4776
# Epoch [ 4540/ 5000] | d_X_loss: 0.0033 | d_Y_loss: 0.0044 | g_total_loss: 3.9118
# Epoch [ 4550/ 5000] | d_X_loss: 0.0042 | d_Y_loss: 0.0079 | g_total_loss: 4.1752
# Epoch [ 4560/ 5000] | d_X_loss: 0.0034 | d_Y_loss: 0.0056 | g_total_loss: 3.9271
# Epoch [ 4570/ 5000] | d_X_loss: 0.0018 | d_Y_loss: 0.0052 | g_total_loss: 4.0024
# Epoch [ 4580/ 5000] | d_X_loss: 0.0009 | d_Y_loss: 0.0110 | g_total_loss: 4.2197
# Epoch [ 4590/ 5000] | d_X_loss: 0.0008 | d_Y_loss: 0.0137 | g_total_loss: 3.9659
# Epoch [ 4600/ 5000] | d_X_loss: 0.0006 | d_Y_loss: 0.0058 | g_total_loss: 3.8696
# Saved image_samples/sample-004600-X-Y.png
# Saved image_samples/sample-004600-Y-X.png
# Epoch [ 4610/ 5000] | d_X_loss: 0.0024 | d_Y_loss: 0.0076 | g_total_loss: 3.8803
# Epoch [ 4620/ 5000] | d_X_loss: 0.0005 | d_Y_loss: 0.0032 | g_total_loss: 3.9208
# Epoch [ 4630/ 5000] | d_X_loss: 0.0087 | d_Y_loss: 0.0049 | g_total_loss: 3.8636
# Epoch [ 4640/ 5000] | d_X_loss: 0.0032 | d_Y_loss: 0.0096 | g_total_loss: 3.7918
# Epoch [ 4650/ 5000] | d_X_loss: 0.0043 | d_Y_loss: 0.0027 | g_total_loss: 3.8234
# Epoch [ 4660/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 0.0044 | g_total_loss: 3.9343
# Epoch [ 4670/ 5000] | d_X_loss: 0.0085 | d_Y_loss: 0.0135 | g_total_loss: 3.8589
# Epoch [ 4680/ 5000] | d_X_loss: 0.0030 | d_Y_loss: 0.0074 | g_total_loss: 3.9924
# Epoch [ 4690/ 5000] | d_X_loss: 0.0024 | d_Y_loss: 0.0126 | g_total_loss: 4.0745
# Epoch [ 4700/ 5000] | d_X_loss: 0.0003 | d_Y_loss: 0.0121 | g_total_loss: 4.6175
# Saved image_samples/sample-004700-X-Y.png
# Saved image_samples/sample-004700-Y-X.png
# Epoch [ 4710/ 5000] | d_X_loss: 0.0029 | d_Y_loss: 0.0048 | g_total_loss: 3.8614
# Epoch [ 4720/ 5000] | d_X_loss: 0.0672 | d_Y_loss: 0.0039 | g_total_loss: 3.9290
# Epoch [ 4730/ 5000] | d_X_loss: 0.0578 | d_Y_loss: 0.0052 | g_total_loss: 4.3402
# Epoch [ 4740/ 5000] | d_X_loss: 0.0014 | d_Y_loss: 0.0035 | g_total_loss: 4.3212
# Epoch [ 4750/ 5000] | d_X_loss: 0.0008 | d_Y_loss: 0.0001 | g_total_loss: 4.3869
# Epoch [ 4760/ 5000] | d_X_loss: 0.0054 | d_Y_loss: 0.0032 | g_total_loss: 3.9444
# Epoch [ 4770/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0002 | g_total_loss: 4.2272
# Epoch [ 4780/ 5000] | d_X_loss: 0.0007 | d_Y_loss: 0.0001 | g_total_loss: 4.0563
# Epoch [ 4790/ 5000] | d_X_loss: 0.0009 | d_Y_loss: 0.0001 | g_total_loss: 4.5435
# Epoch [ 4800/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.9985
# Saved image_samples/sample-004800-X-Y.png
# Saved image_samples/sample-004800-Y-X.png
# Epoch [ 4810/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0001 | g_total_loss: 3.9936
# Epoch [ 4820/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 0.0000 | g_total_loss: 4.3554
# Epoch [ 4830/ 5000] | d_X_loss: 0.0028 | d_Y_loss: 0.0000 | g_total_loss: 3.9593
# Epoch [ 4840/ 5000] | d_X_loss: 0.0008 | d_Y_loss: 0.0001 | g_total_loss: 3.9739
# Epoch [ 4850/ 5000] | d_X_loss: 0.0012 | d_Y_loss: 0.0000 | g_total_loss: 4.1236
# Epoch [ 4860/ 5000] | d_X_loss: 0.0009 | d_Y_loss: 0.0001 | g_total_loss: 4.0487
# Epoch [ 4870/ 5000] | d_X_loss: 0.0014 | d_Y_loss: 0.0001 | g_total_loss: 3.9383
# Epoch [ 4880/ 5000] | d_X_loss: 0.0071 | d_Y_loss: 0.0000 | g_total_loss: 4.1196
# Epoch [ 4890/ 5000] | d_X_loss: 0.0013 | d_Y_loss: 0.0001 | g_total_loss: 4.1804
# Epoch [ 4900/ 5000] | d_X_loss: 0.0012 | d_Y_loss: 0.0000 | g_total_loss: 4.0044
# Saved image_samples/sample-004900-X-Y.png
# Saved image_samples/sample-004900-Y-X.png
# Epoch [ 4910/ 5000] | d_X_loss: 0.0041 | d_Y_loss: 0.0000 | g_total_loss: 3.9826
# Epoch [ 4920/ 5000] | d_X_loss: 0.0014 | d_Y_loss: 0.0000 | g_total_loss: 3.9739
# Epoch [ 4930/ 5000] | d_X_loss: 0.0038 | d_Y_loss: 0.0001 | g_total_loss: 3.7610
# Epoch [ 4940/ 5000] | d_X_loss: 0.0014 | d_Y_loss: 0.0000 | g_total_loss: 4.1558
# Epoch [ 4950/ 5000] | d_X_loss: 0.0005 | d_Y_loss: 0.0000 | g_total_loss: 4.1664
# Epoch [ 4960/ 5000] | d_X_loss: 0.0008 | d_Y_loss: 0.0000 | g_total_loss: 4.0187
# Epoch [ 4970/ 5000] | d_X_loss: 0.0025 | d_Y_loss: 0.0000 | g_total_loss: 3.9328
# Epoch [ 4980/ 5000] | d_X_loss: 0.0028 | d_Y_loss: 0.0000 | g_total_loss: 4.2811
# Epoch [ 4990/ 5000] | d_X_loss: 0.0013 | d_Y_loss: 0.0001 | g_total_loss: 3.8501
# Epoch [ 5000/ 5000] | d_X_loss: 0.0050 | d_Y_loss: 0.0000 | g_total_loss: 4.0283
# Saved image_samples/sample-005000-X-Y.png
# Saved image_samples/sample-005000-Y-X.png

# %% [markdown]
# #### Training and Loss Patterns

# %%
fig, ax = plt.subplots(figsize=(12,8))
losses = np.array(losses)
plt.plot(losses.T[0], label='Discriminator, X', alpha=0.5)
plt.plot(losses.T[1], label='Discriminator, Y', alpha=0.5)
plt.plot(losses.T[2], label='Generators', alpha=0.5)
plt.title("Training Losses")
plt.legend()

# %% [markdown]
# ### Results

# %%
import matplotlib.image as mpimg

# %%
def view_samples(iteration, sample_dir='/content/image_samples'):
    # samples are named by iteration
    path_XtoY = os.path.join(sample_dir, 'sample-{:06d}-X-Y.png'.format(iteration))
    path_YtoX = os.path.join(sample_dir, 'sample-{:06d}-Y-X.png'.format(iteration))

    # read in those samples
    x2y, y2x = None, None
    try:
        x2y = mpimg.imread(path_XtoY)
        y2x = mpimg.imread(path_YtoX)
    except:
        print('Invalid number of iterations.')

    fig, (ax1, ax2) = plt.subplots(figsize=(18,20), nrows=2, ncols=1, sharey=True, sharex=True)
    ax1.imshow(x2y)
    ax1.set_title('X to Y')
    ax2.imshow(y2x)
    ax2.set_title('Y to X')

# %%
# view samples at iteration 100
view_samples(100)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# view samples at iteration 5000
view_samples(5000)
# Out:
# Output hidden; open in https://colab.research.google.com to view.
